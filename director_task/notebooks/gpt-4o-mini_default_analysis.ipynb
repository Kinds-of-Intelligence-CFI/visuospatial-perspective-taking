# %% [markdown]
# # load each dataset

# %%
import os
import glob

from inspect_ai.log import EvalLog, read_eval_log


fill_ratios = [0.9]
related_ratios = [0.3, 0.5, 0.7, 0.9]
logs: list[list[EvalLog]] = [[] for _ in fill_ratios]

log_dir = "../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini"

def get_eval_file(folder_path):
    """Get the single .eval file from a folder, raise error if not exactly 1."""
    eval_files = glob.glob(os.path.join(folder_path, "*.eval"))
    
    if len(eval_files) == 0:
        raise FileNotFoundError(f"No .eval file found in {folder_path}")
    elif len(eval_files) > 1:
        raise ValueError(f"Multiple .eval files found in {folder_path}: {eval_files}")
    
    return eval_files[0]

for (fill_index, fill) in enumerate(fill_ratios):
    for related in related_ratios:
        folder = os.path.join(log_dir, "fill_ratio_" + str(fill), "related_ratio_" + str(related), "default")
        eval_file = get_eval_file(folder)
        log = read_eval_log(eval_file, resolve_attachments=False, header_only=True)
        print(f"loaded log file: {eval_file}")
        logs[fill_index].append(log)
# Out:
# loaded log file: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# loaded log file: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.5/default/2025-10-22T19-40-30+01-00_directors-task_XZ3rtVYjPbWz5AFGrwYU4E.eval
# loaded log file: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.7/default/2025-10-23T14-55-49+01-00_directors-task_Ve2z3qo2Axj58agBL4aJ4P.eval
# loaded log file: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.9/default/2025-10-24T13-16-40+01-00_directors-task_4t2zihL9VHhtEmXErLQznK.eval

# %%
def parse_coordinate_string(coord_str):
    """
    Parse a coordinate string like 'C2' into (x, y) coordinates.
    
    Args:
        coord_str: String in format 'XY' where X is letter (A,B,C...) and Y is number (0,1,2...)
        
    Returns:
        tuple: (x, y) coordinates where x=column (0-based), y=row (0-based)
        
    Raises:
        ValueError: If string format is invalid
    """
    if not coord_str or len(coord_str) < 2:
        raise ValueError(f"Invalid coordinate string: '{coord_str}'")
    
    # Extract column letter and row number
    col_letter = coord_str[0].upper()
    row_str = coord_str[1:]
    
    # Validate column letter (A-Z)
    if not col_letter.isalpha():
        raise ValueError(f"Invalid column letter: '{col_letter}'")
    
    # Validate row number
    if not row_str.isdigit():
        raise ValueError(f"Invalid row number: '{row_str}'") 
    
    # Convert letter to 0-based column index (A=0, B=1, C=2, ...)
    x = ord(col_letter) - ord('A')
    
    # Convert string to 0-based row index
    y = int(row_str) -1
    
    return (x, y)

# %% [markdown]
# ## now find and calculate the relative error ofr control samples

# %%
import gc

from inspect_ai.model import ContentText
import numpy as np





control_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] =="control":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        control_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue


        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# The 'score' field is deprecated. Access sample scores through 'scores' instead.
# Error parsing coordinates for answer 'none': Invalid row number: 'one'
# Error parsing coordinates for answer '2A': Invalid column letter: '2'
# Error parsing coordinates for answer 'not found': Invalid row number: 'ot found'
# Error parsing coordinates for answer 'There is no shoe present in the grid.': Invalid row number: 'here is no shoe present in the grid.'
# Error parsing coordinates for answer 'There are no brown clothes in the grid.': Invalid row number: 'here are no brown clothes in the grid.'
# Error parsing coordinates for answer 'none found': Invalid row number: 'one found'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.5/default/2025-10-22T19-40-30+01-00_directors-task_XZ3rtVYjPbWz5AFGrwYU4E.eval
# Error parsing coordinates for answer 'There is no large car available.': Invalid row number: 'here is no large car available.'
# Error parsing coordinates for answer '1D': Invalid column letter: '1'
# Error parsing coordinates for answer 'No book found': Invalid row number: 'o book found'
# Error parsing coordinates for answer 'Item not found': Invalid row number: 'tem not found'
# Error parsing coordinates for answer 'There are no clothes in the grid.': Invalid row number: 'here are no clothes in the grid.'
# Error parsing coordinates for answer 'Not Found': Invalid row number: 'ot Found'
# Error parsing coordinates for answer 'No fruit found.': Invalid row number: 'o fruit found.'
# Error parsing coordinates for answer 'NA': Invalid row number: 'A'
# Error parsing coordinates for answer 'No black shoe is present.': Invalid row number: 'o black shoe is present.'
# Error parsing coordinates for answer 'No items matching 'brown sharp clothes' found in the grid.': Invalid row number: 'o items matching 'brown sharp clothes' found in the grid.'
# Error parsing coordinates for answer 'There is no green plant in the grid.': Invalid row number: 'here is no green plant in the grid.'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.7/default/2025-10-23T14-55-49+01-00_directors-task_Ve2z3qo2Axj58agBL4aJ4P.eval
# Error parsing coordinates for answer 'No purple fruit': Invalid row number: 'o purple fruit'
# Error parsing coordinates for answer 'No black bag found': Invalid row number: 'o black bag found'
# Error parsing coordinates for answer 'No visible stackable book available.': Invalid row number: 'o visible stackable book available.'
# Error parsing coordinates for answer 'No': Invalid row number: 'o'
# Error parsing coordinates for answer 'No visible plant in the grid.': Invalid row number: 'o visible plant in the grid.'
# Error parsing coordinates for answer 'No matching item found.': Invalid row number: 'o matching item found.'
# Error parsing coordinates for answer 'Not available': Invalid row number: 'ot available'
# Error parsing coordinates for answer '3A': Invalid column letter: '3'
# Error parsing coordinates for answer 'Not found': Invalid row number: 'ot found'
# Error parsing coordinates for answer 'No books found.': Invalid row number: 'o books found.'
# Error parsing coordinates for answer 'Item not found': Invalid row number: 'tem not found'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.9/default/2025-10-24T13-16-40+01-00_directors-task_4t2zihL9VHhtEmXErLQznK.eval
# Error parsing coordinates for answer 'No sharp shoe found.': Invalid row number: 'o sharp shoe found.'
# Error parsing coordinates for answer 'No sharp shoe found in the grid.': Invalid row number: 'o sharp shoe found in the grid.'
# Error parsing coordinates for answer 'No brown clothes are present in the grid.': Invalid row number: 'o brown clothes are present in the grid.'
# Error parsing coordinates for answer 'There is no bag present in the grid.': Invalid row number: 'here is no bag present in the grid.'
# Error parsing coordinates for answer 'No item labeled as a stackable book is present in the grid.': Invalid row number: 'o item labeled as a stackable book is present in the grid.'
# Error parsing coordinates for answer '4A': Invalid column letter: '4'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

# Convert control_errors to a more analysis-friendly format
print(f"Total control errors analyzed: {len(control_errors)}")

if len(control_errors) > 0:
    # Create a counter for error patterns
    error_counter = Counter(tuple(error) for error in control_errors)

    # Get the range of errors to determine heatmap size
    x_errors = [error[0] for error in control_errors]
    y_errors = [error[1] for error in control_errors]

    x_min, x_max = min(x_errors), max(x_errors)
    y_min, y_max = min(y_errors), max(y_errors)

    print(f"Error range: x [{x_min}, {x_max}], y [{y_min}, {y_max}]")

    # Create a grid for the heatmap
    # Make it symmetric around 0 for better visualization
    max_abs_x = max(abs(x_min), abs(x_max))
    max_abs_y = max(abs(y_min), abs(y_max))

    # Create grid centered at 0
    grid_size_x = 2 * max_abs_x + 1
    grid_size_y = 2 * max_abs_y + 1

    heatmap_data = np.zeros((grid_size_y, grid_size_x))

    # Fill in the heatmap data
    for (dx, dy), count in error_counter.items():
        # Convert error coordinates to heatmap indices
        heatmap_x = dx + max_abs_x  # Center at max_abs_x
        heatmap_y = dy + max_abs_y  # Center at max_abs_y
        heatmap_data[heatmap_y, heatmap_x] = count

    # Create the visualization
    plt.figure(figsize=(12, 8))

    # Find min and max values for log scale (excluding zeros)
    nonzero_data = heatmap_data[heatmap_data > 0]
    if len(nonzero_data) > 0:
        vmin = nonzero_data.min()
        vmax = nonzero_data.max()

        # Create heatmap with log scale
        # We need to handle zeros specially for log scale
        heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)

        sns.heatmap(heatmap_data_log,
                    annot=heatmap_data,  # Show actual counts in annotations
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Reds',
                    norm=LogNorm(vmin=vmin, vmax=vmax),
                    xticklabels=range(-max_abs_x, max_abs_x + 1),
                    yticklabels=range(-max_abs_y, max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors (log scale)'})
    else:
        # Fallback to linear scale if no data
        sns.heatmap(heatmap_data,
                    annot=True,
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Reds',
                    center=0,
                    xticklabels=range(-max_abs_x, max_abs_x + 1),
                    yticklabels=range(-max_abs_y, max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors'})

    plt.title('Control Sample Error Patterns (Log Scale)\n(Answer Position - Correct Position)', fontsize=18)
    plt.xlabel('Column Error (Δx)', fontsize=16)
    plt.ylabel('Row Error (Δy)', fontsize=16)
    plt.tick_params(labelsize=12)

    # Add a marker for the "correct" position (0,0)
    center_x = max_abs_x
    center_y = max_abs_y
    plt.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=200, color='blue',
                label='Perfect Match (0,0)')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # Print some statistics
    print(f"\nError Statistics:")
    print(f"Most common error: {error_counter.most_common(1)[0] if error_counter else 
'None'}")
    print(f"Unique error patterns: {len(error_counter)}")

    # Show top 5 most common errors
    print(f"\nTop 5 most common error patterns:")
    for i, ((dx, dy), count) in enumerate(error_counter.most_common(5)):
        print(f"  {i+1}. Error ({dx:+2d}, {dy:+2d}): {count} occurrences")

    # Calculate some basic statistics
    x_errors_array = np.array(x_errors)
    y_errors_array = np.array(y_errors)

    print(f"\nMean error: ({np.mean(x_errors_array):+.2f}, {np.mean(y_errors_array):+.2f})")
    print(f"Std error: ({np.std(x_errors_array):.2f}, {np.std(y_errors_array):.2f})")

else:
    print("No control errors found to visualize.")
# Out:
# Total control errors analyzed: 2493
# Error range: x [-3, 3], y [-3, 3]
# Error Statistics:
# Most common error: ((np.int64(1), np.int64(0)), 428)
# Unique error patterns: 48
#
# Top 5 most common error patterns:
#   1. Error (+1, +0): 428 occurrences
#   2. Error (-1, +0): 219 occurrences
#   3. Error (+0, +1): 133 occurrences
#   4. Error (+2, +0): 116 occurrences
#   5. Error (+0, -1): 110 occurrences
#
# Mean error: (-0.12, -0.01)
# Std error: (1.77, 1.35)

# %% [markdown]
# ## Test Sample Error Analysis

# %%
test_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] == "test":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        test_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue

        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# Error parsing coordinates for answer '3A': Invalid column letter: '3'
# Error parsing coordinates for answer 'No sharp clothes found.': Invalid row number: 'o sharp clothes found.'
# Error parsing coordinates for answer 'No black clothes found.': Invalid row number: 'o black clothes found.'
# Error parsing coordinates for answer 'No items found.': Invalid row number: 'o items found.'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.5/default/2025-10-22T19-40-30+01-00_directors-task_XZ3rtVYjPbWz5AFGrwYU4E.eval
# Error parsing coordinates for answer 'No sharp clothes present': Invalid row number: 'o sharp clothes present'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.7/default/2025-10-23T14-55-49+01-00_directors-task_Ve2z3qo2Axj58agBL4aJ4P.eval
# Error parsing coordinates for answer 'No sharp clothes found.': Invalid row number: 'o sharp clothes found.'
# Error parsing coordinates for answer 'No valid item.': Invalid row number: 'o valid item.'
# Error parsing coordinates for answer 'None': Invalid row number: 'one'
# Error parsing coordinates for answer 'There are no clothing items visible on the shelving grid.': Invalid row number: 'here are no clothing items visible on the shelving grid.'
# Error parsing coordinates for answer 'No sharp clothes found.': Invalid row number: 'o sharp clothes found.'
# Error parsing coordinates for answer 'No brown sharp shoe is present in the grid.': Invalid row number: 'o brown sharp shoe is present in the grid.'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.9/default/2025-10-24T13-16-40+01-00_directors-task_4t2zihL9VHhtEmXErLQznK.eval

# %%
# Convert test_errors to a more analysis-friendly format
print(f"Total test errors analyzed: {len(test_errors)}")

if len(test_errors) > 0:
    # Create a counter for error patterns
    test_error_counter = Counter(tuple(error) for error in test_errors)
    
    # Get the range of errors to determine heatmap size
    x_errors = [error[0] for error in test_errors]
    y_errors = [error[1] for error in test_errors]
    
    x_min, x_max = min(x_errors), max(x_errors)
    y_min, y_max = min(y_errors), max(y_errors)
    
    print(f"Error range: x [{x_min}, {x_max}], y [{y_min}, {y_max}]")
    
    # Create a grid for the heatmap
    # Make it symmetric around 0 for better visualization
    max_abs_x = max(abs(x_min), abs(x_max))
    max_abs_y = max(abs(y_min), abs(y_max))
    
    # Create grid centered at 0
    grid_size_x = 2 * max_abs_x + 1
    grid_size_y = 2 * max_abs_y + 1
    
    heatmap_data = np.zeros((grid_size_y, grid_size_x))
    
    # Fill in the heatmap data
    for (dx, dy), count in test_error_counter.items():
        # Convert error coordinates to heatmap indices
        heatmap_x = dx + max_abs_x  # Center at max_abs_x
        heatmap_y = dy + max_abs_y  # Center at max_abs_y
        heatmap_data[heatmap_y, heatmap_x] = count
    
    # Create the visualization
    plt.figure(figsize=(12, 8))
    
    # Find min and max values for log scale (excluding zeros)
    nonzero_data = heatmap_data[heatmap_data > 0]
    if len(nonzero_data) > 0:
        vmin = nonzero_data.min()
        vmax = nonzero_data.max()
        
        # Create heatmap with log scale
        # We need to handle zeros specially for log scale
        heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)
        
        sns.heatmap(heatmap_data_log, 
                    annot=heatmap_data,  # Show actual counts in annotations
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Blues',  # Different color to distinguish from control samples
                    norm=LogNorm(vmin=vmin, vmax=vmax),
                    xticklabels=range(-max_abs_x, max_abs_x + 1),
                    yticklabels=range(-max_abs_y, max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors (log scale)'})
    else:
        # Fallback to linear scale if no data
        sns.heatmap(heatmap_data, 
                    annot=True, 
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Blues',
                    center=0,
                    xticklabels=range(-max_abs_x, max_abs_x + 1),
                    yticklabels=range(-max_abs_y, max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors'})
    
    plt.title('Test Sample Error Patterns (Log Scale)\n(Answer Position - Correct Position)', fontsize=18)
    plt.xlabel('Column Error (Δx)', fontsize=16)
    plt.ylabel('Row Error (Δy)', fontsize=16)
    plt.tick_params(labelsize=12)
    
    # Add a marker for the "correct" position (0,0)
    center_x = max_abs_x
    center_y = max_abs_y
    plt.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=200, color='orange', 
                label='Perfect Match (0,0)')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Print some statistics
    print(f"\nTest Sample Error Statistics:")
    print(f"Most common error: {test_error_counter.most_common(1)[0] if test_error_counter else 'None'}")
    print(f"Unique error patterns: {len(test_error_counter)}")
    
    # Show top 5 most common errors
    print(f"\nTop 5 most common error patterns:")
    for i, ((dx, dy), count) in enumerate(test_error_counter.most_common(5)):
        print(f"  {i+1}. Error ({dx:+2d}, {dy:+2d}): {count} occurrences")
    
    # Calculate some basic statistics
    x_errors_array = np.array(x_errors)
    y_errors_array = np.array(y_errors)
    
    print(f"\nMean error: ({np.mean(x_errors_array):+.2f}, {np.mean(y_errors_array):+.2f})")
    print(f"Std error: ({np.std(x_errors_array):.2f}, {np.std(y_errors_array):.2f})")
    
else:
    print("No test errors found to visualize.")
# Out:
# Total test errors analyzed: 3416
# Error range: x [-3, 3], y [-3, 3]
# Test Sample Error Statistics:
# Most common error: ((np.int64(-1), np.int64(0)), 259)
# Unique error patterns: 48
#
# Top 5 most common error patterns:
#   1. Error (-1, +0): 259 occurrences
#   2. Error (+1, +0): 248 occurrences
#   3. Error (-2, +0): 192 occurrences
#   4. Error (+0, -1): 184 occurrences
#   5. Error (-1, -1): 174 occurrences
#
# Mean error: (-0.42, -0.19)
# Std error: (1.63, 1.53)

# %% [markdown]
# ## Comparison: Control vs Test Sample Errors

# %%
# Side-by-side comparison of control vs test errors
if len(control_errors) > 0 and len(test_errors) > 0:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
    
    # Prepare data for both plots
    control_counter = Counter(tuple(error) for error in control_errors)
    test_counter = Counter(tuple(error) for error in test_errors)
    
    # Get combined range for consistent scaling
    all_x = [error[0] for error in control_errors + test_errors]
    all_y = [error[1] for error in control_errors + test_errors]
    
    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x)))
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y)))
    
    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1
    
    # Control errors heatmap
    control_heatmap = np.zeros((grid_size_y, grid_size_x))
    for (dx, dy), count in control_counter.items():
        heatmap_x = dx + combined_max_abs_x
        heatmap_y = dy + combined_max_abs_y
        control_heatmap[heatmap_y, heatmap_x] = count
    
    # Test errors heatmap  
    test_heatmap = np.zeros((grid_size_y, grid_size_x))
    for (dx, dy), count in test_counter.items():
        heatmap_x = dx + combined_max_abs_x
        heatmap_y = dy + combined_max_abs_y
        test_heatmap[heatmap_y, heatmap_x] = count
    
    # Find global min/max for consistent color scaling
    control_nonzero = control_heatmap[control_heatmap > 0]
    test_nonzero = test_heatmap[test_heatmap > 0]
    
    if len(control_nonzero) > 0 and len(test_nonzero) > 0:
        global_vmin = min(control_nonzero.min(), test_nonzero.min())
        global_vmax = max(control_nonzero.max(), test_nonzero.max())
        
        # Control plot
        control_data_log = np.where(control_heatmap > 0, control_heatmap, np.nan)
        sns.heatmap(control_data_log,
                    annot=control_heatmap,
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Reds',
                    norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                    xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                    yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors (log scale)'},
                    ax=ax1)
        
        ax1.set_title('Control Sample Errors', fontsize=18)
        ax1.set_xlabel('Column Error (Δx)', fontsize=16)
        ax1.set_ylabel('Row Error (Δy)', fontsize=16)
        ax1.tick_params(labelsize=12)
        
        # Test plot
        test_data_log = np.where(test_heatmap > 0, test_heatmap, np.nan)
        sns.heatmap(test_data_log,
                    annot=test_heatmap,
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Blues',
                    norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                    xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                    yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors (log scale)'},
                    ax=ax2)
        
        ax2.set_title('Test Sample Errors', fontsize=18)
        ax2.set_xlabel('Column Error (Δx)', fontsize=16)
        ax2.set_ylabel('Row Error (Δy)', fontsize=16)
        ax2.tick_params(labelsize=12)
        
        # Add markers for perfect match
        center_x = combined_max_abs_x
        center_y = combined_max_abs_y
        ax1.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=200, color='blue', label='Perfect Match (0,0)')
        ax2.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=200, color='orange', label='Perfect Match (0,0)')
        
        ax1.legend()
        ax2.legend()
        
        plt.tight_layout()
        plt.show()
        
        # Comparative statistics
        print("=== COMPARATIVE STATISTICS ===")
        print(f"Control errors: {len(control_errors)} total, {len(control_counter)} unique patterns")
        print(f"Test errors: {len(test_errors)} total, {len(test_counter)} unique patterns")
        
        control_x = np.array([error[0] for error in control_errors])
        control_y = np.array([error[1] for error in control_errors])
        test_x = np.array([error[0] for error in test_errors])
        test_y = np.array([error[1] for error in test_errors])
        
        print(f"\nMean errors:")
        print(f"  Control: ({np.mean(control_x):+.2f}, {np.mean(control_y):+.2f})")
        print(f"  Test:    ({np.mean(test_x):+.2f}, {np.mean(test_y):+.2f})")
        
        print(f"\nStandard deviation:")
        print(f"  Control: ({np.std(control_x):.2f}, {np.std(control_y):.2f})")
        print(f"  Test:    ({np.std(test_x):.2f}, {np.std(test_y):.2f})")
        
        print(f"\nMost common error patterns:")
        print(f"  Control: {control_counter.most_common(1)[0] if control_counter else 'None'}")
        print(f"  Test:    {test_counter.most_common(1)[0] if test_counter else 'None'}")
        
else:
    print("Need both control and test errors for comparison.")
# Out:
# === COMPARATIVE STATISTICS ===
# Control errors: 2493 total, 48 unique patterns
# Test errors: 3416 total, 48 unique patterns
#
# Mean errors:
#   Control: (-0.12, -0.01)
#   Test:    (-0.42, -0.19)
#
# Standard deviation:
#   Control: (1.77, 1.35)
#   Test:    (1.63, 1.53)
#
# Most common error patterns:
#   Control: ((np.int64(1), np.int64(0)), 428)
#   Test:    ((np.int64(-1), np.int64(0)), 259)

# %% [markdown]
# ## now look at left right tasks
# we should now make a heatmap of errors but for left-right questions and split it by reversed or not.

# %%
import gc

import numpy as np





control_left_reversed_errors = []
control_left_same_errors = []
control_right_reversed_errors = []
control_right_same_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] =="control":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        if sample.metadata["question"]["selection_rule"] == "leftmost" and sample.metadata["question"]["is_reversed"]:
                            control_left_reversed_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "leftmost" and not sample.metadata["question"]["is_reversed"]:
                            control_left_same_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "rightmost" and sample.metadata["question"]["is_reversed"]:
                            control_right_reversed_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "rightmost" and not sample.metadata["question"]["is_reversed"]:
                            control_right_same_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue


        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# Error parsing coordinates for answer 'none': Invalid row number: 'one'
# Error parsing coordinates for answer '2A': Invalid column letter: '2'
# Error parsing coordinates for answer 'not found': Invalid row number: 'ot found'
# Error parsing coordinates for answer 'There is no shoe present in the grid.': Invalid row number: 'here is no shoe present in the grid.'
# Error parsing coordinates for answer 'There are no brown clothes in the grid.': Invalid row number: 'here are no brown clothes in the grid.'
# Error parsing coordinates for answer 'none found': Invalid row number: 'one found'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.5/default/2025-10-22T19-40-30+01-00_directors-task_XZ3rtVYjPbWz5AFGrwYU4E.eval
# Error parsing coordinates for answer 'There is no large car available.': Invalid row number: 'here is no large car available.'
# Error parsing coordinates for answer '1D': Invalid column letter: '1'
# Error parsing coordinates for answer 'No book found': Invalid row number: 'o book found'
# Error parsing coordinates for answer 'Item not found': Invalid row number: 'tem not found'
# Error parsing coordinates for answer 'There are no clothes in the grid.': Invalid row number: 'here are no clothes in the grid.'
# Error parsing coordinates for answer 'Not Found': Invalid row number: 'ot Found'
# Error parsing coordinates for answer 'No fruit found.': Invalid row number: 'o fruit found.'
# Error parsing coordinates for answer 'NA': Invalid row number: 'A'
# Error parsing coordinates for answer 'No black shoe is present.': Invalid row number: 'o black shoe is present.'
# Error parsing coordinates for answer 'No items matching 'brown sharp clothes' found in the grid.': Invalid row number: 'o items matching 'brown sharp clothes' found in the grid.'
# Error parsing coordinates for answer 'There is no green plant in the grid.': Invalid row number: 'here is no green plant in the grid.'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.7/default/2025-10-23T14-55-49+01-00_directors-task_Ve2z3qo2Axj58agBL4aJ4P.eval
# Error parsing coordinates for answer 'No purple fruit': Invalid row number: 'o purple fruit'
# Error parsing coordinates for answer 'No black bag found': Invalid row number: 'o black bag found'
# Error parsing coordinates for answer 'No visible stackable book available.': Invalid row number: 'o visible stackable book available.'
# Error parsing coordinates for answer 'No': Invalid row number: 'o'
# Error parsing coordinates for answer 'No visible plant in the grid.': Invalid row number: 'o visible plant in the grid.'
# Error parsing coordinates for answer 'No matching item found.': Invalid row number: 'o matching item found.'
# Error parsing coordinates for answer 'Not available': Invalid row number: 'ot available'
# Error parsing coordinates for answer '3A': Invalid column letter: '3'
# Error parsing coordinates for answer 'Not found': Invalid row number: 'ot found'
# Error parsing coordinates for answer 'No books found.': Invalid row number: 'o books found.'
# Error parsing coordinates for answer 'Item not found': Invalid row number: 'tem not found'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.9/default/2025-10-24T13-16-40+01-00_directors-task_4t2zihL9VHhtEmXErLQznK.eval
# Error parsing coordinates for answer 'No sharp shoe found.': Invalid row number: 'o sharp shoe found.'
# Error parsing coordinates for answer 'No sharp shoe found in the grid.': Invalid row number: 'o sharp shoe found in the grid.'
# Error parsing coordinates for answer 'No brown clothes are present in the grid.': Invalid row number: 'o brown clothes are present in the grid.'
# Error parsing coordinates for answer 'There is no bag present in the grid.': Invalid row number: 'here is no bag present in the grid.'
# Error parsing coordinates for answer 'No item labeled as a stackable book is present in the grid.': Invalid row number: 'o item labeled as a stackable book is present in the grid.'
# Error parsing coordinates for answer '4A': Invalid column letter: '4'

# %%
# Visualize left/right errors split by reversed/same direction
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

# Print summary statistics
print("=== LEFT/RIGHT ERROR ANALYSIS ===")
print(f"Control Left Reversed errors: {len(control_left_reversed_errors)}")
print(f"Control Left Same errors: {len(control_left_same_errors)}")
print(f"Control Right Reversed errors: {len(control_right_reversed_errors)}")
print(f"Control Right Same errors: {len(control_right_same_errors)}")

# Combine all errors to determine consistent scaling
all_left_right_errors = (control_left_reversed_errors + control_left_same_errors + 
                        control_right_reversed_errors + control_right_same_errors)

if len(all_left_right_errors) > 0:
    # Get combined range for consistent scaling
    all_x = [error[0] for error in all_left_right_errors]
    all_y = [error[1] for error in all_left_right_errors]
    
    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0
    
    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1
    
    # Create 2x2 subplot for the four categories
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    
    # Function to create individual heatmap
    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center', 
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None
        
        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))
        
        # Fill in the heatmap data
        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count
        
        return heatmap_data, error_counter
    
    # Create heatmaps for each category
    categories = [
        (control_left_reversed_errors, ax1, "Left Reversed 'rightmost x from my perspective'", "Reds"),
        (control_left_same_errors, ax2, "Left Same'leftmost x from your perspective'", "Blues"),
        (control_right_reversed_errors, ax3, "Right Reversed 'leftmost x from my perspective'", "Greens"),
        (control_right_same_errors, ax4, "Right Same 'rightmost x from your perspective'", "Purples")
    ]
    
    # Collect all non-zero data to determine global color scale
    all_heatmaps = []
    all_counters = []
    
    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)
    
    # Find global min/max for consistent color scaling
    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)
    
    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)
        
        # Create the actual heatmaps with consistent scaling
        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                # Create heatmap with log scale
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)
                
                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)
                
                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (Δx)', fontsize=14)
                ax.set_ylabel('Row Error (Δy)', fontsize=14)
                ax.tick_params(labelsize=10)
                
                # Add marker for perfect match
                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150, 
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)
    
    plt.suptitle('Control Sample Errors: Left/Right Questions by perspective', 
                 fontsize=14, y=0.98)
    plt.tight_layout()
    plt.show()
    
    # Print detailed statistics
    print("\n=== DETAILED STATISTICS ===")
    
    category_names = ["Left Reversed 'rightmost x from my perspective'", "Left Same'leftmost x from your perspective'", "Right Reversed 'leftmost x from my perspective'", "Right Same 'rightmost x from your perspective'"]
    error_lists = [control_left_reversed_errors, control_left_same_errors, 
                   control_right_reversed_errors, control_right_same_errors]
    
    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])
            
            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")
            
            if len(errors) > 0:
                counter = Counter(tuple(error) for error in errors)
                print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")
    
else:
    print("No left/right errors found to visualize.")
# Out:
# === LEFT/RIGHT ERROR ANALYSIS ===
# Control Left Reversed errors: 245
# Control Left Same errors: 118
# Control Right Reversed errors: 270
# Control Right Same errors: 164
# === DETAILED STATISTICS ===
#
# Left Reversed 'rightmost x from my perspective':
#   Count: 245
#   Mean error: (+2.49, +0.72)
#   Std error: (0.80, 1.34)
#   Most common: ((np.int64(3), np.int64(0)), 55)
#
# Left Same'leftmost x from your perspective':
#   Count: 118
#   Mean error: (+0.43, -0.72)
#   Std error: (1.00, 1.44)
#   Most common: ((np.int64(0), np.int64(-1)), 15)
#
# Right Reversed 'leftmost x from my perspective':
#   Count: 270
#   Mean error: (-2.49, -0.94)
#   Std error: (0.86, 1.51)
#   Most common: ((np.int64(-3), np.int64(-2)), 48)
#
# Right Same 'rightmost x from your perspective':
#   Count: 164
#   Mean error: (-0.34, +0.20)
#   Std error: (0.79, 1.53)
#   Most common: ((np.int64(0), np.int64(1)), 27)

# %% [markdown]
# ## Top/Bottom Question Analysis

# %%
import gc
import numpy as np

# Collect errors for topmost/bottommost questions
control_top_reversed_errors = []
control_top_same_errors = []
control_bottom_reversed_errors = []
control_bottom_same_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] =="control":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        
                        # Classify based on selection rule and perspective
                        selection_rule = sample.metadata["question"]["selection_rule"]
                        is_reversed = sample.metadata["question"]["is_reversed"]
                        
                        if selection_rule == "topmost" and is_reversed:
                            control_top_reversed_errors.append(difference)
                        elif selection_rule == "topmost" and not is_reversed:
                            control_top_same_errors.append(difference)
                        elif selection_rule == "bottommost" and is_reversed:
                            control_bottom_reversed_errors.append(difference)
                        elif selection_rule == "bottommost" and not is_reversed:
                            control_bottom_same_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue

        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# Error parsing coordinates for answer 'none': Invalid row number: 'one'
# Error parsing coordinates for answer '2A': Invalid column letter: '2'
# Error parsing coordinates for answer 'not found': Invalid row number: 'ot found'
# Error parsing coordinates for answer 'There is no shoe present in the grid.': Invalid row number: 'here is no shoe present in the grid.'
# Error parsing coordinates for answer 'There are no brown clothes in the grid.': Invalid row number: 'here are no brown clothes in the grid.'
# Error parsing coordinates for answer 'none found': Invalid row number: 'one found'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.5/default/2025-10-22T19-40-30+01-00_directors-task_XZ3rtVYjPbWz5AFGrwYU4E.eval
# Error parsing coordinates for answer 'There is no large car available.': Invalid row number: 'here is no large car available.'
# Error parsing coordinates for answer '1D': Invalid column letter: '1'
# Error parsing coordinates for answer 'No book found': Invalid row number: 'o book found'
# Error parsing coordinates for answer 'Item not found': Invalid row number: 'tem not found'
# Error parsing coordinates for answer 'There are no clothes in the grid.': Invalid row number: 'here are no clothes in the grid.'
# Error parsing coordinates for answer 'Not Found': Invalid row number: 'ot Found'
# Error parsing coordinates for answer 'No fruit found.': Invalid row number: 'o fruit found.'
# Error parsing coordinates for answer 'NA': Invalid row number: 'A'
# Error parsing coordinates for answer 'No black shoe is present.': Invalid row number: 'o black shoe is present.'
# Error parsing coordinates for answer 'No items matching 'brown sharp clothes' found in the grid.': Invalid row number: 'o items matching 'brown sharp clothes' found in the grid.'
# Error parsing coordinates for answer 'There is no green plant in the grid.': Invalid row number: 'here is no green plant in the grid.'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.7/default/2025-10-23T14-55-49+01-00_directors-task_Ve2z3qo2Axj58agBL4aJ4P.eval
# Error parsing coordinates for answer 'No purple fruit': Invalid row number: 'o purple fruit'
# Error parsing coordinates for answer 'No black bag found': Invalid row number: 'o black bag found'
# Error parsing coordinates for answer 'No visible stackable book available.': Invalid row number: 'o visible stackable book available.'
# Error parsing coordinates for answer 'No': Invalid row number: 'o'
# Error parsing coordinates for answer 'No visible plant in the grid.': Invalid row number: 'o visible plant in the grid.'
# Error parsing coordinates for answer 'No matching item found.': Invalid row number: 'o matching item found.'
# Error parsing coordinates for answer 'Not available': Invalid row number: 'ot available'
# Error parsing coordinates for answer '3A': Invalid column letter: '3'
# Error parsing coordinates for answer 'Not found': Invalid row number: 'ot found'
# Error parsing coordinates for answer 'No books found.': Invalid row number: 'o books found.'
# Error parsing coordinates for answer 'Item not found': Invalid row number: 'tem not found'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.9/default/2025-10-24T13-16-40+01-00_directors-task_4t2zihL9VHhtEmXErLQznK.eval
# Error parsing coordinates for answer 'No sharp shoe found.': Invalid row number: 'o sharp shoe found.'
# Error parsing coordinates for answer 'No sharp shoe found in the grid.': Invalid row number: 'o sharp shoe found in the grid.'
# Error parsing coordinates for answer 'No brown clothes are present in the grid.': Invalid row number: 'o brown clothes are present in the grid.'
# Error parsing coordinates for answer 'There is no bag present in the grid.': Invalid row number: 'here is no bag present in the grid.'
# Error parsing coordinates for answer 'No item labeled as a stackable book is present in the grid.': Invalid row number: 'o item labeled as a stackable book is present in the grid.'
# Error parsing coordinates for answer '4A': Invalid column letter: '4'

# %%
# Visualize top/bottom errors split by reversed/same direction
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

# Print summary statistics
print("=== TOP/BOTTOM ERROR ANALYSIS ===")
print(f"Control Top Reversed errors: {len(control_top_reversed_errors)}")
print(f"Control Top Same errors: {len(control_top_same_errors)}")
print(f"Control Bottom Reversed errors: {len(control_bottom_reversed_errors)}")
print(f"Control Bottom Same errors: {len(control_bottom_same_errors)}")

# Combine all errors to determine consistent scaling
all_top_bottom_errors = (control_top_reversed_errors + control_top_same_errors + 
                        control_bottom_reversed_errors + control_bottom_same_errors)

if len(all_top_bottom_errors) > 0:
    # Get combined range for consistent scaling
    all_x = [error[0] for error in all_top_bottom_errors]
    all_y = [error[1] for error in all_top_bottom_errors]
    
    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0
    
    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1
    
    # Create 2x2 subplot for the four categories
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    
    # Function to create individual heatmap
    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center', 
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None
        
        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))
        
        # Fill in the heatmap data
        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count
        
        return heatmap_data, error_counter
    
    # Create heatmaps for each category
    categories = [
        (control_top_reversed_errors, ax1, "Top Reversed 'topmost x from my perspective'", "Reds"),
        (control_top_same_errors, ax2, "Top Same 'topmost x from your perspective'", "Blues"),
        (control_bottom_reversed_errors, ax3, "Bottom Reversed 'bottommost x from my perspective'", "Greens"),
        (control_bottom_same_errors, ax4, "Bottom Same 'bottommost x from your perspective'", "Purples")
    ]
    
    # Collect all non-zero data to determine global color scale
    all_heatmaps = []
    all_counters = []
    
    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)
    
    # Find global min/max for consistent color scaling
    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)
    
    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)
        
        # Create the actual heatmaps with consistent scaling
        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                # Create heatmap with log scale
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)
                
                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)
                
                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (Δx)', fontsize=14)
                ax.set_ylabel('Row Error (Δy)', fontsize=14)
                ax.tick_params(labelsize=10)
                
                # Add marker for perfect match
                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150, 
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)
    
    plt.suptitle('Control Sample Errors: Top/Bottom Questions by Perspective', 
                 fontsize=14, y=0.98)
    plt.tight_layout()
    plt.show()
    
    # Print detailed statistics
    print("\n=== DETAILED STATISTICS ===")
    
    category_names = [
        "Top Reversed 'topmost x from my perspective'", 
        "Top Same 'topmost x from your perspective'", 
        "Bottom Reversed 'bottommost x from my perspective'", 
        "Bottom Same 'bottommost x from your perspective'"
    ]
    error_lists = [control_top_reversed_errors, control_top_same_errors, 
                   control_bottom_reversed_errors, control_bottom_same_errors]
    
    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])
            
            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")
            
            if len(errors) > 0:
                counter = Counter(tuple(error) for error in errors)
                print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")
    
else:
    print("No top/bottom errors found to visualize.")
# Out:
# === TOP/BOTTOM ERROR ANALYSIS ===
# Control Top Reversed errors: 135
# Control Top Same errors: 144
# Control Bottom Reversed errors: 174
# Control Bottom Same errors: 177
# === DETAILED STATISTICS ===
#
# Top Reversed 'topmost x from my perspective':
#   Count: 135
#   Mean error: (-1.01, +0.84)
#   Std error: (1.41, 0.69)
#   Most common: ((np.int64(-2), np.int64(1)), 27)
#
# Top Same 'topmost x from your perspective':
#   Count: 144
#   Mean error: (-0.97, +0.82)
#   Std error: (1.35, 0.76)
#   Most common: ((np.int64(-1), np.int64(1)), 26)
#
# Bottom Reversed 'bottommost x from my perspective':
#   Count: 174
#   Mean error: (-0.53, -0.35)
#   Std error: (1.54, 0.78)
#   Most common: ((np.int64(-1), np.int64(0)), 35)
#
# Bottom Same 'bottommost x from your perspective':
#   Count: 177
#   Mean error: (-0.52, -0.42)
#   Std error: (1.60, 0.85)
#   Most common: ((np.int64(1), np.int64(0)), 29)

# %% [markdown]
# ## Sample Distribution Analysis
# Analyze the distribution of samples across different metadata categories for each log file.

# %%
import pandas as pd
from collections import defaultdict
import gc
import itertools

# Dictionary to store sample counts for each log file
sample_distributions = {}

# First pass: collect all possible values to define the complete set of combinations
all_selection_rule_types = set()
all_sample_types = set()
all_is_reversed_values = set()
all_is_physics_values = set()

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"Scanning log for possible values: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        
        for sample in temp_log.samples:
            # Extract metadata fields
            sample_type = sample.metadata.get("sample_type", "unknown")
            is_physics = sample.metadata.get("is_physics", False)
            
            # Extract question metadata
            question_meta = sample.metadata.get("question", {})
            selection_rule_type = question_meta.get("selection_rule_type", "unknown")
            is_reversed = question_meta.get("is_reversed", False)
            
            # Collect all possible values
            all_selection_rule_types.add(selection_rule_type)
            all_sample_types.add(sample_type)
            all_is_reversed_values.add(is_reversed)
            all_is_physics_values.add(is_physics)
        
        del temp_log
        gc.collect()

# Create all possible combinations
all_combinations = list(itertools.product(
    sorted(all_selection_rule_types),
    sorted(all_is_reversed_values),
    sorted(all_sample_types),
    sorted(all_is_physics_values)
))

print(f"Found {len(all_combinations)} possible combinations:")
for combo in all_combinations:
    print(f"  {combo}")

# Second pass: count actual occurrences
for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        log_key = f"fill_{fill}_related_{related_ratios[related_index]}"
        
        print(f"Analyzing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        
        # Initialize counts for all combinations with 0
        counts = {combo: 0 for combo in all_combinations}
        
        for sample in temp_log.samples:
            # Extract metadata fields
            sample_type = sample.metadata.get("sample_type", "unknown")
            is_physics = sample.metadata.get("is_physics", False)
            
            # Extract question metadata
            question_meta = sample.metadata.get("question", {})
            selection_rule_type = question_meta.get("selection_rule_type", "unknown")
            is_reversed = question_meta.get("is_reversed", False)
            
            # Create combination key
            combo_key = (selection_rule_type, is_reversed, sample_type, is_physics)
            counts[combo_key] += 1
        
        sample_distributions[log_key] = counts
        
        del temp_log
        gc.collect()

# Convert to a more readable format and display results
print("\n=== SAMPLE DISTRIBUTION ANALYSIS ===\n")

# Create a comprehensive DataFrame for analysis
all_data = []
for log_key, counts in sample_distributions.items():
    for (selection_rule_type, is_reversed, sample_type, is_physics), count in counts.items():
        all_data.append({
            'log_file': log_key,
            'selection_rule_type': selection_rule_type,
            'is_reversed': is_reversed,
            'sample_type': sample_type,
            'is_physics': is_physics,
            'count': count
        })

df = pd.DataFrame(all_data)

# Display summary by log file (including zeros)
for log_key in sorted(sample_distributions.keys()):
    print(f"\n{log_key}:")
    log_df = df[df['log_file'] == log_key]
    
    # Group by combination and sum counts
    summary = log_df.groupby(['selection_rule_type', 'is_reversed', 'sample_type', 'is_physics'])['count'].sum().reset_index()
    
    # Sort for consistent display
    summary = summary.sort_values(['selection_rule_type', 'is_reversed', 'sample_type', 'is_physics'])
    
    for _, row in summary.iterrows():
        print(f"  {row['selection_rule_type']}, reversed={row['is_reversed']}, {row['sample_type']}, physics={row['is_physics']}: {row['count']}")
    
    total_samples = summary['count'].sum()
    print(f"  Total samples: {total_samples}")

# Overall summary across all log files (including zeros)
print(f"\n=== OVERALL SUMMARY ACROSS ALL LOG FILES ===")
overall_summary = df.groupby(['selection_rule_type', 'is_reversed', 'sample_type', 'is_physics'])['count'].sum().reset_index()
overall_summary = overall_summary.sort_values(['selection_rule_type', 'is_reversed', 'sample_type', 'is_physics'])

print(f"\nCombination counts across all {len(sample_distributions)} log files:")
for _, row in overall_summary.iterrows():
    print(f"  {row['selection_rule_type']}, reversed={row['is_reversed']}, {row['sample_type']}, physics={row['is_physics']}: {row['count']}")

total_all_samples = overall_summary['count'].sum()
print(f"\nGrand total samples across all logs: {total_all_samples}")

# Create a pivot table for better visualization (including zeros)
print(f"\n=== PIVOT TABLE: Sample Type vs Selection Rule Type ===")
pivot = df.pivot_table(
    index=['selection_rule_type', 'is_reversed'], 
    columns=['sample_type', 'is_physics'], 
    values='count', 
    aggfunc='sum', 
    fill_value=0
)
print(pivot)
# Out:
# Scanning log for possible values: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# Scanning log for possible values: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.5/default/2025-10-22T19-40-30+01-00_directors-task_XZ3rtVYjPbWz5AFGrwYU4E.eval
# Scanning log for possible values: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.7/default/2025-10-23T14-55-49+01-00_directors-task_Ve2z3qo2Axj58agBL4aJ4P.eval
# Scanning log for possible values: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.9/default/2025-10-24T13-16-40+01-00_directors-task_4t2zihL9VHhtEmXErLQznK.eval
# Found 32 possible combinations:
#   ('none', False, 'control', False)
#   ('none', False, 'control', True)
#   ('none', False, 'test', False)
#   ('none', False, 'test', True)
#   ('none', True, 'control', False)
#   ('none', True, 'control', True)
#   ('none', True, 'test', False)
#   ('none', True, 'test', True)
#   ('size_related', False, 'control', False)
#   ('size_related', False, 'control', True)
#   ('size_related', False, 'test', False)
#   ('size_related', False, 'test', True)
#   ('size_related', True, 'control', False)
#   ('size_related', True, 'control', True)
#   ('size_related', True, 'test', False)
#   ('size_related', True, 'test', True)
#   ('spatial_different_perspective', False, 'control', False)
#   ('spatial_different_perspective', False, 'control', True)
#   ('spatial_different_perspective', False, 'test', False)
#   ('spatial_different_perspective', False, 'test', True)
#   ('spatial_different_perspective', True, 'control', False)
#   ('spatial_different_perspective', True, 'control', True)
#   ('spatial_different_perspective', True, 'test', False)
#   ('spatial_different_perspective', True, 'test', True)
#   ('spatial_same_perspective', False, 'control', False)
#   ('spatial_same_perspective', False, 'control', True)
#   ('spatial_same_perspective', False, 'test', False)
#   ('spatial_same_perspective', False, 'test', True)
#   ('spatial_same_perspective', True, 'control', False)
#   ('spatial_same_perspective', True, 'control', True)
#   ('spatial_same_perspective', True, 'test', False)
#   ('spatial_same_perspective', True, 'test', True)
# Analyzing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# Analyzing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.5/default/2025-10-22T19-40-30+01-00_directors-task_XZ3rtVYjPbWz5AFGrwYU4E.eval
# Analyzing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.7/default/2025-10-23T14-55-49+01-00_directors-task_Ve2z3qo2Axj58agBL4aJ4P.eval
# Analyzing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.9/default/2025-10-24T13-16-40+01-00_directors-task_4t2zihL9VHhtEmXErLQznK.eval
#
# === SAMPLE DISTRIBUTION ANALYSIS ===
#
#
# fill_0.9_related_0.3:
#   none, reversed=False, control, physics=False: 67
#   none, reversed=False, control, physics=True: 48
#   none, reversed=False, test, physics=False: 62
#   none, reversed=False, test, physics=True: 59
#   none, reversed=True, control, physics=False: 58
#   none, reversed=True, control, physics=True: 77
#   none, reversed=True, test, physics=False: 63
#   none, reversed=True, test, physics=True: 66
#   size_related, reversed=False, control, physics=False: 61
#   size_related, reversed=False, control, physics=True: 62
#   size_related, reversed=False, test, physics=False: 69
#   size_related, reversed=False, test, physics=True: 68
#   size_related, reversed=True, control, physics=False: 64
#   size_related, reversed=True, control, physics=True: 63
#   size_related, reversed=True, test, physics=False: 56
#   size_related, reversed=True, test, physics=True: 57
#   spatial_different_perspective, reversed=False, control, physics=False: 54
#   spatial_different_perspective, reversed=False, control, physics=True: 66
#   spatial_different_perspective, reversed=False, test, physics=False: 60
#   spatial_different_perspective, reversed=False, test, physics=True: 65
#   spatial_different_perspective, reversed=True, control, physics=False: 71
#   spatial_different_perspective, reversed=True, control, physics=True: 59
#   spatial_different_perspective, reversed=True, test, physics=False: 65
#   spatial_different_perspective, reversed=True, test, physics=True: 60
#   spatial_same_perspective, reversed=False, control, physics=False: 64
#   spatial_same_perspective, reversed=False, control, physics=True: 55
#   spatial_same_perspective, reversed=False, test, physics=False: 47
#   spatial_same_perspective, reversed=False, test, physics=True: 70
#   spatial_same_perspective, reversed=True, control, physics=False: 61
#   spatial_same_perspective, reversed=True, control, physics=True: 70
#   spatial_same_perspective, reversed=True, test, physics=False: 78
#   spatial_same_perspective, reversed=True, test, physics=True: 55
#   Total samples: 2000
#
# fill_0.9_related_0.5:
#   none, reversed=False, control, physics=False: 65
#   none, reversed=False, control, physics=True: 64
#   none, reversed=False, test, physics=False: 72
#   none, reversed=False, test, physics=True: 60
#   none, reversed=True, control, physics=False: 60
#   none, reversed=True, control, physics=True: 61
#   none, reversed=True, test, physics=False: 53
#   none, reversed=True, test, physics=True: 65
#   size_related, reversed=False, control, physics=False: 66
#   size_related, reversed=False, control, physics=True: 59
#   size_related, reversed=False, test, physics=False: 62
#   size_related, reversed=False, test, physics=True: 53
#   size_related, reversed=True, control, physics=False: 59
#   size_related, reversed=True, control, physics=True: 66
#   size_related, reversed=True, test, physics=False: 63
#   size_related, reversed=True, test, physics=True: 72
#   spatial_different_perspective, reversed=False, control, physics=False: 60
#   spatial_different_perspective, reversed=False, control, physics=True: 64
#   spatial_different_perspective, reversed=False, test, physics=False: 62
#   spatial_different_perspective, reversed=False, test, physics=True: 50
#   spatial_different_perspective, reversed=True, control, physics=False: 65
#   spatial_different_perspective, reversed=True, control, physics=True: 61
#   spatial_different_perspective, reversed=True, test, physics=False: 63
#   spatial_different_perspective, reversed=True, test, physics=True: 75
#   spatial_same_perspective, reversed=False, control, physics=False: 54
#   spatial_same_perspective, reversed=False, control, physics=True: 71
#   spatial_same_perspective, reversed=False, test, physics=False: 68
#   spatial_same_perspective, reversed=False, test, physics=True: 62
#   spatial_same_perspective, reversed=True, control, physics=False: 71
#   spatial_same_perspective, reversed=True, control, physics=True: 54
#   spatial_same_perspective, reversed=True, test, physics=False: 57
#   spatial_same_perspective, reversed=True, test, physics=True: 63
#   Total samples: 2000
#
# fill_0.9_related_0.7:
#   none, reversed=False, control, physics=False: 70
#   none, reversed=False, control, physics=True: 57
#   none, reversed=False, test, physics=False: 71
#   none, reversed=False, test, physics=True: 65
#   none, reversed=True, control, physics=False: 55
#   none, reversed=True, control, physics=True: 68
#   none, reversed=True, test, physics=False: 54
#   none, reversed=True, test, physics=True: 60
#   size_related, reversed=False, control, physics=False: 59
#   size_related, reversed=False, control, physics=True: 66
#   size_related, reversed=False, test, physics=False: 72
#   size_related, reversed=False, test, physics=True: 66
#   size_related, reversed=True, control, physics=False: 66
#   size_related, reversed=True, control, physics=True: 59
#   size_related, reversed=True, test, physics=False: 53
#   size_related, reversed=True, test, physics=True: 59
#   spatial_different_perspective, reversed=False, control, physics=False: 59
#   spatial_different_perspective, reversed=False, control, physics=True: 61
#   spatial_different_perspective, reversed=False, test, physics=False: 61
#   spatial_different_perspective, reversed=False, test, physics=True: 57
#   spatial_different_perspective, reversed=True, control, physics=False: 66
#   spatial_different_perspective, reversed=True, control, physics=True: 64
#   spatial_different_perspective, reversed=True, test, physics=False: 64
#   spatial_different_perspective, reversed=True, test, physics=True: 68
#   spatial_same_perspective, reversed=False, control, physics=False: 59
#   spatial_same_perspective, reversed=False, control, physics=True: 63
#   spatial_same_perspective, reversed=False, test, physics=False: 61
#   spatial_same_perspective, reversed=False, test, physics=True: 62
#   spatial_same_perspective, reversed=True, control, physics=False: 66
#   spatial_same_perspective, reversed=True, control, physics=True: 62
#   spatial_same_perspective, reversed=True, test, physics=False: 64
#   spatial_same_perspective, reversed=True, test, physics=True: 63
#   Total samples: 2000
#
# fill_0.9_related_0.9:
#   none, reversed=False, control, physics=False: 68
#   none, reversed=False, control, physics=True: 69
#   none, reversed=False, test, physics=False: 53
#   none, reversed=False, test, physics=True: 62
#   none, reversed=True, control, physics=False: 57
#   none, reversed=True, control, physics=True: 56
#   none, reversed=True, test, physics=False: 72
#   none, reversed=True, test, physics=True: 63
#   size_related, reversed=False, control, physics=False: 58
#   size_related, reversed=False, control, physics=True: 56
#   size_related, reversed=False, test, physics=False: 55
#   size_related, reversed=False, test, physics=True: 67
#   size_related, reversed=True, control, physics=False: 67
#   size_related, reversed=True, control, physics=True: 69
#   size_related, reversed=True, test, physics=False: 70
#   size_related, reversed=True, test, physics=True: 58
#   spatial_different_perspective, reversed=False, control, physics=False: 55
#   spatial_different_perspective, reversed=False, control, physics=True: 61
#   spatial_different_perspective, reversed=False, test, physics=False: 64
#   spatial_different_perspective, reversed=False, test, physics=True: 60
#   spatial_different_perspective, reversed=True, control, physics=False: 70
#   spatial_different_perspective, reversed=True, control, physics=True: 64
#   spatial_different_perspective, reversed=True, test, physics=False: 61
#   spatial_different_perspective, reversed=True, test, physics=True: 65
#   spatial_same_perspective, reversed=False, control, physics=False: 66
#   spatial_same_perspective, reversed=False, control, physics=True: 69
#   spatial_same_perspective, reversed=False, test, physics=False: 58
#   spatial_same_perspective, reversed=False, test, physics=True: 67
#   spatial_same_perspective, reversed=True, control, physics=False: 59
#   spatial_same_perspective, reversed=True, control, physics=True: 56
#   spatial_same_perspective, reversed=True, test, physics=False: 67
#   spatial_same_perspective, reversed=True, test, physics=True: 58
#   Total samples: 2000
#
# === OVERALL SUMMARY ACROSS ALL LOG FILES ===
#
# Combination counts across all 4 log files:
#   none, reversed=False, control, physics=False: 270
#   none, reversed=False, control, physics=True: 238
#   none, reversed=False, test, physics=False: 258
#   none, reversed=False, test, physics=True: 246
#   none, reversed=True, control, physics=False: 230
#   none, reversed=True, control, physics=True: 262
#   none, reversed=True, test, physics=False: 242
#   none, reversed=True, test, physics=True: 254
#   size_related, reversed=False, control, physics=False: 244
#   size_related, reversed=False, control, physics=True: 243
#   size_related, reversed=False, test, physics=False: 258
#   size_related, reversed=False, test, physics=True: 254
#   size_related, reversed=True, control, physics=False: 256
#   size_related, reversed=True, control, physics=True: 257
#   size_related, reversed=True, test, physics=False: 242
#   size_related, reversed=True, test, physics=True: 246
#   spatial_different_perspective, reversed=False, control, physics=False: 228
#   spatial_different_perspective, reversed=False, control, physics=True: 252
#   spatial_different_perspective, reversed=False, test, physics=False: 247
#   spatial_different_perspective, reversed=False, test, physics=True: 232
#   spatial_different_perspective, reversed=True, control, physics=False: 272
#   spatial_different_perspective, reversed=True, control, physics=True: 248
#   spatial_different_perspective, reversed=True, test, physics=False: 253
#   spatial_different_perspective, reversed=True, test, physics=True: 268
#   spatial_same_perspective, reversed=False, control, physics=False: 243
#   spatial_same_perspective, reversed=False, control, physics=True: 258
#   spatial_same_perspective, reversed=False, test, physics=False: 234
#   spatial_same_perspective, reversed=False, test, physics=True: 261
#   spatial_same_perspective, reversed=True, control, physics=False: 257
#   spatial_same_perspective, reversed=True, control, physics=True: 242
#   spatial_same_perspective, reversed=True, test, physics=False: 266
#   spatial_same_perspective, reversed=True, test, physics=True: 239
#
# Grand total samples across all logs: 8000
#
# === PIVOT TABLE: Sample Type vs Selection Rule Type ===
# sample_type                               control        test
# is_physics                                  False True  False True
# selection_rule_type           is_reversed
# none                          False           270   238   258   246
#                               True            230   262   242   254
# size_related                  False           244   243   258   254
#                               True            256   257   242   246
# spatial_different_perspective False           228   252   247   232
#                               True            272   248   253   268
# spatial_same_perspective      False           243   258   234   261
#                               True            257   242   266   239

# %% [markdown]
# # test errors

# %%
import gc

from inspect_ai.model import ContentText
import numpy as np





test_left_reversed_errors = []
test_left_same_errors = []
test_right_reversed_errors = []
test_right_same_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] =="test":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        if sample.metadata["question"]["selection_rule"] == "leftmost" and sample.metadata["question"]["is_reversed"]:
                            test_left_reversed_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "leftmost" and not sample.metadata["question"]["is_reversed"]:
                            test_left_same_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "rightmost" and sample.metadata["question"]["is_reversed"]:
                            test_right_reversed_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "rightmost" and not sample.metadata["question"]["is_reversed"]:
                            test_right_same_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue


        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# Error parsing coordinates for answer '3A': Invalid column letter: '3'
# Error parsing coordinates for answer 'No sharp clothes found.': Invalid row number: 'o sharp clothes found.'
# Error parsing coordinates for answer 'No black clothes found.': Invalid row number: 'o black clothes found.'
# Error parsing coordinates for answer 'No items found.': Invalid row number: 'o items found.'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.5/default/2025-10-22T19-40-30+01-00_directors-task_XZ3rtVYjPbWz5AFGrwYU4E.eval
# Error parsing coordinates for answer 'No sharp clothes present': Invalid row number: 'o sharp clothes present'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.7/default/2025-10-23T14-55-49+01-00_directors-task_Ve2z3qo2Axj58agBL4aJ4P.eval
# Error parsing coordinates for answer 'No sharp clothes found.': Invalid row number: 'o sharp clothes found.'
# Error parsing coordinates for answer 'No valid item.': Invalid row number: 'o valid item.'
# Error parsing coordinates for answer 'None': Invalid row number: 'one'
# Error parsing coordinates for answer 'There are no clothing items visible on the shelving grid.': Invalid row number: 'here are no clothing items visible on the shelving grid.'
# Error parsing coordinates for answer 'No sharp clothes found.': Invalid row number: 'o sharp clothes found.'
# Error parsing coordinates for answer 'No brown sharp shoe is present in the grid.': Invalid row number: 'o brown sharp shoe is present in the grid.'
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.9/default/2025-10-24T13-16-40+01-00_directors-task_4t2zihL9VHhtEmXErLQznK.eval

# %%
# Visualize left/right errors split by reversed/same direction
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

# Print summary statistics
print("=== LEFT/RIGHT ERROR ANALYSIS ===")
print(f"Test Left Reversed errors: {len(test_left_reversed_errors)}")
print(f"Test Left Same errors: {len(test_left_same_errors)}")
print(f"Test Right Reversed errors: {len(test_right_reversed_errors)}")
print(f"Test Right Same errors: {len(test_right_same_errors)}")

# Combine all errors to determine consistent scaling
all_left_right_errors = (test_left_reversed_errors + test_left_same_errors + 
                        test_right_reversed_errors + test_right_same_errors)

if len(all_left_right_errors) > 0:
    # Get combined range for consistent scaling
    all_x = [error[0] for error in all_left_right_errors]
    all_y = [error[1] for error in all_left_right_errors]
    
    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0
    
    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1
    
    # Create 2x2 subplot for the four categories
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    
    # Function to create individual heatmap
    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center', 
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None
        
        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))
        
        # Fill in the heatmap data
        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count
        
        return heatmap_data, error_counter
    
    # Create heatmaps for each category
    categories = [
        (test_left_reversed_errors, ax1, "Left Reversed 'rightmost x from my perspective'", "Reds"),
        (test_left_same_errors, ax2, "Left Same'leftmost x from your perspective'", "Blues"),
        (test_right_reversed_errors, ax3, "Right Reversed 'leftmost x from my perspective'", "Greens"),
        (test_right_same_errors, ax4, "Right Same 'rightmost x from your perspective'", "Purples")
    ]
    
    # Collect all non-zero data to determine global color scale
    all_heatmaps = []
    all_counters = []
    
    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)
    
    # Find global min/max for consistent color scaling
    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)
    
    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)
        
        # Create the actual heatmaps with consistent scaling
        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                # Create heatmap with log scale
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)
                
                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)
                
                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (Δx)', fontsize=14)
                ax.set_ylabel('Row Error (Δy)', fontsize=14)
                ax.tick_params(labelsize=10)
                
                # Add marker for perfect match
                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150, 
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)
    
    plt.suptitle('GPT-4o-mini Test Sample Errors: Left/Right Questions by perspective', 
                 fontsize=14, y=0.98)
    plt.tight_layout()
    plt.show()
    
    # Print detailed statistics
    print("\n=== DETAILED STATISTICS ===")
    
    category_names = ["Left Reversed 'rightmost x from my perspective'", "Left Same'leftmost x from your perspective'", "Right Reversed 'leftmost x from my perspective'", "Right Same 'rightmost x from your perspective'"]
    error_lists = [test_left_reversed_errors, test_left_same_errors, 
                   test_right_reversed_errors, test_right_same_errors]
    
    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])
            
            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")
            
            if len(errors) > 0:
                counter = Counter(tuple(error) for error in errors)
                print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")
    
else:
    print("No left/right errors found to visualize.")
# Out:
# === LEFT/RIGHT ERROR ANALYSIS ===
# Test Left Reversed errors: 248
# Test Left Same errors: 207
# Test Right Reversed errors: 259
# Test Right Same errors: 202
# === DETAILED STATISTICS ===
#
# Left Reversed 'rightmost x from my perspective':
#   Count: 248
#   Mean error: (+1.88, +0.46)
#   Std error: (0.90, 1.63)
#   Most common: ((np.int64(2), np.int64(0)), 35)
#
# Left Same'leftmost x from your perspective':
#   Count: 207
#   Mean error: (-0.73, -0.77)
#   Std error: (0.92, 1.49)
#   Most common: ((np.int64(0), np.int64(-1)), 31)
#
# Right Reversed 'leftmost x from my perspective':
#   Count: 259
#   Mean error: (-1.90, -0.72)
#   Std error: (0.91, 1.45)
#   Most common: ((np.int64(-2), np.int64(0)), 33)
#
# Right Same 'rightmost x from your perspective':
#   Count: 202
#   Mean error: (+0.62, +0.88)
#   Std error: (0.91, 1.61)
#   Most common: ((np.int64(1), np.int64(0)), 29)

# %% [markdown]
# ## Test Top/Bottom Error Collection

# %%
import gc
import numpy as np
from inspect_ai.model import ContentText

test_top_reversed_errors = []
test_top_same_errors = []
test_bottom_reversed_errors = []
test_bottom_same_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] == "test":
                assert sample.score is not None
                if sample.score.value != "C":
                    if not isinstance(sample.output.message.content, str):
                        answer = None
                        for output in sample.output.message.content:
                            if isinstance(output, str):
                                answer = output.strip()
                            elif isinstance(output, ContentText):
                                answer = output.text.strip()
                            else:
                                continue
                        if answer is None:
                            print(f"Warning: No valid string found in output content: {sample.output.message.content}")
                            continue
                    else:
                        answer = sample.output.message.content.strip()
                    try:
                        answer_coord = parse_coordinate_string(answer)
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        target_coord = target_coords[0]
                        difference = np.array(answer_coord) - np.array(target_coord)

                        selection_rule = sample.metadata["question"]["selection_rule"]
                        is_reversed = sample.metadata["question"]["is_reversed"]

                        if selection_rule == "topmost" and is_reversed:
                            test_top_reversed_errors.append(difference)
                        elif selection_rule == "topmost" and not is_reversed:
                            test_top_same_errors.append(difference)
                        elif selection_rule == "bottommost" and is_reversed:
                            test_bottom_reversed_errors.append(difference)
                        elif selection_rule == "bottommost" and not is_reversed:
                            test_bottom_same_errors.append(difference)

                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue

        del temp_log
        gc.collect()

print(f"Test Top Reversed errors: {len(test_top_reversed_errors)}")
print(f"Test Top Same errors: {len(test_top_same_errors)}")
print(f"Test Bottom Reversed errors: {len(test_bottom_reversed_errors)}")
print(f"Test Bottom Same errors: {len(test_bottom_same_errors)}")
# Out:
# processing log: ../logs/gpt-4o-mini/sweep_2025-10-22_11-11_openai_azure_gpt-4o-mini/fill_ratio_0.9/related_ratio_0.3/default/2025-10-22T11-11-39+01-00_directors-task_KoSDvZ9MxfEb7TqDbFsVTb.eval
# Error parsing coordinates for answer 'To find the correct cell containing the stackable book from your point of view (which would be from the back of the grid), I will identify which grid cells show books.
#
# Looking at the image:
# - Row 1, Column A has a book.
# - Row 2, Column C has a book.
# - Row 3, Column C has a book.
#
# From your perspective, the relevant cells would be:
# - A1 (Row 1, Column A)
# - C2 (Row 2, Column C)
# - C3 (Row 3, Column C)
#
# Since I'm looking for one specific book, I will choose cell A1 because it is the first row and it's from the leftmost column.
#
# Thus, I will submit my answer as "A1."': Invalid row number: 'o find the correct cell containing the stackable book from your point of view (which would be from the back of the grid), I will identify which grid cells show books.
#
# Looking at the image:
# - Row 1, Column A has a book.
# - Row 2, Column C has a book.
# - Row 3, Column C has a book.
#
# From your perspective, the relevant cells would be:
# - A1 (Row 1, Column A)
# - C2 (Row 2, Column C)
# - C3 (Row 3, Column C)
#
# Since I'm looking for one specific book, I will choose cell A1 because it is the first row and it's from the leftmost column.
#
# Thus, I will submit my answer as "A1."'
# Error parsing coordinates for answer 'To find the topmost sharp clothes from my point of view, I need to look for items related to clothing or accessories that may seem "sharp" (like skates or sharp-edged clothing).
#
# In the image:
# - Row 1, Column D (D1) has a pair of ice skates which might be considered sharp due to their blades.
# - Row 2 and Row 3 do not appear to contain clothing-related items with sharp characteristics.
# - In Row 4, I see another pair of ice skates in Column C (C4).
#
# The topmost sharp clothes (the ice skates) I identify is in D1.
#
# Now I will submit my answer.': Invalid row number: 'o find the topmost sharp clothes from my point of view, I need to look for items related to clothing or accessories that may seem "sharp" (like skates or sharp-edged clothing).
#
# In the image:
# - Row 1, Column D (D1) has a pair of ice skates which might be considered sharp due to their blades.
# - Row 2 and Row 3 do not appear to contain clothing-related items with sharp characteristics.
# - In Row 4, I see another pair of ice skates in Column C (C4).
#
# The topmost sharp clothes (the ice skates) I identify is in D1.
#
# Now I will submit my answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'In the grid provided, I need to identify the topmost car from your point of view.
#
# From the image, I can see that there are cars located in the grid cells. The user is viewing the grid from behind, and it appears that the cars are located at the following positions:
#
# - D1 (topmost row)
# - D4 (bottom-most row)
#
# Since we are looking for the topmost car, the correct grid cell would be D1.
#
# Now, I will submit the answer.': Invalid row number: 'n the grid provided, I need to identify the topmost car from your point of view.
#
# From the image, I can see that there are cars located in the grid cells. The user is viewing the grid from behind, and it appears that the cars are located at the following positions:
#
# - D1 (topmost row)
# - D4 (bottom-most row)
#
# Since we are looking for the topmost car, the correct grid cell would be D1.
#
# Now, I will submit the answer.'
# Error parsing coordinates for answer 'To find the smallest stackable book from the user's perspective, I need to evaluate the grid to determine which items are present. The grid contains multiple cells, some of which hold books.
#
# From the image, I observed:
# - In row 1, there is a book located in column B and a second book in column D.
# - In row 2, there is also a book in column C.
# - In row 4, there is another book in column D.
#
# From what I see, the books appear to be located in:
# - B1
# - C2
# - D1
# - D4
#
# To identify the smallest stackable book, it would make sense to compare the visible sizes of the books. Typically, on such grids, books that appear to be thinner or flatter are those that can be considered "small".
#
# Since the specific visual representation of sizes in the image may not be clear, I'll need to select based on what seems to be the most likely candidate for the smallest book.
#
# The most probable smallest book appears to be in cell D4 (since it appears the flattest in comparison).
#
# Let's proceed with this as my selection.
#
# I'll submit the answer as "D4".': Invalid row number: 'o find the smallest stackable book from the user's perspective, I need to evaluate the grid to determine which items are present. The grid contains multiple cells, some of which hold books.
#
# From the image, I observed:
# - In row 1, there is a book located in column B and a second book in column D.
# - In row 2, there is also a book in column C.
# - In row 4, there is another book in column D.
#
# From what I see, the books appear to be located in:
# - B1
# - C2
# - D1
# - D4
#
# To identify the smallest stackable book, it would make sense to compare the visible sizes of the books. Typically, on such grids, books that appear to be thinner or flatter are those that can be considered "small".
#
# Since the specific visual representation of sizes in the image may not be clear, I'll need to select based on what seems to be the most likely candidate for the smallest book.
#
# The most probable smallest book appears to be in cell D4 (since it appears the flattest in comparison).
#
# Let's proceed with this as my selection.
#
# I'll submit the answer as "D4".'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To locate the plant from my point of view, I observe the grid. The items displayed include several sunflowers located in different cells.
#
# From my perspective:
# - Row 1: A1, B1, and C1 each contain sunflowers.
# - Row 2: A2 contains a sunflower.
# - Row 4: A4 and D4 contain a sunflower.
#
# The specific items I'm identifying as plants are all sunflowers. Since I'm looking for the plant, the one that I can see clearly is in cell A1.
#
# I will proceed to submit "A1" as the answer.': Invalid row number: 'o locate the plant from my point of view, I observe the grid. The items displayed include several sunflowers located in different cells.
#
# From my perspective:
# - Row 1: A1, B1, and C1 each contain sunflowers.
# - Row 2: A2 contains a sunflower.
# - Row 4: A4 and D4 contain a sunflower.
#
# The specific items I'm identifying as plants are all sunflowers. Since I'm looking for the plant, the one that I can see clearly is in cell A1.
#
# I will proceed to submit "A1" as the answer.'
# Error parsing coordinates for answer 'To select the topmost sharp shoe from your perspective, I need to identify the shoes present in the grid and determine which one is on the topmost row.
#
# Looking at the grid:
#
# - Row 3: There are two pairs of ice skates.
# - Row 4: This row does not contain any shoes.
#
# From my point of view, the two pairs of ice skates (which are sharp shoes) are located in column C and D of row 3. Since these are the only shoes present, the topmost (and only) pair of shoes visible from your point of view is in the 3rd row.
#
# Now, I will select the first (leftmost) sharp shoe in row 3, which is in column C.
#
# The answer will be `C3`.
#
# I will go ahead and submit this answer.': Invalid row number: 'o select the topmost sharp shoe from your perspective, I need to identify the shoes present in the grid and determine which one is on the topmost row.
#
# Looking at the grid:
#
# - Row 3: There are two pairs of ice skates.
# - Row 4: This row does not contain any shoes.
#
# From my point of view, the two pairs of ice skates (which are sharp shoes) are located in column C and D of row 3. Since these are the only shoes present, the topmost (and only) pair of shoes visible from your point of view is in the 3rd row.
#
# Now, I will select the first (leftmost) sharp shoe in row 3, which is in column C.
#
# The answer will be `C3`.
#
# I will go ahead and submit this answer.'
# Error parsing coordinates for answer 'To find the leftmost sharp shoe (roller skate) from the user's point of view, I need to analyze the image carefully.
#
# Looking at the grid:
# - Row 1, Column A has a skate,
# - Row 2, Column B has a skate,
# - Row 2, Column D has a skate.
#
# From the user's perspective, the leftmost skate is in position A1.
#
# Now, I will submit this answer. The answer will be formatted as `A1`.
#
# I will proceed to submit.': Invalid row number: 'o find the leftmost sharp shoe (roller skate) from the user's point of view, I need to analyze the image carefully.
#
# Looking at the grid:
# - Row 1, Column A has a skate,
# - Row 2, Column B has a skate,
# - Row 2, Column D has a skate.
#
# From the user's perspective, the leftmost skate is in position A1.
#
# Now, I will submit this answer. The answer will be formatted as `A1`.
#
# I will proceed to submit.'
# Error parsing coordinates for answer 'To identify the largest stackable book from my point of view, I'll examine the items displayed and check for book icons in the grid.
#
# From my view, there are three book icons visible:
# - In cell C1
# - In cell D1
# - In cell D3
#
# Now, I will determine which of these book icons is the largest. The grid is designed for me to see from the back, so the items positioned on the top row (1) would appear first and might be more significant than those on the lower rows.
#
# Looking at the grid:
# - Cells C1 and D1 appear to have a blue book icon, while cell D3 shows a stack of two books. However, from the layout, D3 is visually less prominent.
#
# Upon analysis, it looks like both C1 and D1 have equal size, but since they are on the same row, they are likely the same, and D3 seems to have lesser prominence due to its position (3).
#
# For optimal selection, I would go with the first stack of blue books I see:
#
# I will select D1 for submission.
#
# Now, I will proceed to submit this answer.': Invalid row number: 'o identify the largest stackable book from my point of view, I'll examine the items displayed and check for book icons in the grid.
#
# From my view, there are three book icons visible:
# - In cell C1
# - In cell D1
# - In cell D3
#
# Now, I will determine which of these book icons is the largest. The grid is designed for me to see from the back, so the items positioned on the top row (1) would appear first and might be more significant than those on the lower rows.
#
# Looking at the grid:
# - Cells C1 and D1 appear to have a blue book icon, while cell D3 shows a stack of two books. However, from the layout, D3 is visually less prominent.
#
# Upon analysis, it looks like both C1 and D1 have equal size, but since they are on the same row, they are likely the same, and D3 seems to have lesser prominence due to its position (3).
#
# For optimal selection, I would go with the first stack of blue books I see:
#
# I will select D1 for submission.
#
# Now, I will proceed to submit this answer.'
# Error parsing coordinates for answer 'To locate the bottommost clothes from the user's point of view, I will analyze the grid structure. I see that there are several clothes depicted:
#
# 1. In row 2, there is a shirt (B2)
# 2. In row 3, there is a blue shirt (C3) and a pair of colorful socks (B3).
# 3. Row 4 does not contain any clothes but features items like a knife and a blue dot.
#
# Since we're looking for the bottommost clothes, I can see that the blue shirt (C3) in row 3 is the last visible clothing item.
#
# From the user's point of view, making the selection involves identifying the grid cell corresponding to the blue shirt in row 3 of column C.
#
# Thus, the final answer to submit is **C3**. I'll proceed to perform this action.': Invalid row number: 'o locate the bottommost clothes from the user's point of view, I will analyze the grid structure. I see that there are several clothes depicted:
#
# 1. In row 2, there is a shirt (B2)
# 2. In row 3, there is a blue shirt (C3) and a pair of colorful socks (B3).
# 3. Row 4 does not contain any clothes but features items like a knife and a blue dot.
#
# Since we're looking for the bottommost clothes, I can see that the blue shirt (C3) in row 3 is the last visible clothing item.
#
# From the user's point of view, making the selection involves identifying the grid cell corresponding to the blue shirt in row 3 of column C.
#
# Thus, the final answer to submit is **C3**. I'll proceed to perform this action.'
# Error parsing coordinates for answer 'To identify the topmost dress from the user's point of view while standing behind the shelving grid, I will analyze the grid layout.
#
# From the grid:
# - Row 1 contains a dress in column B.
# - Row 2 also has a dress in column A, column B, and column D.
#
# Since the user is looking from behind the grid, row numbers increment downwards (1 at the top, 4 at the bottom). Therefore, the topmost dress visible to them will be in the first row (Row 1).
#
# The dress is located in Column B of Row 1; hence, from the user’s perspective, the coordinates of the topmost dress are B1.
#
# I will now submit B1 as the final answer.': Invalid row number: 'o identify the topmost dress from the user's point of view while standing behind the shelving grid, I will analyze the grid layout.
#
# From the grid:
# - Row 1 contains a dress in column B.
# - Row 2 also has a dress in column A, column B, and column D.
#
# Since the user is looking from behind the grid, row numbers increment downwards (1 at the top, 4 at the bottom). Therefore, the topmost dress visible to them will be in the first row (Row 1).
#
# The dress is located in Column B of Row 1; hence, from the user’s perspective, the coordinates of the topmost dress are B1.
#
# I will now submit B1 as the final answer.'
# Error parsing coordinates for answer 'To find the leftmost sharp shoe from your point of view, I need to locate the sharp shoes in the grid and identify which one is the furthest left.
#
# In the current grid layout:
# - Row 2, Column A contains a sharp shoe.
# - Row 3 contains two sharp shoes located in Columns C and D.
#
# As I look at the grid from your perspective, the leftmost sharp shoe is in Row 2, Column A.
#
# Therefore, I will submit the answer as "A2".': Invalid row number: 'o find the leftmost sharp shoe from your point of view, I need to locate the sharp shoes in the grid and identify which one is the furthest left.
#
# In the current grid layout:
# - Row 2, Column A contains a sharp shoe.
# - Row 3 contains two sharp shoes located in Columns C and D.
#
# As I look at the grid from your perspective, the leftmost sharp shoe is in Row 2, Column A.
#
# Therefore, I will submit the answer as "A2".'
# Error parsing coordinates for answer 'To locate the topmost music instrument from your point of view, I will review the grid and identify the musical items.
#
# Looking at the grid:
#
# - Row 1 has a saxophone (A1).
# - Row 1 also contains two trumpets (D1 and C1), which are music instruments.
#
# Since the user is looking for the topmost music instrument, the saxophone (A1) is the highest in the grid layout.
#
# I will submit "A1" as my answer, as that is the topmost music instrument from your perspective.
#
# Now, I will proceed to submit my answer.': Invalid row number: 'o locate the topmost music instrument from your point of view, I will review the grid and identify the musical items.
#
# Looking at the grid:
#
# - Row 1 has a saxophone (A1).
# - Row 1 also contains two trumpets (D1 and C1), which are music instruments.
#
# Since the user is looking for the topmost music instrument, the saxophone (A1) is the highest in the grid layout.
#
# I will submit "A1" as my answer, as that is the topmost music instrument from your perspective.
#
# Now, I will proceed to submit my answer.'
# Error parsing coordinates for answer 'To find the largest stackable book from your point of view, I need to carefully look at the grid and identify the cells that contain books.
#
# In the grid, I can see there are several blue books located in the following positions:
# - B2
# - C2
# - C3
#
# Since "largest" likely refers to which book is physically the biggest based on the image provided, I will examine the dimensions of these books.
#
# Now, I observe that the books in grid cells B2 and C3 are stacked, whereas C2 contains a standing book that looks larger than the one in C3. Therefore, C2 appears to be the largest book in terms of height and overall size.
#
# Given this reasoning, I will select 'C2' as my answer.
#
# Now, I will submit my answer.': Invalid row number: 'o find the largest stackable book from your point of view, I need to carefully look at the grid and identify the cells that contain books.
#
# In the grid, I can see there are several blue books located in the following positions:
# - B2
# - C2
# - C3
#
# Since "largest" likely refers to which book is physically the biggest based on the image provided, I will examine the dimensions of these books.
#
# Now, I observe that the books in grid cells B2 and C3 are stacked, whereas C2 contains a standing book that looks larger than the one in C3. Therefore, C2 appears to be the largest book in terms of height and overall size.
#
# Given this reasoning, I will select 'C2' as my answer.
#
# Now, I will submit my answer.'
# Error parsing coordinates for answer 'To find the leftmost fruit from the user's point of view (viewing from the back of the grid), I will analyze the grid contents as follows:
#
# 1. The user is viewing the grid from the back, meaning the top row corresponds to row 1, and the leftmost column corresponds to column A.
# 2. I need to locate all the fruits present in the grid.
# 3. Observing the grid from the back, I'm looking for the first fruit item in terms of columns for each row.
#
# After analyzing the grid:
#
# - Row 1 has a violin and two oranges (B1 and C1) but the leftmost item is the violin (not a fruit).
# - Row 2 has an apple in column B (B2) and an orange in column D (D2).
# - Row 3 has no fruits as it contains fries and an orange in column C (C3).
# - Row 4 has no fruits.
#
# The only fruits identified are in Row 1 (C1: orange), Row 2 (B2: apple, D2: orange), and so on. The leftmost fruit is in Row 2, Column B.
#
# Thus, the coordinates of the leftmost fruit from the user’s perspective is B2.
#
# Now, I will submit this answer.': Invalid row number: 'o find the leftmost fruit from the user's point of view (viewing from the back of the grid), I will analyze the grid contents as follows:
#
# 1. The user is viewing the grid from the back, meaning the top row corresponds to row 1, and the leftmost column corresponds to column A.
# 2. I need to locate all the fruits present in the grid.
# 3. Observing the grid from the back, I'm looking for the first fruit item in terms of columns for each row.
#
# After analyzing the grid:
#
# - Row 1 has a violin and two oranges (B1 and C1) but the leftmost item is the violin (not a fruit).
# - Row 2 has an apple in column B (B2) and an orange in column D (D2).
# - Row 3 has no fruits as it contains fries and an orange in column C (C3).
# - Row 4 has no fruits.
#
# The only fruits identified are in Row 1 (C1: orange), Row 2 (B2: apple, D2: orange), and so on. The leftmost fruit is in Row 2, Column B.
#
# Thus, the coordinates of the leftmost fruit from the user’s perspective is B2.
#
# Now, I will submit this answer.'
# Error parsing coordinates for answer 'To find the sharp shoe, I will look for the item that resembles a shoe and is potentially sharp, which usually implies it might be a type of skate.
#
# From the image, I can see several ice skates in different cells. The ice skates are identified in the following grid cells:
#
# - A2
# - C2
# - A4
#
# Given my position and viewing angle, I need to determine the appropriate cell that contains a "sharp shoe."
#
# The skates in rows 2 and 4 (A2 and A4) are visible. The one in row 2 (A2) appears closer to the front with more likely sharp features resembling the skate blade.
#
# Thus, the sharp shoe is located at A2.
#
# I will now submit this answer.': Invalid row number: 'o find the sharp shoe, I will look for the item that resembles a shoe and is potentially sharp, which usually implies it might be a type of skate.
#
# From the image, I can see several ice skates in different cells. The ice skates are identified in the following grid cells:
#
# - A2
# - C2
# - A4
#
# Given my position and viewing angle, I need to determine the appropriate cell that contains a "sharp shoe."
#
# The skates in rows 2 and 4 (A2 and A4) are visible. The one in row 2 (A2) appears closer to the front with more likely sharp features resembling the skate blade.
#
# Thus, the sharp shoe is located at A2.
#
# I will now submit this answer.'
# Error parsing coordinates for answer 'To identify the leftmost fruit from the user's point of view, I will look at the grid and determine which grid cell contains a fruit item (in this case, blueberries).
#
# From our perspective:
# - Column A, Row 1 has blueberries.
# - Column A, Row 2 has blueberries.
#
# We want to find the leftmost item containing fruit. Since "leftmost" implies the furthest left column, and I have blueberries in both Row 1 and Row 2 in Column A, I will select the cell in Row 1 since it is on top.
#
# The coordinates of the leftmost fruit cell from the user's perspective would be A1.
#
# Now, I will submit this answer.': Invalid row number: 'o identify the leftmost fruit from the user's point of view, I will look at the grid and determine which grid cell contains a fruit item (in this case, blueberries).
#
# From our perspective:
# - Column A, Row 1 has blueberries.
# - Column A, Row 2 has blueberries.
#
# We want to find the leftmost item containing fruit. Since "leftmost" implies the furthest left column, and I have blueberries in both Row 1 and Row 2 in Column A, I will select the cell in Row 1 since it is on top.
#
# The coordinates of the leftmost fruit cell from the user's perspective would be A1.
#
# Now, I will submit this answer.'
# Error parsing coordinates for answer 'To find the bottommost sharp shoe from your point of view, I will analyze the shelving grid.
#
# From your perspective (the back of the grid):
# - Row 4 contains items.
# - The sharp shoes are located in column A and column C in row 4.
#
# To determine the bottommost shoe, I see that Row 4 is the lowest row available on the shelf. The sharp shoes in this row are positioned in:
# - A4: A sharp shoe in A column.
# - C4: Another sharp shoe in C column.
#
# Since both sharp shoes are in the bottommost row, it will be necessary to select one. As per your instruction for the "bottommost sharp shoe," I will select the one on the leftmost side, which is located at A4.
#
# Now I will submit the answer.': Invalid row number: 'o find the bottommost sharp shoe from your point of view, I will analyze the shelving grid.
#
# From your perspective (the back of the grid):
# - Row 4 contains items.
# - The sharp shoes are located in column A and column C in row 4.
#
# To determine the bottommost shoe, I see that Row 4 is the lowest row available on the shelf. The sharp shoes in this row are positioned in:
# - A4: A sharp shoe in A column.
# - C4: Another sharp shoe in C column.
#
# Since both sharp shoes are in the bottommost row, it will be necessary to select one. As per your instruction for the "bottommost sharp shoe," I will select the one on the leftmost side, which is located at A4.
#
# Now I will submit the answer.'
# Error parsing coordinates for answer 'To find the rightmost sharp plant from my point of view, I need to look at the grid and identify which cells contain sharp plants.
#
# From the visual information provided:
# - The sharp plants (cacti) are located in three grid cells:
#   1. B1
#   2. C3
#   3. D3
#
# I need to find which of these is the rightmost (furthest to the right). The potential cells are:
# - B1 has a cactus
# - C3 has a cactus
# - D3 has a cactus
#
# The rightmost cactus will be in D3.
#
# Now, I will submit the answer as "D3".': Invalid row number: 'o find the rightmost sharp plant from my point of view, I need to look at the grid and identify which cells contain sharp plants.
#
# From the visual information provided:
# - The sharp plants (cacti) are located in three grid cells:
#   1. B1
#   2. C3
#   3. D3
#
# I need to find which of these is the rightmost (furthest to the right). The potential cells are:
# - B1 has a cactus
# - C3 has a cactus
# - D3 has a cactus
#
# The rightmost cactus will be in D3.
#
# Now, I will submit the answer as "D3".'
# Error parsing coordinates for answer 'To find the bottommost stackable book from your perspective, I need to determine the grid cell coordinates for the books in the bottom rowof the grid. The grid is organized as follows from your point of view:
#
# - Row 1: A1, B1, C1, D1
# - Row 2: A2, B2, C2, D2
# - Row 3: A3, B3, C3, D3
# - Row 4: A4, B4, C4, D4
#
# From the image, I can see:
#
# - A4 (Grapes)
# - B4 (Car)
# - C4 (BOOK)
# - D4 (BOOK)
#
# The bottommost stackable books are located at C4 and D4. Since I need the coordinates for the bottommost one, the answer is C4.
#
# Now, I will submit my answer.': Invalid row number: 'o find the bottommost stackable book from your perspective, I need to determine the grid cell coordinates for the books in the bottom rowof the grid. The grid is organized as follows from your point of view:
#
# - Row 1: A1, B1, C1, D1
# - Row 2: A2, B2, C2, D2
# - Row 3: A3, B3, C3, D3
# - Row 4: A4, B4, C4, D4
#
# From the image, I can see:
#
# - A4 (Grapes)
# - B4 (Car)
# - C4 (BOOK)
# - D4 (BOOK)
#
# The bottommost stackable books are located at C4 and D4. Since I need the coordinates for the bottommost one, the answer is C4.
#
# Now, I will submit my answer.'
# Error parsing coordinates for answer 'From my point of view, the grid has several items, including two cars in positions B2 and C2. To identify the smallest car, I can analyze the grid cells visually.
#
# - Cell B2 contains a small blue toy car.
# - Cell C2 contains a larger car depicted in an actual vehicle design.
#
# Based on their appearances, the smaller car is in cell B2.
#
# Therefore, I will select cell B2. Now, I will submit my answer.': Invalid row number: 'rom my point of view, the grid has several items, including two cars in positions B2 and C2. To identify the smallest car, I can analyze the grid cells visually.
#
# - Cell B2 contains a small blue toy car.
# - Cell C2 contains a larger car depicted in an actual vehicle design.
#
# Based on their appearances, the smaller car is in cell B2.
#
# Therefore, I will select cell B2. Now, I will submit my answer.'
# Error parsing coordinates for answer 'To find the leftmost fruit from the user's point of view, I need to analyze the grid. The user's perspective is from the back of the grid.
#
# Looking at the grid:
# - In row 1, there are grapes in column A and D.
# - In row 2, grapes are present again in column B.
# - In rows 3 and 4, no fruits are present.
#
# From the grid provided, the leftmost fruit (grapes) are located in cell A1 from the viewer's perspective.
#
# I am going to submit 'A1' as the answer.': Invalid row number: 'o find the leftmost fruit from the user's point of view, I need to analyze the grid. The user's perspective is from the back of the grid.
#
# Looking at the grid:
# - In row 1, there are grapes in column A and D.
# - In row 2, grapes are present again in column B.
# - In rows 3 and 4, no fruits are present.
#
# From the grid provided, the leftmost fruit (grapes) are located in cell A1 from the viewer's perspective.
#
# I am going to submit 'A1' as the answer.'
# Error parsing coordinates for answer 'To find the rightmost fruit from the user's point of view, we first need to identify which items in the grid are fruits.
#
# From the image:
#
# - The items in the grid are:
#   - A1: Grapes
#   - A2: Blueberries
#   - A3: Blueberries
#   - C2: Apple
#
# Among these items, the grapes (A1), blueberries (A2, A3), and apple (C2) are considered fruits. Now, to determine which one is the rightmost fruit:
#
# 1. The grapes (A1) are in the leftmost column.
# 2. The blueberries (A2, A3) are also in the leftmost column (A), but located in rows 2 and 3.
# 3. The apple (C2) is in the second column.
#
# The apple (C2) is the rightmost of all the fruits.
#
# Thus, I will submit the answer "C2".': Invalid row number: 'o find the rightmost fruit from the user's point of view, we first need to identify which items in the grid are fruits.
#
# From the image:
#
# - The items in the grid are:
#   - A1: Grapes
#   - A2: Blueberries
#   - A3: Blueberries
#   - C2: Apple
#
# Among these items, the grapes (A1), blueberries (A2, A3), and apple (C2) are considered fruits. Now, to determine which one is the rightmost fruit:
#
# 1. The grapes (A1) are in the leftmost column.
# 2. The blueberries (A2, A3) are also in the leftmost column (A), but located in rows 2 and 3.
# 3. The apple (C2) is in the second column.
#
# The apple (C2) is the rightmost of all the fruits.
#
# Thus, I will submit the answer "C2".'
# Error parsing coordinates for answer 'To find the smallest stackable book from the user's point of view, I will first identify the grid cells that contain books and then determine which one is the smallest.
#
# From the image, we see:
#
# - A1 contains a book (hidden).
# - B2 contains a book titled "BOOK".
# - C3 contains another book (hidden).
# - D4 contains another book (hidden).
#
# Since the user sees the grid from the back, I’ll denote the books present in **A1**, **B2**, **C3**, and **D4**.
#
# Now, I will assess the visible sizes of the books. Typically, the book in **B2** is likely to be the largest as it is opened and well-structured compared to the other books that are stacked or partially obscured.
#
# The two stackable books seem to be in **A1** and **D4** since they appear more like traditional stackable books.
#
# Considering all this, **D4** would likely hold the smallest book as compared to **A1** and **C3**, which seem to be larger or are differently shaped.
#
# Based on this reasoning, I’ll select **D4** as the correct answer for the smallest stackable book.
#
# Now, I will submit my answer.
#
# The coordinates based on the grid are 'D4'.': Invalid row number: 'o find the smallest stackable book from the user's point of view, I will first identify the grid cells that contain books and then determine which one is the smallest.
#
# From the image, we see:
#
# - A1 contains a book (hidden).
# - B2 contains a book titled "BOOK".
# - C3 contains another book (hidden).
# - D4 contains another book (hidden).
#
# Since the user sees the grid from the back, I’ll denote the books present in **A1**, **B2**, **C3**, and **D4**.
#
# Now, I will assess the visible sizes of the books. Typically, the book in **B2** is likely to be the largest as it is opened and well-structured compared to the other books that are stacked or partially obscured.
#
# The two stackable books seem to be in **A1** and **D4** since they appear more like traditional stackable books.
#
# Considering all this, **D4** would likely hold the smallest book as compared to **A1** and **C3**, which seem to be larger or are differently shaped.
#
# Based on this reasoning, I’ll select **D4** as the correct answer for the smallest stackable book.
#
# Now, I will submit my answer.
#
# The coordinates based on the grid are 'D4'.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To determine the location of the smallest stackable book from my point of view at the back of the grid, I will inspect each grid cell.
#
# The grid layout is as follows:
#
# - **Row 1:** A1 (skates), B1 (apple), C1 (book), D1 (book)
# - **Row 2:** A2 (sunflower), B2 (book), C2 (empty), D2 (car)
# - **Row 3:** A3 (skates), B3 (empty), C3 (empty), D3 (trumpet)
# - **Row 4:** A4 (shoes), B4 (empty), C4 (book), D4 (empty)
#
# The smallest stackable book appears to be in the following cells:
# - C1
# - B2
# - C4
#
# Given the information that there are multiple books, I'll assume C1 or C4 could potentially be smaller based on positioning, as they are in a more visible spot from the user's perspective.
#
# Since I can’t ascertain from the image which specific book is smaller without seeing them directly, I would logically choose one of the centrally located cells with a book that might not be obscured by any other items.
#
# I'll select **C1** as it is visible without other items immediately beside it in that row which could reduce its perceived size.
#
# Now, I will submit the answer: **C1**.': Invalid row number: 'o determine the location of the smallest stackable book from my point of view at the back of the grid, I will inspect each grid cell.
#
# The grid layout is as follows:
#
# - **Row 1:** A1 (skates), B1 (apple), C1 (book), D1 (book)
# - **Row 2:** A2 (sunflower), B2 (book), C2 (empty), D2 (car)
# - **Row 3:** A3 (skates), B3 (empty), C3 (empty), D3 (trumpet)
# - **Row 4:** A4 (shoes), B4 (empty), C4 (book), D4 (empty)
#
# The smallest stackable book appears to be in the following cells:
# - C1
# - B2
# - C4
#
# Given the information that there are multiple books, I'll assume C1 or C4 could potentially be smaller based on positioning, as they are in a more visible spot from the user's perspective.
#
# Since I can’t ascertain from the image which specific book is smaller without seeing them directly, I would logically choose one of the centrally located cells with a book that might not be obscured by any other items.
#
# I'll select **C1** as it is visible without other items immediately beside it in that row which could reduce its perceived size.
#
# Now, I will submit the answer: **C1**.'
# Error parsing coordinates for answer 'To find the bottommost sharp shoe from the user's perspective (who is looking from the back of the grid), we need to locate all instances of shoes in the grid.
#
# From the image:
# - In row 2, there is a sharp shoe in column B.
# - In row 3, there is another sharp shoe in column D.
#
# The bottommost sharp shoe is the one in row 3, column D.
#
# Now, I will submit the answer 'D3' as the coordinates for the bottommost sharp shoe.': Invalid row number: 'o find the bottommost sharp shoe from the user's perspective (who is looking from the back of the grid), we need to locate all instances of shoes in the grid.
#
# From the image:
# - In row 2, there is a sharp shoe in column B.
# - In row 3, there is another sharp shoe in column D.
#
# The bottommost sharp shoe is the one in row 3, column D.
#
# Now, I will submit the answer 'D3' as the coordinates for the bottommost sharp shoe.'
# Error parsing coordinates for answer 'To find the topmost sharp shoe from my point of view, I need to examine the grid carefully.
#
# In the top row (row 1), there are no shoes visible. In the second row (row 2), one of the items appears to be a sharp shoe, but there are no shoes there either.
#
# Upon checking the third row (row 3), I see some items but not shoes.
#
# The only visible sharp shoes are located on row 2, column C. Therefore, the topmost sharp shoes must be in that position.
#
# Now, I will submit the answer as C2.': Invalid row number: 'o find the topmost sharp shoe from my point of view, I need to examine the grid carefully.
#
# In the top row (row 1), there are no shoes visible. In the second row (row 2), one of the items appears to be a sharp shoe, but there are no shoes there either.
#
# Upon checking the third row (row 3), I see some items but not shoes.
#
# The only visible sharp shoes are located on row 2, column C. Therefore, the topmost sharp shoes must be in that position.
#
# Now, I will submit the answer as C2.'
# Error parsing coordinates for answer 'To find the shirt from the user's point of view, we need to identify the coordinates of the shirt in the grid.
#
# Looking at the grid:
# - **Row 1** has one shirt in **Column B**.
# - **Row 3** has shirts in **Column B** and **C**.
# - **Row 4** has a shirt in **Column B**.
#
# From the user's point of view, they will look at the grid from the back, where:
# - Column A is on the left, and Column D is on the right.
# - Row 1 is at the top, and Row 4 is at the bottom.
#
# Given this orientation, the shirt (in **Column B** and **Row 1**) would be viewed by the user as **B1**.
#
# Next, I will submit this answer, as it accurately reflects the location of one of the shirts from the user's perspective.
#
# I'll go ahead and submit the answer as "B1".': Invalid row number: 'o find the shirt from the user's point of view, we need to identify the coordinates of the shirt in the grid.
#
# Looking at the grid:
# - **Row 1** has one shirt in **Column B**.
# - **Row 3** has shirts in **Column B** and **C**.
# - **Row 4** has a shirt in **Column B**.
#
# From the user's point of view, they will look at the grid from the back, where:
# - Column A is on the left, and Column D is on the right.
# - Row 1 is at the top, and Row 4 is at the bottom.
#
# Given this orientation, the shirt (in **Column B** and **Row 1**) would be viewed by the user as **B1**.
#
# Next, I will submit this answer, as it accurately reflects the location of one of the shirts from the user's perspective.
#
# I'll go ahead and submit the answer as "B1".'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the leftmost shoe from the user's point of view, I need to look at the grid cells from their perspective. The user is on the right side, meaning that the leftmost items would be in the leftmost column labeled 'A'.
#
# Looking at the grid:
#
# - In column A (the leftmost column), the items listed in order from top to bottom are:
#   - A1: (empty)
#   - A2: ice skates (shoe)
#   - A3: sock
#   - A4: (red dot)
#
# The leftmost shoe (ice skates) is located in A2.
#
# Now, I'll submit the answer as 'A2'.': Invalid row number: 'o find the leftmost shoe from the user's point of view, I need to look at the grid cells from their perspective. The user is on the right side, meaning that the leftmost items would be in the leftmost column labeled 'A'.
#
# Looking at the grid:
#
# - In column A (the leftmost column), the items listed in order from top to bottom are:
#   - A1: (empty)
#   - A2: ice skates (shoe)
#   - A3: sock
#   - A4: (red dot)
#
# The leftmost shoe (ice skates) is located in A2.
#
# Now, I'll submit the answer as 'A2'.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To determine the rightmost fruit from my point of view, I'll first identify the fruits present in the grid.
#
# From the grid, I can see:
#
# - Row 3 contains both blueberries and a bunch of grapes which are fruits.
# - Row 4 contains blueberries as well.
#
# Now looking at their positions:
# - The blueberries in Row 3 are in Column A and Column B (the last fruit in this row being grapes in Column C).
# - The blueberries in Row 4 are in Column A which is not the rightmost.
# - The grapes in Row 3 in Column C are indeed the rightmost fruit visible from this perspective.
#
# Since I'm looking at the grid from the back, I will determine the coordinates for grapes, which are in Column C, Row 3.
#
# So, the answer will be C3.
#
# Now, I will submit the answer.': Invalid row number: 'o determine the rightmost fruit from my point of view, I'll first identify the fruits present in the grid.
#
# From the grid, I can see:
#
# - Row 3 contains both blueberries and a bunch of grapes which are fruits.
# - Row 4 contains blueberries as well.
#
# Now looking at their positions:
# - The blueberries in Row 3 are in Column A and Column B (the last fruit in this row being grapes in Column C).
# - The blueberries in Row 4 are in Column A which is not the rightmost.
# - The grapes in Row 3 in Column C are indeed the rightmost fruit visible from this perspective.
#
# Since I'm looking at the grid from the back, I will determine the coordinates for grapes, which are in Column C, Row 3.
#
# So, the answer will be C3.
#
# Now, I will submit the answer.'
# Error parsing coordinates for answer 'To find the rightmost sharp plant from my point of view, I'll analyze the grid layout to locate all the sharp plants (cacti) visible from the back.
#
# From the image:
#
# - In column A:
#   - Row 1: Cactus (sharp plant)
#   - Row 2: Cactus (sharp plant)
# - In column C:
#   - Row 3: Cactus (sharp plant)
#
# Analyzing their positions:
# - The cactus in row 3 of column C is the rightmost among them.
#
# Now, I will submit the coordinates for that cell. In my perspective, this is "C3."
#
# I'll proceed with the submission.': Invalid row number: 'o find the rightmost sharp plant from my point of view, I'll analyze the grid layout to locate all the sharp plants (cacti) visible from the back.
#
# From the image:
#
# - In column A:
#   - Row 1: Cactus (sharp plant)
#   - Row 2: Cactus (sharp plant)
# - In column C:
#   - Row 3: Cactus (sharp plant)
#
# Analyzing their positions:
# - The cactus in row 3 of column C is the rightmost among them.
#
# Now, I will submit the coordinates for that cell. In my perspective, this is "C3."
#
# I'll proceed with the submission.'
# Error parsing coordinates for answer 'To find the topmost stackable book from my point of view, I'll analyze the grid provided:
#
# 1. The grid cells are organized into columns (A, B, C, D) and rows (1, 2, 3, 4).
# 2. The items are arranged such that some cells contain books. From my view, the items are:
#    - Row 1: A book in cell A1, a book in cell C1
#    - Row 2: No books
#    - Row 3:  No books
#    - Row 4: No books
#
# The books in the topmost row are in cells A1 and C1. The first cell I encounter in this row from my perspective is A1.
#
# Thus, I conclude that the answer to the user's request for the topmost stackable book is in cell A1.
#
# Now, I will submit this answer.': Invalid row number: 'o find the topmost stackable book from my point of view, I'll analyze the grid provided:
#
# 1. The grid cells are organized into columns (A, B, C, D) and rows (1, 2, 3, 4).
# 2. The items are arranged such that some cells contain books. From my view, the items are:
#    - Row 1: A book in cell A1, a book in cell C1
#    - Row 2: No books
#    - Row 3:  No books
#    - Row 4: No books
#
# The books in the topmost row are in cells A1 and C1. The first cell I encounter in this row from my perspective is A1.
#
# Thus, I conclude that the answer to the user's request for the topmost stackable book is in cell A1.
#
# Now, I will submit this answer.'
# Error parsing coordinates for answer 'To find the smallest stackable book from my point of view, I need to analyze the grid for the books available. The grid represents the storage shelves with the items displayed in a 4x4 format.
#
# From the image, I can see the following:
#
# - The books are located in grid cells:
#   - B2 (one book)
#   - D2 (also one book)
#   - C3 (one book)
#
# Since I need to determine which of these is the smallest stackable book, I will select the book in grid cell D2, as it's likely to be the smallest one based on a common understanding of stackable items, but this could change if I had visibility of their sizes.
#
# From my perspective standing from the back, I will confirm my choice and prepare to submit my answer.
#
# I will submit 'D2' as the answer.': Invalid row number: 'o find the smallest stackable book from my point of view, I need to analyze the grid for the books available. The grid represents the storage shelves with the items displayed in a 4x4 format.
#
# From the image, I can see the following:
#
# - The books are located in grid cells:
#   - B2 (one book)
#   - D2 (also one book)
#   - C3 (one book)
#
# Since I need to determine which of these is the smallest stackable book, I will select the book in grid cell D2, as it's likely to be the smallest one based on a common understanding of stackable items, but this could change if I had visibility of their sizes.
#
# From my perspective standing from the back, I will confirm my choice and prepare to submit my answer.
#
# I will submit 'D2' as the answer.'
# Error parsing coordinates for answer 'Looking at the shelving grid from my perspective (the back of the grid), I need to identify the smallest book among the items stored in the grid cells.
#
# In the provided image, there are four visible books:
# - In cell B1
# - In cell C1
# - In cell D3
# - In cell D4
#
# To determine which book is the smallest, I can visually compare their sizes. The smallest book is likely to be found in cell B1 since the image shows that it appears smaller than the others.
#
# Thus, the coordinate of the grid cell containing the smallest book is B1.
#
# I will now submit this answer.': Invalid row number: 'ooking at the shelving grid from my perspective (the back of the grid), I need to identify the smallest book among the items stored in the grid cells.
#
# In the provided image, there are four visible books:
# - In cell B1
# - In cell C1
# - In cell D3
# - In cell D4
#
# To determine which book is the smallest, I can visually compare their sizes. The smallest book is likely to be found in cell B1 since the image shows that it appears smaller than the others.
#
# Thus, the coordinate of the grid cell containing the smallest book is B1.
#
# I will now submit this answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To determine the leftmost stackable book from the user's point of view, I will analyze the grid from the back (the user's side) and identify the locations of the books.
#
# From the image, the visible books are located in:
# - Cell B1
# - Cell B2
# - Cell C1
#
# From the user's perspective (the back of the grid), the leftmost column is A, followed by B, C, and D. The user's point of view makes the cell positions appear differently than they do from the front.
#
# In this case:
# - The first visible book is in B1 (topmost).
# - The next stackable book is in B2 (just below it).
#
# Since the question asks for the leftmost stackable book, looking vertically, the stackable book directly located at the leftmost position would be in column B2.
#
# Therefore, I will select B2 as it is the leftmost stackable book from the user's perspective.
#
# Now, I will submit the answer.': Invalid row number: 'o determine the leftmost stackable book from the user's point of view, I will analyze the grid from the back (the user's side) and identify the locations of the books.
#
# From the image, the visible books are located in:
# - Cell B1
# - Cell B2
# - Cell C1
#
# From the user's perspective (the back of the grid), the leftmost column is A, followed by B, C, and D. The user's point of view makes the cell positions appear differently than they do from the front.
#
# In this case:
# - The first visible book is in B1 (topmost).
# - The next stackable book is in B2 (just below it).
#
# Since the question asks for the leftmost stackable book, looking vertically, the stackable book directly located at the leftmost position would be in column B2.
#
# Therefore, I will select B2 as it is the leftmost stackable book from the user's perspective.
#
# Now, I will submit the answer.'
# Error parsing coordinates for answer 'To find the "brown sharp clothes" from your point of view, I will first analyze the items in the grid.
#
# Looking at the grid:
#
# - Row 1: Lemon, T-Shirt, empty, Strawberry
# - Row 2: Pot, Roller Skates, empty, empty
# - Row 3: Vase, Roller Skate, empty, Roller Skate
# - Row 4: Basketball, empty, Car, Sunflower
#
# The only item that matches the description of "brown sharp clothes" is located at C3, which appears to be a brown roller skate.
#
# Thus, I will select the grid cell corresponding to the brown roller skate, which is C3.
#
# Now, I will submit my answer.': Invalid row number: 'o find the "brown sharp clothes" from your point of view, I will first analyze the items in the grid.
#
# Looking at the grid:
#
# - Row 1: Lemon, T-Shirt, empty, Strawberry
# - Row 2: Pot, Roller Skates, empty, empty
# - Row 3: Vase, Roller Skate, empty, Roller Skate
# - Row 4: Basketball, empty, Car, Sunflower
#
# The only item that matches the description of "brown sharp clothes" is located at C3, which appears to be a brown roller skate.
#
# Thus, I will select the grid cell corresponding to the brown roller skate, which is C3.
#
# Now, I will submit my answer.'
# Error parsing coordinates for answer 'To find the largest car from my point of view, I will examine the grid cells for car images and assess their sizes.
#
# From the given grid, I can see the following car images:
# - A1 (small car)
# - A4 (larger car)
#
# Based on the visual assessment, the largest car appears to be in cell A4.
#
# ...
#
# The instrument in column A, row 1 is the first music instrument (guitar).
#
# I will submit the answer as "A1".': Invalid row number: 'o locate the "music instrument" from your point of view, I will analyze the grid from your perspective, which is the back of the shelving grid.
#
# Upon inspecting the grid:
# - In column A, rows 1, 2, and 4 contain guitars.
# - In column B, rows 1, 2, 3, and 4 contain violins.
# - In column C, rows 1, 2, and 3 contain violins.
# - In column D, only row 2 is empty, and other rows contain violins.
#
# Based on the items displayed:
# - The guitars are primarily located in column A and some in row 4.
# - The violins are prevalent in columns B and C.
#
# Since the user's request is for a "music instrument", it sounds like it could refer to either the guitars or violins. However, given the context that I should avoid items that don't match (like the car in column D, row 4) and focus on identifying a specific instrument rather than all of them, I will choose an instrument that is clearly identifiable.
#
# I observe guitars in column A and violins in columns B and C. To provide a specific answer, I will select the first music instrument found in the grid that stands out.
#
# The instrument in column A, row 1 is the first music instrument (guitar).
#
# I will submit the answer as "A1".'
# Error parsing coordinates for answer 'Looking at the shelving grid from the user's point of view (standing on the right side), I can identify the positions of the books.
#
# Column A has a book in row 1, row 2, row 3, and row 4.
# Column B has a book in row 1 and row 2.
# Column C has a book in row 1, row 3, and row 4.
# Column D has a book in row 1, row 2, and row 4.
#
# Since the user specified to select the book, I need to find one that's visible. It's clear that all the visible columns have books in them.
#
# Now, to identify a specific book, I will select a book from the grid. The first book that is visible from my perspective is located at A1.
#
# Now I will submit the answer for the selected book's location, which is in cell A1.': Invalid row number: 'ooking at the shelving grid from the user's point of view (standing on the right side), I can identify the positions of the books.
#
# Column A has a book in row 1, row 2, row 3, and row 4.
# Column B has a book in row 1 and row 2.
# Column C has a book in row 1, row 3, and row 4.
# Column D has a book in row 1, row 2, and row 4.
#
# Since the user specified to select the book, I need to find one that's visible. It's clear that all the visible columns have books in them.
#
# Now, to identify a specific book, I will select a book from the grid. The first book that is visible from my perspective is located at A1.
#
# Now I will submit the answer for the selected book's location, which is in cell A1.'
# Error parsing coordinates for answer 'To find the topmost dress from my point of view, I will examine the grid.
#
# Looking at the grid:
# - The dresses are located in the following positions:
#   - Row 1: A1, B1, C1
#   - Row 2: A2, B2, C2
#   - Row 3: A3, B3, C3
#   - Row 4: A4, B4, (and the orange in D4)
#
# Since I am standing at the back and viewing the grid from there, the topmost row is Row 1. In this row, the first three columns A, B, and C contain dresses.
#
# I will select the first dress in the leftmost position (A1) as it is the topmost dress. Thus, the coordinates for the topmost dress are A1.
#
# Now, I will submit this answer.': Invalid row number: 'o find the topmost dress from my point of view, I will examine the grid.
#
# Looking at the grid:
# - The dresses are located in the following positions:
#   - Row 1: A1, B1, C1
#   - Row 2: A2, B2, C2
#   - Row 3: A3, B3, C3
#   - Row 4: A4, B4, (and the orange in D4)
#
# Since I am standing at the back and viewing the grid from there, the topmost row is Row 1. In this row, the first three columns A, B, and C contain dresses.
#
# I will select the first dress in the leftmost position (A1) as it is the topmost dress. Thus, the coordinates for the topmost dress are A1.
#
# Now, I will submit this answer.'
# Error parsing coordinates for answer 'To identify the largest stackable book, I need to look at the grid and determine which cell contains the largest book. From the view, we can see the items as follows:
#
# - Row 1: Empty, Empty, Empty, Empty
# - Row 2: Cactus, Empty, Empty, Empty
# - Row 3: Book (1), Empty, Empty, Empty
# - Row 4: Book (2), Book (3), Book (4), Book (5)
#
# From the layout, it is clear that the grid cells contain books, but they're all the same size. Therefore, I can choose any of the cells that contain a book.
#
# The largest stackable book would be represented in the grid in column C (in row number 3) or multiple in row number 4. There are two options in row 4 in columns B and C.
#
# I'll choose the first available option from the bottom row in column C as that is the most likely to match the description of a stackable book appearance based on size.
#
# The coordinates from my point of view, representing the largest stackable book, would thus be 'C4'.
#
# Now I will submit 'C4' as the final answer.': Invalid row number: 'o identify the largest stackable book, I need to look at the grid and determine which cell contains the largest book. From the view, we can see the items as follows:
#
# - Row 1: Empty, Empty, Empty, Empty
# - Row 2: Cactus, Empty, Empty, Empty
# - Row 3: Book (1), Empty, Empty, Empty
# - Row 4: Book (2), Book (3), Book (4), Book (5)
#
# From the layout, it is clear that the grid cells contain books, but they're all the same size. Therefore, I can choose any of the cells that contain a book.
#
# The largest stackable book would be represented in the grid in column C (in row number 3) or multiple in row number 4. There are two options in row 4 in columns B and C.
#
# I'll choose the first available option from the bottom row in column C as that is the most likely to match the description of a stackable book appearance based on size.
#
# The coordinates from my point of view, representing the largest stackable book, would thus be 'C4'.
#
# Now I will submit 'C4' as the final answer.'
# Error parsing coordinates for answer 'To find the socks from your point of view, I'll carefully observe the layout of the grid.
#
# From your viewpoint, I see:
#
# - Column A has two pairs of socks (first and last rows, but they are styled differently).
# - Column B has one pair of socks (2nd row).
# - Column C has socks in two different rows (3rd and 4th).
# - Column D has a singular ice skate but no socks.
#
# The socks are located in the regions corresponding to columns and rows that have variations of colors and striped patterns.
#
# The pairs of socks are located in:
# - A1 (striped one)
# - A4 (striped one)
# - B2 (striped one)
# - C3 (striped one with colors).
#
# A careful review suggests that the socks in Column B, Row 2 (B2) is distinct and has a consistent pattern.
#
# I will select B2 as the answer.
#
# Now, let's submit that choice.': Invalid row number: 'o find the socks from your point of view, I'll carefully observe the layout of the grid.
#
# From your viewpoint, I see:
#
# - Column A has two pairs of socks (first and last rows, but they are styled differently).
# - Column B has one pair of socks (2nd row).
# - Column C has socks in two different rows (3rd and 4th).
# - Column D has a singular ice skate but no socks.
#
# The socks are located in the regions corresponding to columns and rows that have variations of colors and striped patterns.
#
# The pairs of socks are located in:
# - A1 (striped one)
# - A4 (striped one)
# - B2 (striped one)
# - C3 (striped one with colors).
#
# A careful review suggests that the socks in Column B, Row 2 (B2) is distinct and has a consistent pattern.
#
# I will select B2 as the answer.
#
# Now, let's submit that choice.'
# Error parsing coordinates for answer 'To locate the stackable book from your perspective, I need to determine which grid cell contains this item based on the image provided.
#
# From the user's perspective (the person standing behind the shelving grid), the coordinates are:
# - A1 (1st row, 1st column)
# - A2 (2nd row, 1st column)
# - A3 (3rd row, 1st column)
# - A4 (4th row, 1st column)
# - B1 (1st row, 2nd column)
# - B2 (2nd row, 2nd column)
# - B3 (3rd row, 2nd column, etc.)
#
# Now, I will examine the image to find the stackable book. It's important to note that there are several books shown, stacked vertically in different grid cells.
#
# Upon reviewing the image closely:
#
# - In column A, rows 1, 2, and 3 have stackable books.
# - In column B, rows 1 and 2 also have stackable books, while row 3 is empty.
# - In column C, rows 1 and 2 also have stackable books, while row 3 is empty.
# - In column D, only row 1 has a book, while rows 2 and 3 are stacked with other items.
#
# The stackable books appear to be in several locations. Since I need to choose one, the most straightforward choice would be A1, A2, or A3.
#
# Selecting A1, which is the top, stackable book that is clearly part of the collection. It is the first book visible in the top-left corner.
#
# Thus, my final answer is **A1**.
#
# I will now submit this answer.': Invalid row number: 'o locate the stackable book from your perspective, I need to determine which grid cell contains this item based on the image provided.
#
# From the user's perspective (the person standing behind the shelving grid), the coordinates are:
# - A1 (1st row, 1st column)
# - A2 (2nd row, 1st column)
# - A3 (3rd row, 1st column)
# - A4 (4th row, 1st column)
# - B1 (1st row, 2nd column)
# - B2 (2nd row, 2nd column)
# - B3 (3rd row, 2nd column, etc.)
#
# Now, I will examine the image to find the stackable book. It's important to note that there are several books shown, stacked vertically in different grid cells.
#
# Upon reviewing the image closely:
#
# - In column A, rows 1, 2, and 3 have stackable books.
# - In column B, rows 1 and 2 also have stackable books, while row 3 is empty.
# - In column C, rows 1 and 2 also have stackable books, while row 3 is empty.
# - In column D, only row 1 has a book, while rows 2 and 3 are stacked with other items.
#
# The stackable books appear to be in several locations. Since I need to choose one, the most straightforward choice would be A1, A2, or A3.
#
# Selecting A1, which is the top, stackable book that is clearly part of the collection. It is the first book visible in the top-left corner.
#
# Thus, my final answer is **A1**.
#
# I will now submit this answer.'
# Error parsing coordinates for answer 'To select the stackable book from my point of view (the back of the grid), I need to identify which grid cells contain books.
#
# From the grid:
# - Row 1: A1 (book), B1 (book), C1 (empty), D1 (book)
# - Row 2: A2 (empty), B2 (empty), C2 (empty), D2 (empty)
# - Row 3: A3 (book), B3 (empty), C3 (book), D3 (empty)
# - Row 4: A4 (book), B4 (empty), C4 (empty), D4 (book)
#
# The stackable books visible from my point of view (the back) are located in:
# - A1
# - B1
# - D1
# - A3
# - C3
# - A4
# - D4
#
# Given all of these books are potentially stackable, I will select one of them. Since there are multiple options, I will choose the first stackable book I see according to the grid layout, which is A1.
#
# Now, I will proceed to submit the answer for the stackable book in the grid as 'A1'.': Invalid row number: 'o select the stackable book from my point of view (the back of the grid), I need to identify which grid cells contain books.
#
# From the grid:
# - Row 1: A1 (book), B1 (book), C1 (empty), D1 (book)
# - Row 2: A2 (empty), B2 (empty), C2 (empty), D2 (empty)
# - Row 3: A3 (book), B3 (empty), C3 (book), D3 (empty)
# - Row 4: A4 (book), B4 (empty), C4 (empty), D4 (book)
#
# The stackable books visible from my point of view (the back) are located in:
# - A1
# - B1
# - D1
# - A3
# - C3
# - A4
# - D4
#
# Given all of these books are potentially stackable, I will select one of them. Since there are multiple options, I will choose the first stackable book I see according to the grid layout, which is A1.
#
# Now, I will proceed to submit the answer for the stackable book in the grid as 'A1'.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To select the topmost stackable book from your point of view, I need to note the layout of the shelving grid:
#
# - The grid positions have the following items:
#   - Row 1: A1 (book), B1 (book), C1 (book), D1 (missing)
#   - Row 2: A2 (book), B2 (tree), C2 (book), D2 (book)
#   - Row 3: A3 (book), B3 (book), C3 (book), D3 (book)
#   - Row 4: A4 (book), B4 (missing), C4 (book), D4 (missing)
#
# From your point of view (the back of the shelving grid), the topmost book would be in Row 1 since that is the highest row containing a book.
#
# In Row 1, the first three columns (A, B, and C) each have a book. Therefore, any of the cells A1, B1, or C1 can be considered topmost.
#
# However, since the user is likely looking for just one answer, and the leftmost book would typically be reported first, I will select A1.
#
# So the answer to submit will be 'A1'.
#
# Now I will submit the answer.': Invalid row number: 'o select the topmost stackable book from your point of view, I need to note the layout of the shelving grid:
#
# - The grid positions have the following items:
#   - Row 1: A1 (book), B1 (book), C1 (book), D1 (missing)
#   - Row 2: A2 (book), B2 (tree), C2 (book), D2 (book)
#   - Row 3: A3 (book), B3 (book), C3 (book), D3 (book)
#   - Row 4: A4 (book), B4 (missing), C4 (book), D4 (missing)
#
# From your point of view (the back of the shelving grid), the topmost book would be in Row 1 since that is the highest row containing a book.
#
# In Row 1, the first three columns (A, B, and C) each have a book. Therefore, any of the cells A1, B1, or C1 can be considered topmost.
#
# However, since the user is likely looking for just one answer, and the leftmost book would typically be reported first, I will select A1.
#
# So the answer to submit will be 'A1'.
#
# Now I will submit the answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the rightmost sharp plant (which is likely a cactus) from my point of view (the back of the grid), I need to look at the grid layout carefully.
#
# From the image:
#
# - Row 1 has 1 cactus in slot C1.
# - Row 2 is empty (no cacti).
# - Row 3 has 2 cacti in slots B3 and D3.
# - Row 4 has 2 cacti in slots A4 and B4.
#
# The rightmost plant in terms of the grid cells and from my perspective would be D3, which is the last column of row 3.
#
# Thus, the correct answer is **D3**.
#
# I will now submit my answer.': Invalid row number: 'o find the rightmost sharp plant (which is likely a cactus) from my point of view (the back of the grid), I need to look at the grid layout carefully.
#
# From the image:
#
# - Row 1 has 1 cactus in slot C1.
# - Row 2 is empty (no cacti).
# - Row 3 has 2 cacti in slots B3 and D3.
# - Row 4 has 2 cacti in slots A4 and B4.
#
# The rightmost plant in terms of the grid cells and from my perspective would be D3, which is the last column of row 3.
#
# Thus, the correct answer is **D3**.
#
# I will now submit my answer.'
# Error parsing coordinates for answer 'To find the topmost fruit from your point of view, I will look at the first row of the grid. From your perspective, the items are arranged in columns A, B, C, and D as follows:
#
# - Row 1: Empty, red ball, fruit, fruit
# - Row 2: Fruit, fruit, fruit, fruit
# - Row 3: Fruit, fruit, fruit, fruit
# - Row 4: Empty, fruit, empty, empty
#
# The topmost fruit is in row 2, column A.
#
# I will submit the answer 'A2'.': Invalid row number: 'o find the topmost fruit from your point of view, I will look at the first row of the grid. From your perspective, the items are arranged in columns A, B, C, and D as follows:
#
# - Row 1: Empty, red ball, fruit, fruit
# - Row 2: Fruit, fruit, fruit, fruit
# - Row 3: Fruit, fruit, fruit, fruit
# - Row 4: Empty, fruit, empty, empty
#
# The topmost fruit is in row 2, column A.
#
# I will submit the answer 'A2'.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Test Top Reversed errors: 0
# Test Top Same errors: 0
# Test Bottom Reversed errors: 0
# Test Bottom Same errors: 0

# %% [markdown]
# ## Combined (Test + Control) Left/Right Error Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

combined_left_reversed_errors = control_left_reversed_errors + test_left_reversed_errors
combined_left_same_errors = control_left_same_errors + test_left_same_errors
combined_right_reversed_errors = control_right_reversed_errors + test_right_reversed_errors
combined_right_same_errors = control_right_same_errors + test_right_same_errors

print("=== COMBINED LEFT/RIGHT ERROR ANALYSIS ===")
print(f"Combined Left Reversed errors: {len(combined_left_reversed_errors)}")
print(f"Combined Left Same errors: {len(combined_left_same_errors)}")
print(f"Combined Right Reversed errors: {len(combined_right_reversed_errors)}")
print(f"Combined Right Same errors: {len(combined_right_same_errors)}")

all_left_right_errors = (combined_left_reversed_errors + combined_left_same_errors +
                        combined_right_reversed_errors + combined_right_same_errors)

if len(all_left_right_errors) > 0:
    all_x = [error[0] for error in all_left_right_errors]
    all_y = [error[1] for error in all_left_right_errors]

    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0

    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1

    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))

    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center',
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None

        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))

        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count

        return heatmap_data, error_counter

    categories = [
        (combined_left_reversed_errors, ax1, "Left Reversed 'rightmost x from my perspective'", "Reds"),
        (combined_left_same_errors, ax2, "Left Same 'leftmost x from your perspective'", "Blues"),
        (combined_right_reversed_errors, ax3, "Right Reversed 'leftmost x from my perspective'", "Greens"),
        (combined_right_same_errors, ax4, "Right Same 'rightmost x from your perspective'", "Purples")
    ]

    all_heatmaps = []
    all_counters = []

    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)

    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)

    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)

        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)

                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)

                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (dx)', fontsize=14)
                ax.set_ylabel('Row Error (dy)', fontsize=14)
                ax.tick_params(labelsize=10)

                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150,
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)

    plt.suptitle('GPT-4o-mini Errors: Left/Right Questions by Perspective',
                 fontsize=18, y=0.98)
    plt.tight_layout()
    plt.show()

    print("\n=== DETAILED STATISTICS ===")

    category_names = ["Left Reversed 'rightmost x from my perspective'", "Left Same 'leftmost x from your perspective'", "Right Reversed 'leftmost x from my perspective'", "Right Same 'rightmost x from your perspective'"]
    error_lists = [combined_left_reversed_errors, combined_left_same_errors,
                   combined_right_reversed_errors, combined_right_same_errors]

    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])

            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")

            counter = Counter(tuple(error) for error in errors)
            print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")

else:
    print("No left/right errors found to visualize.")
# Out:
# === COMBINED LEFT/RIGHT ERROR ANALYSIS ===
# Combined Left Reversed errors: 493
# Combined Left Same errors: 325
# Combined Right Reversed errors: 529
# Combined Right Same errors: 366
# === DETAILED STATISTICS ===
#
# Left Reversed 'rightmost x from my perspective':
#   Count: 493
#   Mean error: (+2.18, +0.59)
#   Std error: (0.90, 1.50)
#   Most common: ((np.int64(3), np.int64(0)), 80)
#
# Left Same 'leftmost x from your perspective':
#   Count: 325
#   Mean error: (-0.31, -0.75)
#   Std error: (1.10, 1.47)
#   Most common: ((np.int64(0), np.int64(-1)), 46)
#
# Right Reversed 'leftmost x from my perspective':
#   Count: 529
#   Mean error: (-2.20, -0.83)
#   Std error: (0.93, 1.49)
#   Most common: ((np.int64(-3), np.int64(-2)), 65)
#
# Right Same 'rightmost x from your perspective':
#   Count: 366
#   Mean error: (+0.19, +0.57)
#   Std error: (0.98, 1.61)
#   Most common: ((np.int64(0), np.int64(1)), 45)

# %% [markdown]
# ## Combined (Test + Control) Top/Bottom Error Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

combined_top_reversed_errors = control_top_reversed_errors + test_top_reversed_errors
combined_top_same_errors = control_top_same_errors + test_top_same_errors
combined_bottom_reversed_errors = control_bottom_reversed_errors + test_bottom_reversed_errors
combined_bottom_same_errors = control_bottom_same_errors + test_bottom_same_errors

print("=== COMBINED TOP/BOTTOM ERROR ANALYSIS ===")
print(f"Combined Top Reversed errors: {len(combined_top_reversed_errors)}")
print(f"Combined Top Same errors: {len(combined_top_same_errors)}")
print(f"Combined Bottom Reversed errors: {len(combined_bottom_reversed_errors)}")
print(f"Combined Bottom Same errors: {len(combined_bottom_same_errors)}")

all_top_bottom_errors = (combined_top_reversed_errors + combined_top_same_errors +
                        combined_bottom_reversed_errors + combined_bottom_same_errors)

if len(all_top_bottom_errors) > 0:
    all_x = [error[0] for error in all_top_bottom_errors]
    all_y = [error[1] for error in all_top_bottom_errors]

    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0

    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1

    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))

    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center',
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None

        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))

        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count

        return heatmap_data, error_counter

    categories = [
        (combined_top_reversed_errors, ax1, "Top Reversed 'topmost x from my perspective'", "Reds"),
        (combined_top_same_errors, ax2, "Top Same 'topmost x from your perspective'", "Blues"),
        (combined_bottom_reversed_errors, ax3, "Bottom Reversed 'bottommost x from my perspective'", "Greens"),
        (combined_bottom_same_errors, ax4, "Bottom Same 'bottommost x from your perspective'", "Purples")
    ]

    all_heatmaps = []
    all_counters = []

    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)

    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)

    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)

        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)

                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)

                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (dx)', fontsize=14)
                ax.set_ylabel('Row Error (dy)', fontsize=14)
                ax.tick_params(labelsize=10)

                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150,
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)

    plt.suptitle('GPT-4o-mini Errors: Top/Bottom Questions by Perspective',
                 fontsize=18, y=0.98)
    plt.tight_layout()
    plt.show()

    print("\n=== DETAILED STATISTICS ===")

    category_names = [
        "Top Reversed 'topmost x from my perspective'",
        "Top Same 'topmost x from your perspective'",
        "Bottom Reversed 'bottommost x from my perspective'",
        "Bottom Same 'bottommost x from your perspective'"
    ]
    error_lists = [combined_top_reversed_errors, combined_top_same_errors,
                   combined_bottom_reversed_errors, combined_bottom_same_errors]

    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])

            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")

            counter = Counter(tuple(error) for error in errors)
            print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")

else:
    print("No top/bottom errors found to visualize.")
# Out:
# === COMBINED TOP/BOTTOM ERROR ANALYSIS ===
# Combined Top Reversed errors: 135
# Combined Top Same errors: 144
# Combined Bottom Reversed errors: 174
# Combined Bottom Same errors: 177
# === DETAILED STATISTICS ===
#
# Top Reversed 'topmost x from my perspective':
#   Count: 135
#   Mean error: (-1.01, +0.84)
#   Std error: (1.41, 0.69)
#   Most common: ((np.int64(-2), np.int64(1)), 27)
#
# Top Same 'topmost x from your perspective':
#   Count: 144
#   Mean error: (-0.97, +0.82)
#   Std error: (1.35, 0.76)
#   Most common: ((np.int64(-1), np.int64(1)), 26)
#
# Bottom Reversed 'bottommost x from my perspective':
#   Count: 174
#   Mean error: (-0.53, -0.35)
#   Std error: (1.54, 0.78)
#   Most common: ((np.int64(-1), np.int64(0)), 35)
#
# Bottom Same 'bottommost x from your perspective':
#   Count: 177
#   Mean error: (-0.52, -0.42)
#   Std error: (1.60, 0.85)
#   Most common: ((np.int64(1), np.int64(0)), 29)
