# %% [markdown]
# # load each dataset

# %%
import os
import glob

from inspect_ai.log import EvalLog, read_eval_log


fill_ratios = [0.9]
related_ratios = [0.3, 0.5, 0.7, 0.9]
logs: list[list[EvalLog]] = [[] for _ in fill_ratios]

log_dir = "../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o"

def get_eval_file(folder_path):
    """Get the single .eval file from a folder, raise error if not exactly 1."""
    eval_files = glob.glob(os.path.join(folder_path, "*.eval"))
    
    if len(eval_files) == 0:
        raise FileNotFoundError(f"No .eval file found in {folder_path}")
    elif len(eval_files) > 1:
        raise ValueError(f"Multiple .eval files found in {folder_path}: {eval_files}")
    
    return eval_files[0]

for (fill_index, fill) in enumerate(fill_ratios):
    for related in related_ratios:
        folder = os.path.join(log_dir, "fill_ratio_" + str(fill), "related_ratio_" + str(related), "default")
        eval_file = get_eval_file(folder)
        log = read_eval_log(eval_file, resolve_attachments=False, header_only=True)
        print(f"loaded log file: {eval_file}")
        logs[fill_index].append(log)
# Out:
# loaded log file: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# loaded log file: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.5/default/2025-10-20T19-20-02+01-00_directors-task_PkNRqW2U87pg3CrsTYJSuT.eval
# loaded log file: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.7/default/2025-10-21T14-46-31+01-00_directors-task_HArkempL7Je5dYRNuL36TL.eval
# loaded log file: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.9/default/2025-10-21T17-02-03+01-00_directors-task_aRE75H22mfZEaDEXBYHCVa.eval

# %%
def parse_coordinate_string(coord_str):
    """
    Parse a coordinate string like 'C2' into (x, y) coordinates.
    
    Args:
        coord_str: String in format 'XY' where X is letter (A,B,C...) and Y is number (0,1,2...)
        
    Returns:
        tuple: (x, y) coordinates where x=column (0-based), y=row (0-based)
        
    Raises:
        ValueError: If string format is invalid
    """
    if not coord_str or len(coord_str) < 2:
        raise ValueError(f"Invalid coordinate string: '{coord_str}'")
    
    # Extract column letter and row number
    col_letter = coord_str[0].upper()
    row_str = coord_str[1:]
    
    # Validate column letter (A-Z)
    if not col_letter.isalpha():
        raise ValueError(f"Invalid column letter: '{col_letter}'")
    
    # Validate row number
    if not row_str.isdigit():
        raise ValueError(f"Invalid row number: '{row_str}'") 
    
    # Convert letter to 0-based column index (A=0, B=1, C=2, ...)
    x = ord(col_letter) - ord('A')
    
    # Convert string to 0-based row index
    y = int(row_str) -1
    
    return (x, y)

# %% [markdown]
# ## now find and calculate the relative error ofr control samples

# %%
import gc

from inspect_ai.model import ContentText
import numpy as np





control_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] =="control":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        control_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue


        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# The 'score' field is deprecated. Access sample scores through 'scores' instead.
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.5/default/2025-10-20T19-20-02+01-00_directors-task_PkNRqW2U87pg3CrsTYJSuT.eval
# Error parsing coordinates for answer 'C4 (Pink Heels)': Invalid row number: '4 (Pink Heels)'
# Error parsing coordinates for answer 'There is no green plant item in the grid. Therefore, I cannot submit a grid location for an item that does not exist.': Invalid row number: 'here is no green plant item in the grid. Therefore, I cannot submit a grid location for an item that does not exist.'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.7/default/2025-10-21T14-46-31+01-00_directors-task_HArkempL7Je5dYRNuL36TL.eval
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.9/default/2025-10-21T17-02-03+01-00_directors-task_aRE75H22mfZEaDEXBYHCVa.eval
# Error parsing coordinates for answer 'No plant is visible in the grid.': Invalid row number: 'o plant is visible in the grid.'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

# Convert control_errors to a more analysis-friendly format
print(f"Total control errors analyzed: {len(control_errors)}")

if len(control_errors) > 0:
    # Create a counter for error patterns
    error_counter = Counter(tuple(error) for error in control_errors)

    # Get the range of errors to determine heatmap size
    x_errors = [error[0] for error in control_errors]
    y_errors = [error[1] for error in control_errors]

    x_min, x_max = min(x_errors), max(x_errors)
    y_min, y_max = min(y_errors), max(y_errors)

    print(f"Error range: x [{x_min}, {x_max}], y [{y_min}, {y_max}]")

    # Create a grid for the heatmap
    # Make it symmetric around 0 for better visualization
    max_abs_x = max(abs(x_min), abs(x_max))
    max_abs_y = max(abs(y_min), abs(y_max))

    # Create grid centered at 0
    grid_size_x = 2 * max_abs_x + 1
    grid_size_y = 2 * max_abs_y + 1

    heatmap_data = np.zeros((grid_size_y, grid_size_x))

    # Fill in the heatmap data
    for (dx, dy), count in error_counter.items():
        # Convert error coordinates to heatmap indices
        heatmap_x = dx + max_abs_x  # Center at max_abs_x
        heatmap_y = dy + max_abs_y  # Center at max_abs_y
        heatmap_data[heatmap_y, heatmap_x] = count

    # Create the visualization
    plt.figure(figsize=(12, 8))

    # Find min and max values for log scale (excluding zeros)
    nonzero_data = heatmap_data[heatmap_data > 0]
    if len(nonzero_data) > 0:
        vmin = nonzero_data.min()
        vmax = nonzero_data.max()

        # Create heatmap with log scale
        # We need to handle zeros specially for log scale
        heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)

        sns.heatmap(heatmap_data_log,
                    annot=heatmap_data,  # Show actual counts in annotations
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Reds',
                    norm=LogNorm(vmin=vmin, vmax=vmax),
                    xticklabels=range(-max_abs_x, max_abs_x + 1),
                    yticklabels=range(-max_abs_y, max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors (log scale)'})
    else:
        # Fallback to linear scale if no data
        sns.heatmap(heatmap_data,
                    annot=True,
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Reds',
                    center=0,
                    xticklabels=range(-max_abs_x, max_abs_x + 1),
                    yticklabels=range(-max_abs_y, max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors'})

    plt.title('Control Sample Error Patterns (Log Scale)\n(Answer Position - Correct Position)', fontsize=18)
    plt.xlabel('Column Error (Δx)', fontsize=16)
    plt.ylabel('Row Error (Δy)', fontsize=16)
    plt.tick_params(labelsize=12)

    # Add a marker for the "correct" position (0,0)
    center_x = max_abs_x
    center_y = max_abs_y
    plt.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=200, color='blue',
                label='Perfect Match (0,0)')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # Print some statistics
    print(f"\nError Statistics:")
    print(f"Most common error: {error_counter.most_common(1)[0] if error_counter else 
'None'}")
    print(f"Unique error patterns: {len(error_counter)}")

    # Show top 5 most common errors
    print(f"\nTop 5 most common error patterns:")
    for i, ((dx, dy), count) in enumerate(error_counter.most_common(5)):
        print(f"  {i+1}. Error ({dx:+2d}, {dy:+2d}): {count} occurrences")

    # Calculate some basic statistics
    x_errors_array = np.array(x_errors)
    y_errors_array = np.array(y_errors)

    print(f"\nMean error: ({np.mean(x_errors_array):+.2f}, {np.mean(y_errors_array):+.2f})")
    print(f"Std error: ({np.std(x_errors_array):.2f}, {np.std(y_errors_array):.2f})")

else:
    print("No control errors found to visualize.")
# Out:
# Total control errors analyzed: 1815
# Error range: x [-3, 3], y [-3, 3]
# Error Statistics:
# Most common error: ((np.int64(1), np.int64(0)), 345)
# Unique error patterns: 48
#
# Top 5 most common error patterns:
#   1. Error (+1, +0): 345 occurrences
#   2. Error (-1, +0): 189 occurrences
#   3. Error (+3, +0): 109 occurrences
#   4. Error (+0, -1): 101 occurrences
#   5. Error (+0, +1): 79 occurrences
#
# Mean error: (+0.22, -0.16)
# Std error: (1.65, 1.35)

# %% [markdown]
# ## Test Sample Error Analysis

# %%
test_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] == "test":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        test_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue

        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# Error parsing coordinates for answer 'D2 or B1': Invalid row number: '2 or B1'
# Error parsing coordinates for answer 'C1, B1, A2': Invalid row number: '1, B1, A2'
# Error parsing coordinates for answer 'A3 and C3': Invalid row number: '3 and C3'
# Error parsing coordinates for answer 'D1, B1, B3': Invalid row number: '1, B1, B3'
# Error parsing coordinates for answer 'A1 and C4': Invalid row number: '1 and C4'
# Error parsing coordinates for answer 'A1 or C1 or D4': Invalid row number: '1 or C1 or D4'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.5/default/2025-10-20T19-20-02+01-00_directors-task_PkNRqW2U87pg3CrsTYJSuT.eval
# Error parsing coordinates for answer 'D4,A4,B2,A2,C1': Invalid row number: '4,A4,B2,A2,C1'
# Error parsing coordinates for answer 'B1, D1, A2, C3, B4': Invalid row number: '1, D1, A2, C3, B4'
# Error parsing coordinates for answer 'D4 and B4': Invalid row number: '4 and B4'
# Error parsing coordinates for answer 'D1, C1, B3, A1, A3, B4': Invalid row number: '1, C1, B3, A1, A3, B4'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.7/default/2025-10-21T14-46-31+01-00_directors-task_HArkempL7Je5dYRNuL36TL.eval
# Error parsing coordinates for answer 'D4, C4, A4, D3, B2, B1, A1': Invalid row number: '4, C4, A4, D3, B2, B1, A1'
# Error parsing coordinates for answer 'A1, A2, C3, D1, B3': Invalid row number: '1, A2, C3, D1, B3'
# Error parsing coordinates for answer 'D4, D3, D2, C4, C3, C2, B2, B1': Invalid row number: '4, D3, D2, C4, C3, C2, B2, B1'
# Error parsing coordinates for answer 'D1, B1, C2, B3, C3, B4': Invalid row number: '1, B1, C2, B3, C3, B4'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.9/default/2025-10-21T17-02-03+01-00_directors-task_aRE75H22mfZEaDEXBYHCVa.eval
# Error parsing coordinates for answer 'D1, D2, D3, D4, C2, B1, B3, A1': Invalid row number: '1, D2, D3, D4, C2, B1, B3, A1'
# Error parsing coordinates for answer 'A1, C1, D2': Invalid row number: '1, C1, D2'
# Error parsing coordinates for answer 'C1, B3, B2, A1, C3': Invalid row number: '1, B3, B2, A1, C3'
# Error parsing coordinates for answer 'From the user's perspective (back view, mirrors left and right but keeps up and down): Instruments at D4, C3, D2, A3.': Invalid row number: 'rom the user's perspective (back view, mirrors left and right but keeps up and down): Instruments at D4, C3, D2, A3.'
# Error parsing coordinates for answer '1A': Invalid column letter: '1'
# Error parsing coordinates for answer 'A1, A4, B1, B2': Invalid row number: '1, A4, B1, B2'

# %%
# Convert test_errors to a more analysis-friendly format
print(f"Total test errors analyzed: {len(test_errors)}")

if len(test_errors) > 0:
    # Create a counter for error patterns
    test_error_counter = Counter(tuple(error) for error in test_errors)
    
    # Get the range of errors to determine heatmap size
    x_errors = [error[0] for error in test_errors]
    y_errors = [error[1] for error in test_errors]
    
    x_min, x_max = min(x_errors), max(x_errors)
    y_min, y_max = min(y_errors), max(y_errors)
    
    print(f"Error range: x [{x_min}, {x_max}], y [{y_min}, {y_max}]")
    
    # Create a grid for the heatmap
    # Make it symmetric around 0 for better visualization
    max_abs_x = max(abs(x_min), abs(x_max))
    max_abs_y = max(abs(y_min), abs(y_max))
    
    # Create grid centered at 0
    grid_size_x = 2 * max_abs_x + 1
    grid_size_y = 2 * max_abs_y + 1
    
    heatmap_data = np.zeros((grid_size_y, grid_size_x))
    
    # Fill in the heatmap data
    for (dx, dy), count in test_error_counter.items():
        # Convert error coordinates to heatmap indices
        heatmap_x = dx + max_abs_x  # Center at max_abs_x
        heatmap_y = dy + max_abs_y  # Center at max_abs_y
        heatmap_data[heatmap_y, heatmap_x] = count
    
    # Create the visualization
    plt.figure(figsize=(12, 8))
    
    # Find min and max values for log scale (excluding zeros)
    nonzero_data = heatmap_data[heatmap_data > 0]
    if len(nonzero_data) > 0:
        vmin = nonzero_data.min()
        vmax = nonzero_data.max()
        
        # Create heatmap with log scale
        # We need to handle zeros specially for log scale
        heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)
        
        sns.heatmap(heatmap_data_log, 
                    annot=heatmap_data,  # Show actual counts in annotations
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Blues',  # Different color to distinguish from control samples
                    norm=LogNorm(vmin=vmin, vmax=vmax),
                    xticklabels=range(-max_abs_x, max_abs_x + 1),
                    yticklabels=range(-max_abs_y, max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors (log scale)'})
    else:
        # Fallback to linear scale if no data
        sns.heatmap(heatmap_data, 
                    annot=True, 
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Blues',
                    center=0,
                    xticklabels=range(-max_abs_x, max_abs_x + 1),
                    yticklabels=range(-max_abs_y, max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors'})
    
    plt.title('Test Sample Error Patterns (Log Scale)\n(Answer Position - Correct Position)', fontsize=18)
    plt.xlabel('Column Error (Δx)', fontsize=16)
    plt.ylabel('Row Error (Δy)', fontsize=16)
    plt.tick_params(labelsize=12)
    
    # Add a marker for the "correct" position (0,0)
    center_x = max_abs_x
    center_y = max_abs_y
    plt.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=200, color='orange', 
                label='Perfect Match (0,0)')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Print some statistics
    print(f"\nTest Sample Error Statistics:")
    print(f"Most common error: {test_error_counter.most_common(1)[0] if test_error_counter else 'None'}")
    print(f"Unique error patterns: {len(test_error_counter)}")
    
    # Show top 5 most common errors
    print(f"\nTop 5 most common error patterns:")
    for i, ((dx, dy), count) in enumerate(test_error_counter.most_common(5)):
        print(f"  {i+1}. Error ({dx:+2d}, {dy:+2d}): {count} occurrences")
    
    # Calculate some basic statistics
    x_errors_array = np.array(x_errors)
    y_errors_array = np.array(y_errors)
    
    print(f"\nMean error: ({np.mean(x_errors_array):+.2f}, {np.mean(y_errors_array):+.2f})")
    print(f"Std error: ({np.std(x_errors_array):.2f}, {np.std(y_errors_array):.2f})")
    
else:
    print("No test errors found to visualize.")
# Out:
# Total test errors analyzed: 3290
# Error range: x [-3, 3], y [-3, 3]
# Test Sample Error Statistics:
# Most common error: ((np.int64(1), np.int64(0)), 263)
# Unique error patterns: 48
#
# Top 5 most common error patterns:
#   1. Error (+1, +0): 263 occurrences
#   2. Error (-1, +0): 245 occurrences
#   3. Error (+0, -1): 213 occurrences
#   4. Error (+0, -2): 164 occurrences
#   5. Error (-2, +0): 145 occurrences
#
# Mean error: (-0.06, -0.37)
# Std error: (1.59, 1.55)

# %% [markdown]
# ## Comparison: Control vs Test Sample Errors

# %%
# Side-by-side comparison of control vs test errors
if len(control_errors) > 0 and len(test_errors) > 0:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
    
    # Prepare data for both plots
    control_counter = Counter(tuple(error) for error in control_errors)
    test_counter = Counter(tuple(error) for error in test_errors)
    
    # Get combined range for consistent scaling
    all_x = [error[0] for error in control_errors + test_errors]
    all_y = [error[1] for error in control_errors + test_errors]
    
    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x)))
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y)))
    
    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1
    
    # Control errors heatmap
    control_heatmap = np.zeros((grid_size_y, grid_size_x))
    for (dx, dy), count in control_counter.items():
        heatmap_x = dx + combined_max_abs_x
        heatmap_y = dy + combined_max_abs_y
        control_heatmap[heatmap_y, heatmap_x] = count
    
    # Test errors heatmap  
    test_heatmap = np.zeros((grid_size_y, grid_size_x))
    for (dx, dy), count in test_counter.items():
        heatmap_x = dx + combined_max_abs_x
        heatmap_y = dy + combined_max_abs_y
        test_heatmap[heatmap_y, heatmap_x] = count
    
    # Find global min/max for consistent color scaling
    control_nonzero = control_heatmap[control_heatmap > 0]
    test_nonzero = test_heatmap[test_heatmap > 0]
    
    if len(control_nonzero) > 0 and len(test_nonzero) > 0:
        global_vmin = min(control_nonzero.min(), test_nonzero.min())
        global_vmax = max(control_nonzero.max(), test_nonzero.max())
        
        # Control plot
        control_data_log = np.where(control_heatmap > 0, control_heatmap, np.nan)
        sns.heatmap(control_data_log,
                    annot=control_heatmap,
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Reds',
                    norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                    xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                    yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors (log scale)'},
                    ax=ax1)
        
        ax1.set_title('Control Sample Errors', fontsize=18)
        ax1.set_xlabel('Column Error (Δx)', fontsize=16)
        ax1.set_ylabel('Row Error (Δy)', fontsize=16)
        ax1.tick_params(labelsize=12)
        
        # Test plot
        test_data_log = np.where(test_heatmap > 0, test_heatmap, np.nan)
        sns.heatmap(test_data_log,
                    annot=test_heatmap,
                    fmt='g',
                    annot_kws={'fontsize': 12},
                    cmap='Blues',
                    norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                    xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                    yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                    cbar_kws={'label': 'Number of Errors (log scale)'},
                    ax=ax2)
        
        ax2.set_title('Test Sample Errors', fontsize=18)
        ax2.set_xlabel('Column Error (Δx)', fontsize=16)
        ax2.set_ylabel('Row Error (Δy)', fontsize=16)
        ax2.tick_params(labelsize=12)
        
        # Add markers for perfect match
        center_x = combined_max_abs_x
        center_y = combined_max_abs_y
        ax1.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=200, color='blue', label='Perfect Match (0,0)')
        ax2.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=200, color='orange', label='Perfect Match (0,0)')
        
        ax1.legend()
        ax2.legend()
        
        plt.tight_layout()
        plt.show()
        
        # Comparative statistics
        print("=== COMPARATIVE STATISTICS ===")
        print(f"Control errors: {len(control_errors)} total, {len(control_counter)} unique patterns")
        print(f"Test errors: {len(test_errors)} total, {len(test_counter)} unique patterns")
        
        control_x = np.array([error[0] for error in control_errors])
        control_y = np.array([error[1] for error in control_errors])
        test_x = np.array([error[0] for error in test_errors])
        test_y = np.array([error[1] for error in test_errors])
        
        print(f"\nMean errors:")
        print(f"  Control: ({np.mean(control_x):+.2f}, {np.mean(control_y):+.2f})")
        print(f"  Test:    ({np.mean(test_x):+.2f}, {np.mean(test_y):+.2f})")
        
        print(f"\nStandard deviation:")
        print(f"  Control: ({np.std(control_x):.2f}, {np.std(control_y):.2f})")
        print(f"  Test:    ({np.std(test_x):.2f}, {np.std(test_y):.2f})")
        
        print(f"\nMost common error patterns:")
        print(f"  Control: {control_counter.most_common(1)[0] if control_counter else 'None'}")
        print(f"  Test:    {test_counter.most_common(1)[0] if test_counter else 'None'}")
        
else:
    print("Need both control and test errors for comparison.")
# Out:
# === COMPARATIVE STATISTICS ===
# Control errors: 1815 total, 48 unique patterns
# Test errors: 3290 total, 48 unique patterns
#
# Mean errors:
#   Control: (+0.22, -0.16)
#   Test:    (-0.06, -0.37)
#
# Standard deviation:
#   Control: (1.65, 1.35)
#   Test:    (1.59, 1.55)
#
# Most common error patterns:
#   Control: ((np.int64(1), np.int64(0)), 345)
#   Test:    ((np.int64(1), np.int64(0)), 263)

# %% [markdown]
# ## now look at left right tasks
# we should now make a heatmap of errors but for left-right questions and split it by reversed or not.

# %%
import gc

import numpy as np





control_left_reversed_errors = []
control_left_same_errors = []
control_right_reversed_errors = []
control_right_same_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] =="control":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        if sample.metadata["question"]["selection_rule"] == "leftmost" and sample.metadata["question"]["is_reversed"]:
                            control_left_reversed_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "leftmost" and not sample.metadata["question"]["is_reversed"]:
                            control_left_same_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "rightmost" and sample.metadata["question"]["is_reversed"]:
                            control_right_reversed_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "rightmost" and not sample.metadata["question"]["is_reversed"]:
                            control_right_same_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue


        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.5/default/2025-10-20T19-20-02+01-00_directors-task_PkNRqW2U87pg3CrsTYJSuT.eval
# Error parsing coordinates for answer 'C4 (Pink Heels)': Invalid row number: '4 (Pink Heels)'
# Error parsing coordinates for answer 'There is no green plant item in the grid. Therefore, I cannot submit a grid location for an item that does not exist.': Invalid row number: 'here is no green plant item in the grid. Therefore, I cannot submit a grid location for an item that does not exist.'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.7/default/2025-10-21T14-46-31+01-00_directors-task_HArkempL7Je5dYRNuL36TL.eval
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.9/default/2025-10-21T17-02-03+01-00_directors-task_aRE75H22mfZEaDEXBYHCVa.eval
# Error parsing coordinates for answer 'No plant is visible in the grid.': Invalid row number: 'o plant is visible in the grid.'

# %%
# Visualize left/right errors split by reversed/same direction
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

# Print summary statistics
print("=== LEFT/RIGHT ERROR ANALYSIS ===")
print(f"Control Left Reversed errors: {len(control_left_reversed_errors)}")
print(f"Control Left Same errors: {len(control_left_same_errors)}")
print(f"Control Right Reversed errors: {len(control_right_reversed_errors)}")
print(f"Control Right Same errors: {len(control_right_same_errors)}")

# Combine all errors to determine consistent scaling
all_left_right_errors = (control_left_reversed_errors + control_left_same_errors + 
                        control_right_reversed_errors + control_right_same_errors)

if len(all_left_right_errors) > 0:
    # Get combined range for consistent scaling
    all_x = [error[0] for error in all_left_right_errors]
    all_y = [error[1] for error in all_left_right_errors]
    
    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0
    
    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1
    
    # Create 2x2 subplot for the four categories
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    
    # Function to create individual heatmap
    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center', 
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None
        
        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))
        
        # Fill in the heatmap data
        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count
        
        return heatmap_data, error_counter
    
    # Create heatmaps for each category
    categories = [
        (control_left_reversed_errors, ax1, "Left Reversed 'rightmost x from my perspective'", "Reds"),
        (control_left_same_errors, ax2, "Left Same'leftmost x from your perspective'", "Blues"),
        (control_right_reversed_errors, ax3, "Right Reversed 'leftmost x from my perspective'", "Greens"),
        (control_right_same_errors, ax4, "Right Same 'rightmost x from your perspective'", "Purples")
    ]
    
    # Collect all non-zero data to determine global color scale
    all_heatmaps = []
    all_counters = []
    
    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)
    
    # Find global min/max for consistent color scaling
    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)
    
    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)
        
        # Create the actual heatmaps with consistent scaling
        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                # Create heatmap with log scale
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)
                
                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)
                
                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (Δx)', fontsize=14)
                ax.set_ylabel('Row Error (Δy)', fontsize=14)
                ax.tick_params(labelsize=10)
                
                # Add marker for perfect match
                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150, 
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)
    
    plt.suptitle('Control Sample Errors: Left/Right Questions by perspective', 
                 fontsize=14, y=0.98)
    plt.tight_layout()
    plt.show()
    
    # Print detailed statistics
    print("\n=== DETAILED STATISTICS ===")
    
    category_names = ["Left Reversed 'rightmost x from my perspective'", "Left Same'leftmost x from your perspective'", "Right Reversed 'leftmost x from my perspective'", "Right Same 'rightmost x from your perspective'"]
    error_lists = [control_left_reversed_errors, control_left_same_errors, 
                   control_right_reversed_errors, control_right_same_errors]
    
    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])
            
            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")
            
            if len(errors) > 0:
                counter = Counter(tuple(error) for error in errors)
                print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")
    
else:
    print("No left/right errors found to visualize.")
# Out:
# === LEFT/RIGHT ERROR ANALYSIS ===
# Control Left Reversed errors: 195
# Control Left Same errors: 151
# Control Right Reversed errors: 208
# Control Right Same errors: 151
# === DETAILED STATISTICS ===
#
# Left Reversed 'rightmost x from my perspective':
#   Count: 195
#   Mean error: (+1.58, +0.51)
#   Std error: (1.31, 1.60)
#   Most common: ((np.int64(3), np.int64(0)), 18)
#
# Left Same'leftmost x from your perspective':
#   Count: 151
#   Mean error: (+0.90, -1.61)
#   Std error: (0.64, 1.10)
#   Most common: ((np.int64(1), np.int64(-2)), 42)
#
# Right Reversed 'leftmost x from my perspective':
#   Count: 208
#   Mean error: (-0.98, -0.80)
#   Std error: (1.23, 1.56)
#   Most common: ((np.int64(0), np.int64(-1)), 20)
#
# Right Same 'rightmost x from your perspective':
#   Count: 151
#   Mean error: (-0.73, +0.17)
#   Std error: (0.80, 1.43)
#   Most common: ((np.int64(-1), np.int64(0)), 36)

# %% [markdown]
# ## Top/Bottom Question Analysis

# %%
import gc
import numpy as np

# Collect errors for topmost/bottommost questions
control_top_reversed_errors = []
control_top_same_errors = []
control_bottom_reversed_errors = []
control_bottom_same_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] =="control":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        
                        # Classify based on selection rule and perspective
                        selection_rule = sample.metadata["question"]["selection_rule"]
                        is_reversed = sample.metadata["question"]["is_reversed"]
                        
                        if selection_rule == "topmost" and is_reversed:
                            control_top_reversed_errors.append(difference)
                        elif selection_rule == "topmost" and not is_reversed:
                            control_top_same_errors.append(difference)
                        elif selection_rule == "bottommost" and is_reversed:
                            control_bottom_reversed_errors.append(difference)
                        elif selection_rule == "bottommost" and not is_reversed:
                            control_bottom_same_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue

        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.5/default/2025-10-20T19-20-02+01-00_directors-task_PkNRqW2U87pg3CrsTYJSuT.eval
# Error parsing coordinates for answer 'C4 (Pink Heels)': Invalid row number: '4 (Pink Heels)'
# Error parsing coordinates for answer 'There is no green plant item in the grid. Therefore, I cannot submit a grid location for an item that does not exist.': Invalid row number: 'here is no green plant item in the grid. Therefore, I cannot submit a grid location for an item that does not exist.'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.7/default/2025-10-21T14-46-31+01-00_directors-task_HArkempL7Je5dYRNuL36TL.eval
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.9/default/2025-10-21T17-02-03+01-00_directors-task_aRE75H22mfZEaDEXBYHCVa.eval
# Error parsing coordinates for answer 'No plant is visible in the grid.': Invalid row number: 'o plant is visible in the grid.'

# %%
# Visualize top/bottom errors split by reversed/same direction
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

# Print summary statistics
print("=== TOP/BOTTOM ERROR ANALYSIS ===")
print(f"Control Top Reversed errors: {len(control_top_reversed_errors)}")
print(f"Control Top Same errors: {len(control_top_same_errors)}")
print(f"Control Bottom Reversed errors: {len(control_bottom_reversed_errors)}")
print(f"Control Bottom Same errors: {len(control_bottom_same_errors)}")

# Combine all errors to determine consistent scaling
all_top_bottom_errors = (control_top_reversed_errors + control_top_same_errors + 
                        control_bottom_reversed_errors + control_bottom_same_errors)

if len(all_top_bottom_errors) > 0:
    # Get combined range for consistent scaling
    all_x = [error[0] for error in all_top_bottom_errors]
    all_y = [error[1] for error in all_top_bottom_errors]
    
    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0
    
    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1
    
    # Create 2x2 subplot for the four categories
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    
    # Function to create individual heatmap
    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center', 
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None
        
        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))
        
        # Fill in the heatmap data
        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count
        
        return heatmap_data, error_counter
    
    # Create heatmaps for each category
    categories = [
        (control_top_reversed_errors, ax1, "Top Reversed 'topmost x from my perspective'", "Reds"),
        (control_top_same_errors, ax2, "Top Same 'topmost x from your perspective'", "Blues"),
        (control_bottom_reversed_errors, ax3, "Bottom Reversed 'bottommost x from my perspective'", "Greens"),
        (control_bottom_same_errors, ax4, "Bottom Same 'bottommost x from your perspective'", "Purples")
    ]
    
    # Collect all non-zero data to determine global color scale
    all_heatmaps = []
    all_counters = []
    
    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)
    
    # Find global min/max for consistent color scaling
    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)
    
    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)
        
        # Create the actual heatmaps with consistent scaling
        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                # Create heatmap with log scale
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)
                
                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)
                
                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (Δx)', fontsize=14)
                ax.set_ylabel('Row Error (Δy)', fontsize=14)
                ax.tick_params(labelsize=10)
                
                # Add marker for perfect match
                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150, 
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)
    
    plt.suptitle('Control Sample Errors: Top/Bottom Questions by Perspective', 
                 fontsize=14, y=0.98)
    plt.tight_layout()
    plt.show()
    
    # Print detailed statistics
    print("\n=== DETAILED STATISTICS ===")
    
    category_names = [
        "Top Reversed 'topmost x from my perspective'", 
        "Top Same 'topmost x from your perspective'", 
        "Bottom Reversed 'bottommost x from my perspective'", 
        "Bottom Same 'bottommost x from your perspective'"
    ]
    error_lists = [control_top_reversed_errors, control_top_same_errors, 
                   control_bottom_reversed_errors, control_bottom_same_errors]
    
    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])
            
            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")
            
            if len(errors) > 0:
                counter = Counter(tuple(error) for error in errors)
                print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")
    
else:
    print("No top/bottom errors found to visualize.")
# Out:
# === TOP/BOTTOM ERROR ANALYSIS ===
# Control Top Reversed errors: 92
# Control Top Same errors: 50
# Control Bottom Reversed errors: 151
# Control Bottom Same errors: 102
# === DETAILED STATISTICS ===
#
# Top Reversed 'topmost x from my perspective':
#   Count: 92
#   Mean error: (+0.14, +0.83)
#   Std error: (1.75, 1.23)
#   Most common: ((np.int64(1), np.int64(0)), 13)
#
# Top Same 'topmost x from your perspective':
#   Count: 50
#   Mean error: (-0.68, +0.60)
#   Std error: (1.53, 0.77)
#   Most common: ((np.int64(1), np.int64(0)), 9)
#
# Bottom Reversed 'bottommost x from my perspective':
#   Count: 151
#   Mean error: (+0.15, -0.47)
#   Std error: (1.61, 1.02)
#   Most common: ((np.int64(1), np.int64(0)), 36)
#
# Bottom Same 'bottommost x from your perspective':
#   Count: 102
#   Mean error: (+0.34, -0.36)
#   Std error: (1.38, 0.79)
#   Most common: ((np.int64(1), np.int64(0)), 33)

# %% [markdown]
# ## Sample Distribution Analysis
# Analyze the distribution of samples across different metadata categories for each log file.

# %%
import pandas as pd
from collections import defaultdict
import gc
import itertools

# Dictionary to store sample counts for each log file
sample_distributions = {}

# First pass: collect all possible values to define the complete set of combinations
all_selection_rule_types = set()
all_sample_types = set()
all_is_reversed_values = set()
all_is_physics_values = set()

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"Scanning log for possible values: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        
        for sample in temp_log.samples:
            # Extract metadata fields
            sample_type = sample.metadata.get("sample_type", "unknown")
            is_physics = sample.metadata.get("is_physics", False)
            
            # Extract question metadata
            question_meta = sample.metadata.get("question", {})
            selection_rule_type = question_meta.get("selection_rule_type", "unknown")
            is_reversed = question_meta.get("is_reversed", False)
            
            # Collect all possible values
            all_selection_rule_types.add(selection_rule_type)
            all_sample_types.add(sample_type)
            all_is_reversed_values.add(is_reversed)
            all_is_physics_values.add(is_physics)
        
        del temp_log
        gc.collect()

# Create all possible combinations
all_combinations = list(itertools.product(
    sorted(all_selection_rule_types),
    sorted(all_is_reversed_values),
    sorted(all_sample_types),
    sorted(all_is_physics_values)
))

print(f"Found {len(all_combinations)} possible combinations:")
for combo in all_combinations:
    print(f"  {combo}")

# Second pass: count actual occurrences
for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        log_key = f"fill_{fill}_related_{related_ratios[related_index]}"
        
        print(f"Analyzing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        
        # Initialize counts for all combinations with 0
        counts = {combo: 0 for combo in all_combinations}
        
        for sample in temp_log.samples:
            # Extract metadata fields
            sample_type = sample.metadata.get("sample_type", "unknown")
            is_physics = sample.metadata.get("is_physics", False)
            
            # Extract question metadata
            question_meta = sample.metadata.get("question", {})
            selection_rule_type = question_meta.get("selection_rule_type", "unknown")
            is_reversed = question_meta.get("is_reversed", False)
            
            # Create combination key
            combo_key = (selection_rule_type, is_reversed, sample_type, is_physics)
            counts[combo_key] += 1
        
        sample_distributions[log_key] = counts
        
        del temp_log
        gc.collect()

# Convert to a more readable format and display results
print("\n=== SAMPLE DISTRIBUTION ANALYSIS ===\n")

# Create a comprehensive DataFrame for analysis
all_data = []
for log_key, counts in sample_distributions.items():
    for (selection_rule_type, is_reversed, sample_type, is_physics), count in counts.items():
        all_data.append({
            'log_file': log_key,
            'selection_rule_type': selection_rule_type,
            'is_reversed': is_reversed,
            'sample_type': sample_type,
            'is_physics': is_physics,
            'count': count
        })

df = pd.DataFrame(all_data)

# Display summary by log file (including zeros)
for log_key in sorted(sample_distributions.keys()):
    print(f"\n{log_key}:")
    log_df = df[df['log_file'] == log_key]
    
    # Group by combination and sum counts
    summary = log_df.groupby(['selection_rule_type', 'is_reversed', 'sample_type', 'is_physics'])['count'].sum().reset_index()
    
    # Sort for consistent display
    summary = summary.sort_values(['selection_rule_type', 'is_reversed', 'sample_type', 'is_physics'])
    
    for _, row in summary.iterrows():
        print(f"  {row['selection_rule_type']}, reversed={row['is_reversed']}, {row['sample_type']}, physics={row['is_physics']}: {row['count']}")
    
    total_samples = summary['count'].sum()
    print(f"  Total samples: {total_samples}")

# Overall summary across all log files (including zeros)
print(f"\n=== OVERALL SUMMARY ACROSS ALL LOG FILES ===")
overall_summary = df.groupby(['selection_rule_type', 'is_reversed', 'sample_type', 'is_physics'])['count'].sum().reset_index()
overall_summary = overall_summary.sort_values(['selection_rule_type', 'is_reversed', 'sample_type', 'is_physics'])

print(f"\nCombination counts across all {len(sample_distributions)} log files:")
for _, row in overall_summary.iterrows():
    print(f"  {row['selection_rule_type']}, reversed={row['is_reversed']}, {row['sample_type']}, physics={row['is_physics']}: {row['count']}")

total_all_samples = overall_summary['count'].sum()
print(f"\nGrand total samples across all logs: {total_all_samples}")

# Create a pivot table for better visualization (including zeros)
print(f"\n=== PIVOT TABLE: Sample Type vs Selection Rule Type ===")
pivot = df.pivot_table(
    index=['selection_rule_type', 'is_reversed'], 
    columns=['sample_type', 'is_physics'], 
    values='count', 
    aggfunc='sum', 
    fill_value=0
)
print(pivot)
# Out:
# Scanning log for possible values: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# Scanning log for possible values: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.5/default/2025-10-20T19-20-02+01-00_directors-task_PkNRqW2U87pg3CrsTYJSuT.eval
# Scanning log for possible values: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.7/default/2025-10-21T14-46-31+01-00_directors-task_HArkempL7Je5dYRNuL36TL.eval
# Scanning log for possible values: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.9/default/2025-10-21T17-02-03+01-00_directors-task_aRE75H22mfZEaDEXBYHCVa.eval
# Found 32 possible combinations:
#   ('none', False, 'control', False)
#   ('none', False, 'control', True)
#   ('none', False, 'test', False)
#   ('none', False, 'test', True)
#   ('none', True, 'control', False)
#   ('none', True, 'control', True)
#   ('none', True, 'test', False)
#   ('none', True, 'test', True)
#   ('size_related', False, 'control', False)
#   ('size_related', False, 'control', True)
#   ('size_related', False, 'test', False)
#   ('size_related', False, 'test', True)
#   ('size_related', True, 'control', False)
#   ('size_related', True, 'control', True)
#   ('size_related', True, 'test', False)
#   ('size_related', True, 'test', True)
#   ('spatial_different_perspective', False, 'control', False)
#   ('spatial_different_perspective', False, 'control', True)
#   ('spatial_different_perspective', False, 'test', False)
#   ('spatial_different_perspective', False, 'test', True)
#   ('spatial_different_perspective', True, 'control', False)
#   ('spatial_different_perspective', True, 'control', True)
#   ('spatial_different_perspective', True, 'test', False)
#   ('spatial_different_perspective', True, 'test', True)
#   ('spatial_same_perspective', False, 'control', False)
#   ('spatial_same_perspective', False, 'control', True)
#   ('spatial_same_perspective', False, 'test', False)
#   ('spatial_same_perspective', False, 'test', True)
#   ('spatial_same_perspective', True, 'control', False)
#   ('spatial_same_perspective', True, 'control', True)
#   ('spatial_same_perspective', True, 'test', False)
#   ('spatial_same_perspective', True, 'test', True)
# Analyzing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# Analyzing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.5/default/2025-10-20T19-20-02+01-00_directors-task_PkNRqW2U87pg3CrsTYJSuT.eval
# Analyzing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.7/default/2025-10-21T14-46-31+01-00_directors-task_HArkempL7Je5dYRNuL36TL.eval
# Analyzing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.9/default/2025-10-21T17-02-03+01-00_directors-task_aRE75H22mfZEaDEXBYHCVa.eval
#
# === SAMPLE DISTRIBUTION ANALYSIS ===
#
#
# fill_0.9_related_0.3:
#   none, reversed=False, control, physics=False: 67
#   none, reversed=False, control, physics=True: 48
#   none, reversed=False, test, physics=False: 62
#   none, reversed=False, test, physics=True: 59
#   none, reversed=True, control, physics=False: 58
#   none, reversed=True, control, physics=True: 77
#   none, reversed=True, test, physics=False: 63
#   none, reversed=True, test, physics=True: 66
#   size_related, reversed=False, control, physics=False: 61
#   size_related, reversed=False, control, physics=True: 62
#   size_related, reversed=False, test, physics=False: 69
#   size_related, reversed=False, test, physics=True: 68
#   size_related, reversed=True, control, physics=False: 64
#   size_related, reversed=True, control, physics=True: 63
#   size_related, reversed=True, test, physics=False: 56
#   size_related, reversed=True, test, physics=True: 57
#   spatial_different_perspective, reversed=False, control, physics=False: 54
#   spatial_different_perspective, reversed=False, control, physics=True: 66
#   spatial_different_perspective, reversed=False, test, physics=False: 60
#   spatial_different_perspective, reversed=False, test, physics=True: 65
#   spatial_different_perspective, reversed=True, control, physics=False: 71
#   spatial_different_perspective, reversed=True, control, physics=True: 59
#   spatial_different_perspective, reversed=True, test, physics=False: 65
#   spatial_different_perspective, reversed=True, test, physics=True: 60
#   spatial_same_perspective, reversed=False, control, physics=False: 64
#   spatial_same_perspective, reversed=False, control, physics=True: 55
#   spatial_same_perspective, reversed=False, test, physics=False: 47
#   spatial_same_perspective, reversed=False, test, physics=True: 70
#   spatial_same_perspective, reversed=True, control, physics=False: 61
#   spatial_same_perspective, reversed=True, control, physics=True: 70
#   spatial_same_perspective, reversed=True, test, physics=False: 78
#   spatial_same_perspective, reversed=True, test, physics=True: 55
#   Total samples: 2000
#
# fill_0.9_related_0.5:
#   none, reversed=False, control, physics=False: 65
#   none, reversed=False, control, physics=True: 64
#   none, reversed=False, test, physics=False: 72
#   none, reversed=False, test, physics=True: 60
#   none, reversed=True, control, physics=False: 60
#   none, reversed=True, control, physics=True: 61
#   none, reversed=True, test, physics=False: 53
#   none, reversed=True, test, physics=True: 65
#   size_related, reversed=False, control, physics=False: 66
#   size_related, reversed=False, control, physics=True: 59
#   size_related, reversed=False, test, physics=False: 62
#   size_related, reversed=False, test, physics=True: 53
#   size_related, reversed=True, control, physics=False: 59
#   size_related, reversed=True, control, physics=True: 66
#   size_related, reversed=True, test, physics=False: 63
#   size_related, reversed=True, test, physics=True: 72
#   spatial_different_perspective, reversed=False, control, physics=False: 60
#   spatial_different_perspective, reversed=False, control, physics=True: 64
#   spatial_different_perspective, reversed=False, test, physics=False: 62
#   spatial_different_perspective, reversed=False, test, physics=True: 50
#   spatial_different_perspective, reversed=True, control, physics=False: 65
#   spatial_different_perspective, reversed=True, control, physics=True: 61
#   spatial_different_perspective, reversed=True, test, physics=False: 63
#   spatial_different_perspective, reversed=True, test, physics=True: 75
#   spatial_same_perspective, reversed=False, control, physics=False: 54
#   spatial_same_perspective, reversed=False, control, physics=True: 71
#   spatial_same_perspective, reversed=False, test, physics=False: 68
#   spatial_same_perspective, reversed=False, test, physics=True: 62
#   spatial_same_perspective, reversed=True, control, physics=False: 71
#   spatial_same_perspective, reversed=True, control, physics=True: 54
#   spatial_same_perspective, reversed=True, test, physics=False: 57
#   spatial_same_perspective, reversed=True, test, physics=True: 63
#   Total samples: 2000
#
# fill_0.9_related_0.7:
#   none, reversed=False, control, physics=False: 70
#   none, reversed=False, control, physics=True: 57
#   none, reversed=False, test, physics=False: 71
#   none, reversed=False, test, physics=True: 65
#   none, reversed=True, control, physics=False: 55
#   none, reversed=True, control, physics=True: 68
#   none, reversed=True, test, physics=False: 54
#   none, reversed=True, test, physics=True: 60
#   size_related, reversed=False, control, physics=False: 59
#   size_related, reversed=False, control, physics=True: 66
#   size_related, reversed=False, test, physics=False: 72
#   size_related, reversed=False, test, physics=True: 66
#   size_related, reversed=True, control, physics=False: 66
#   size_related, reversed=True, control, physics=True: 59
#   size_related, reversed=True, test, physics=False: 53
#   size_related, reversed=True, test, physics=True: 59
#   spatial_different_perspective, reversed=False, control, physics=False: 59
#   spatial_different_perspective, reversed=False, control, physics=True: 61
#   spatial_different_perspective, reversed=False, test, physics=False: 61
#   spatial_different_perspective, reversed=False, test, physics=True: 57
#   spatial_different_perspective, reversed=True, control, physics=False: 66
#   spatial_different_perspective, reversed=True, control, physics=True: 64
#   spatial_different_perspective, reversed=True, test, physics=False: 64
#   spatial_different_perspective, reversed=True, test, physics=True: 68
#   spatial_same_perspective, reversed=False, control, physics=False: 59
#   spatial_same_perspective, reversed=False, control, physics=True: 63
#   spatial_same_perspective, reversed=False, test, physics=False: 61
#   spatial_same_perspective, reversed=False, test, physics=True: 62
#   spatial_same_perspective, reversed=True, control, physics=False: 66
#   spatial_same_perspective, reversed=True, control, physics=True: 62
#   spatial_same_perspective, reversed=True, test, physics=False: 64
#   spatial_same_perspective, reversed=True, test, physics=True: 63
#   Total samples: 2000
#
# fill_0.9_related_0.9:
#   none, reversed=False, control, physics=False: 68
#   none, reversed=False, control, physics=True: 69
#   none, reversed=False, test, physics=False: 53
#   none, reversed=False, test, physics=True: 62
#   none, reversed=True, control, physics=False: 57
#   none, reversed=True, control, physics=True: 56
#   none, reversed=True, test, physics=False: 72
#   none, reversed=True, test, physics=True: 63
#   size_related, reversed=False, control, physics=False: 58
#   size_related, reversed=False, control, physics=True: 56
#   size_related, reversed=False, test, physics=False: 55
#   size_related, reversed=False, test, physics=True: 67
#   size_related, reversed=True, control, physics=False: 67
#   size_related, reversed=True, control, physics=True: 69
#   size_related, reversed=True, test, physics=False: 70
#   size_related, reversed=True, test, physics=True: 58
#   spatial_different_perspective, reversed=False, control, physics=False: 55
#   spatial_different_perspective, reversed=False, control, physics=True: 61
#   spatial_different_perspective, reversed=False, test, physics=False: 64
#   spatial_different_perspective, reversed=False, test, physics=True: 60
#   spatial_different_perspective, reversed=True, control, physics=False: 70
#   spatial_different_perspective, reversed=True, control, physics=True: 64
#   spatial_different_perspective, reversed=True, test, physics=False: 61
#   spatial_different_perspective, reversed=True, test, physics=True: 65
#   spatial_same_perspective, reversed=False, control, physics=False: 66
#   spatial_same_perspective, reversed=False, control, physics=True: 69
#   spatial_same_perspective, reversed=False, test, physics=False: 58
#   spatial_same_perspective, reversed=False, test, physics=True: 67
#   spatial_same_perspective, reversed=True, control, physics=False: 59
#   spatial_same_perspective, reversed=True, control, physics=True: 56
#   spatial_same_perspective, reversed=True, test, physics=False: 67
#   spatial_same_perspective, reversed=True, test, physics=True: 58
#   Total samples: 2000
#
# === OVERALL SUMMARY ACROSS ALL LOG FILES ===
#
# Combination counts across all 4 log files:
#   none, reversed=False, control, physics=False: 270
#   none, reversed=False, control, physics=True: 238
#   none, reversed=False, test, physics=False: 258
#   none, reversed=False, test, physics=True: 246
#   none, reversed=True, control, physics=False: 230
#   none, reversed=True, control, physics=True: 262
#   none, reversed=True, test, physics=False: 242
#   none, reversed=True, test, physics=True: 254
#   size_related, reversed=False, control, physics=False: 244
#   size_related, reversed=False, control, physics=True: 243
#   size_related, reversed=False, test, physics=False: 258
#   size_related, reversed=False, test, physics=True: 254
#   size_related, reversed=True, control, physics=False: 256
#   size_related, reversed=True, control, physics=True: 257
#   size_related, reversed=True, test, physics=False: 242
#   size_related, reversed=True, test, physics=True: 246
#   spatial_different_perspective, reversed=False, control, physics=False: 228
#   spatial_different_perspective, reversed=False, control, physics=True: 252
#   spatial_different_perspective, reversed=False, test, physics=False: 247
#   spatial_different_perspective, reversed=False, test, physics=True: 232
#   spatial_different_perspective, reversed=True, control, physics=False: 272
#   spatial_different_perspective, reversed=True, control, physics=True: 248
#   spatial_different_perspective, reversed=True, test, physics=False: 253
#   spatial_different_perspective, reversed=True, test, physics=True: 268
#   spatial_same_perspective, reversed=False, control, physics=False: 243
#   spatial_same_perspective, reversed=False, control, physics=True: 258
#   spatial_same_perspective, reversed=False, test, physics=False: 234
#   spatial_same_perspective, reversed=False, test, physics=True: 261
#   spatial_same_perspective, reversed=True, control, physics=False: 257
#   spatial_same_perspective, reversed=True, control, physics=True: 242
#   spatial_same_perspective, reversed=True, test, physics=False: 266
#   spatial_same_perspective, reversed=True, test, physics=True: 239
#
# Grand total samples across all logs: 8000
#
# === PIVOT TABLE: Sample Type vs Selection Rule Type ===
# sample_type                               control        test
# is_physics                                  False True  False True
# selection_rule_type           is_reversed
# none                          False           270   238   258   246
#                               True            230   262   242   254
# size_related                  False           244   243   258   254
#                               True            256   257   242   246
# spatial_different_perspective False           228   252   247   232
#                               True            272   248   253   268
# spatial_same_perspective      False           243   258   234   261
#                               True            257   242   266   239

# %% [markdown]
# # test errors

# %%
import gc

from inspect_ai.model import ContentText
import numpy as np





test_left_reversed_errors = []
test_left_same_errors = []
test_right_reversed_errors = []
test_right_same_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] =="test":
                assert sample.score is not None
                if sample.score.value != "C":
                    answer = sample.output.completion
                    try:
                        # Parse the answer coordinate string
                        answer_coord = parse_coordinate_string(answer)
                        
                        # Get target coordinates from sample metadata 
                        # director_answer_coordinates is a list of coordinate tuples
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        
                        target_coord = target_coords[0]  # Get the single target coordinate tuple
                        
                        # Calculate difference (answer - target)
                        difference = np.array(answer_coord) - np.array(target_coord)
                        if sample.metadata["question"]["selection_rule"] == "leftmost" and sample.metadata["question"]["is_reversed"]:
                            test_left_reversed_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "leftmost" and not sample.metadata["question"]["is_reversed"]:
                            test_left_same_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "rightmost" and sample.metadata["question"]["is_reversed"]:
                            test_right_reversed_errors.append(difference)
                        elif sample.metadata["question"]["selection_rule"] == "rightmost" and not sample.metadata["question"]["is_reversed"]:
                            test_right_same_errors.append(difference)
                        
                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue


        del temp_log
        gc.collect()
# Out:
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# Error parsing coordinates for answer 'D2 or B1': Invalid row number: '2 or B1'
# Error parsing coordinates for answer 'C1, B1, A2': Invalid row number: '1, B1, A2'
# Error parsing coordinates for answer 'A3 and C3': Invalid row number: '3 and C3'
# Error parsing coordinates for answer 'D1, B1, B3': Invalid row number: '1, B1, B3'
# Error parsing coordinates for answer 'A1 and C4': Invalid row number: '1 and C4'
# Error parsing coordinates for answer 'A1 or C1 or D4': Invalid row number: '1 or C1 or D4'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.5/default/2025-10-20T19-20-02+01-00_directors-task_PkNRqW2U87pg3CrsTYJSuT.eval
# Error parsing coordinates for answer 'D4,A4,B2,A2,C1': Invalid row number: '4,A4,B2,A2,C1'
# Error parsing coordinates for answer 'B1, D1, A2, C3, B4': Invalid row number: '1, D1, A2, C3, B4'
# Error parsing coordinates for answer 'D4 and B4': Invalid row number: '4 and B4'
# Error parsing coordinates for answer 'D1, C1, B3, A1, A3, B4': Invalid row number: '1, C1, B3, A1, A3, B4'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.7/default/2025-10-21T14-46-31+01-00_directors-task_HArkempL7Je5dYRNuL36TL.eval
# Error parsing coordinates for answer 'D4, C4, A4, D3, B2, B1, A1': Invalid row number: '4, C4, A4, D3, B2, B1, A1'
# Error parsing coordinates for answer 'A1, A2, C3, D1, B3': Invalid row number: '1, A2, C3, D1, B3'
# Error parsing coordinates for answer 'D4, D3, D2, C4, C3, C2, B2, B1': Invalid row number: '4, D3, D2, C4, C3, C2, B2, B1'
# Error parsing coordinates for answer 'D1, B1, C2, B3, C3, B4': Invalid row number: '1, B1, C2, B3, C3, B4'
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.9/default/2025-10-21T17-02-03+01-00_directors-task_aRE75H22mfZEaDEXBYHCVa.eval
# Error parsing coordinates for answer 'D1, D2, D3, D4, C2, B1, B3, A1': Invalid row number: '1, D2, D3, D4, C2, B1, B3, A1'
# Error parsing coordinates for answer 'A1, C1, D2': Invalid row number: '1, C1, D2'
# Error parsing coordinates for answer 'C1, B3, B2, A1, C3': Invalid row number: '1, B3, B2, A1, C3'
# Error parsing coordinates for answer 'From the user's perspective (back view, mirrors left and right but keeps up and down): Instruments at D4, C3, D2, A3.': Invalid row number: 'rom the user's perspective (back view, mirrors left and right but keeps up and down): Instruments at D4, C3, D2, A3.'
# Error parsing coordinates for answer '1A': Invalid column letter: '1'
# Error parsing coordinates for answer 'A1, A4, B1, B2': Invalid row number: '1, A4, B1, B2'

# %%
# Visualize left/right errors split by reversed/same direction
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

# Print summary statistics
print("=== LEFT/RIGHT ERROR ANALYSIS ===")
print(f"Test Left Reversed errors: {len(test_left_reversed_errors)}")
print(f"Test Left Same errors: {len(test_left_same_errors)}")
print(f"Test Right Reversed errors: {len(test_right_reversed_errors)}")
print(f"Test Right Same errors: {len(test_right_same_errors)}")

# Combine all errors to determine consistent scaling
all_left_right_errors = (test_left_reversed_errors + test_left_same_errors + 
                        test_right_reversed_errors + test_right_same_errors)

if len(all_left_right_errors) > 0:
    # Get combined range for consistent scaling
    all_x = [error[0] for error in all_left_right_errors]
    all_y = [error[1] for error in all_left_right_errors]
    
    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0
    
    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1
    
    # Create 2x2 subplot for the four categories
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    
    # Function to create individual heatmap
    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center', 
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None
        
        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))
        
        # Fill in the heatmap data
        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count
        
        return heatmap_data, error_counter
    
    # Create heatmaps for each category
    categories = [
        (test_left_reversed_errors, ax1, "Left Reversed 'rightmost x from my perspective'", "Reds"),
        (test_left_same_errors, ax2, "Left Same'leftmost x from your perspective'", "Blues"),
        (test_right_reversed_errors, ax3, "Right Reversed 'leftmost x from my perspective'", "Greens"),
        (test_right_same_errors, ax4, "Right Same 'rightmost x from your perspective'", "Purples")
    ]
    
    # Collect all non-zero data to determine global color scale
    all_heatmaps = []
    all_counters = []
    
    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)
    
    # Find global min/max for consistent color scaling
    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)
    
    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)
        
        # Create the actual heatmaps with consistent scaling
        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                # Create heatmap with log scale
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)
                
                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)
                
                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (Δx)', fontsize=14)
                ax.set_ylabel('Row Error (Δy)', fontsize=14)
                ax.tick_params(labelsize=10)
                
                # Add marker for perfect match
                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150, 
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)
    
    plt.suptitle('GPT-4o Test Sample Errors: Left/Right Questions by perspective', 
                 fontsize=14, y=0.98)
    plt.tight_layout()
    plt.show()
    
    # Print detailed statistics
    print("\n=== DETAILED STATISTICS ===")
    
    category_names = ["Left Reversed 'rightmost x from my perspective'", "Left Same'leftmost x from your perspective'", "Right Reversed 'leftmost x from my perspective'", "Right Same 'rightmost x from your perspective'"]
    error_lists = [test_left_reversed_errors, test_left_same_errors, 
                   test_right_reversed_errors, test_right_same_errors]
    
    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])
            
            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")
            
            if len(errors) > 0:
                counter = Counter(tuple(error) for error in errors)
                print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")
    
else:
    print("No left/right errors found to visualize.")
# Out:
# === LEFT/RIGHT ERROR ANALYSIS ===
# Test Left Reversed errors: 232
# Test Left Same errors: 208
# Test Right Reversed errors: 236
# Test Right Same errors: 196
# === DETAILED STATISTICS ===
#
# Left Reversed 'rightmost x from my perspective':
#   Count: 232
#   Mean error: (+0.61, +0.29)
#   Std error: (1.50, 1.73)
#   Most common: ((np.int64(1), np.int64(0)), 16)
#
# Left Same'leftmost x from your perspective':
#   Count: 208
#   Mean error: (-0.61, -1.12)
#   Std error: (0.93, 1.30)
#   Most common: ((np.int64(0), np.int64(-1)), 35)
#
# Right Reversed 'leftmost x from my perspective':
#   Count: 236
#   Mean error: (+0.12, -0.69)
#   Std error: (1.32, 1.57)
#   Most common: ((np.int64(1), np.int64(0)), 24)
#
# Right Same 'rightmost x from your perspective':
#   Count: 196
#   Mean error: (+0.69, +0.42)
#   Std error: (0.86, 1.71)
#   Most common: ((np.int64(1), np.int64(0)), 28)

# %% [markdown]
# ## Test Top/Bottom Error Collection

# %%
import gc
import numpy as np
from inspect_ai.model import ContentText

test_top_reversed_errors = []
test_top_same_errors = []
test_bottom_reversed_errors = []
test_bottom_same_errors = []

for (fill_index, fill) in enumerate(fill_ratios):
    for (related_index, related) in enumerate(related_ratios):
        log = logs[fill_index][related_index]
        print(f"processing log: {log.location}")
        temp_log = read_eval_log(log.location, resolve_attachments=False)
        assert temp_log.samples is not None
        for sample in temp_log.samples:
            if sample.metadata["sample_type"] == "test":
                assert sample.score is not None
                if sample.score.value != "C":
                    if not isinstance(sample.output.message.content, str):
                        answer = None
                        for output in sample.output.message.content:
                            if isinstance(output, str):
                                answer = output.strip()
                            elif isinstance(output, ContentText):
                                answer = output.text.strip()
                            else:
                                continue
                        if answer is None:
                            print(f"Warning: No valid string found in output content: {sample.output.message.content}")
                            continue
                    else:
                        answer = sample.output.message.content.strip()
                    try:
                        answer_coord = parse_coordinate_string(answer)
                        target_coords = sample.metadata["director_answer_coordinates"]
                        if len(target_coords) != 1:
                            print(f"Warning: Expected exactly 1 target coordinate, got {len(target_coords)}: {target_coords}")
                            continue
                        target_coord = target_coords[0]
                        difference = np.array(answer_coord) - np.array(target_coord)

                        selection_rule = sample.metadata["question"]["selection_rule"]
                        is_reversed = sample.metadata["question"]["is_reversed"]

                        if selection_rule == "topmost" and is_reversed:
                            test_top_reversed_errors.append(difference)
                        elif selection_rule == "topmost" and not is_reversed:
                            test_top_same_errors.append(difference)
                        elif selection_rule == "bottommost" and is_reversed:
                            test_bottom_reversed_errors.append(difference)
                        elif selection_rule == "bottommost" and not is_reversed:
                            test_bottom_same_errors.append(difference)

                    except (ValueError, IndexError, KeyError) as e:
                        print(f"Error parsing coordinates for answer '{answer}': {e}")
                        continue

        del temp_log
        gc.collect()

print(f"Test Top Reversed errors: {len(test_top_reversed_errors)}")
print(f"Test Top Same errors: {len(test_top_same_errors)}")
print(f"Test Bottom Reversed errors: {len(test_bottom_reversed_errors)}")
print(f"Test Bottom Same errors: {len(test_bottom_same_errors)}")
# Out:
# processing log: ../logs/gpt-4o/sweep_2025-10-20_16-08_openai_azure_gpt-4o/fill_ratio_0.9/related_ratio_0.3/default/2025-10-20T16-08-58+01-00_directors-task_bb7gvYHAfjQAnypi5MP7dJ.eval
# Error parsing coordinates for answer 'Let's analyze the grid and identify the rightmost stackable book:
#
# The stackable books are located in the following grid cells:
# - Cell A2: A book is present.
# - Cell C4: A book is present.
# - Cell D4: A book is present.
#
# Among these, the rightmost book is in cell D4.
#
# I will now submit that answer.': Invalid row number: 'et's analyze the grid and identify the rightmost stackable book:
#
# The stackable books are located in the following grid cells:
# - Cell A2: A book is present.
# - Cell C4: A book is present.
# - Cell D4: A book is present.
#
# Among these, the rightmost book is in cell D4.
#
# I will now submit that answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the leftmost sharp shoe from the user's point of view, we need to consider the view from the back of the shelving grid as if standing in the user's position, facing towards the items. The term "sharp shoe" seems to refer to high-heeled shoes rather than roller skates since "sharp" might relate to the conical shape or point.
#
# Here are steps to identify items:
#
# 1. Identify which cells contain "shoes".
#    - The item that resembles a "sharp shoe" is in A2 (considering the high-heeled shoe).
#
# 2. Identify the correct grid cell:
#    - From the user's point of view, the leftmost sharp shoe is in A2, since the shelf is being viewed from the opposite side. The user stands facing grid column D from the back side, making A2 appear on their rightmost side.
#
# Since the user's view is inverted compared to the direct view shown, the leftmost sharp shoe from the user's perspective would be in A2.
#
# Let's submit A2 as our answer.': Invalid row number: 'o find the leftmost sharp shoe from the user's point of view, we need to consider the view from the back of the shelving grid as if standing in the user's position, facing towards the items. The term "sharp shoe" seems to refer to high-heeled shoes rather than roller skates since "sharp" might relate to the conical shape or point.
#
# Here are steps to identify items:
#
# 1. Identify which cells contain "shoes".
#    - The item that resembles a "sharp shoe" is in A2 (considering the high-heeled shoe).
#
# 2. Identify the correct grid cell:
#    - From the user's point of view, the leftmost sharp shoe is in A2, since the shelf is being viewed from the opposite side. The user stands facing grid column D from the back side, making A2 appear on their rightmost side.
#
# Since the user's view is inverted compared to the direct view shown, the leftmost sharp shoe from the user's perspective would be in A2.
#
# Let's submit A2 as our answer.'
# Error parsing coordinates for answer 'To find the topmost music instrument from the user's point of view, I'll identify the positions of all the music instruments in the view from my point of view.
#
# From the image:
# - There's a saxophone in cell A1.
# - There are two trumpets in cell D1 and D2.
#
# Since we need the topmost instrument from the user's point of view:
# - The topmost instrument from the user's view is in the bottom from my perspective.
#
# Therefore, the saxophone is the topmost from the user's perspective. It is in cell A1.
#
# I am going to submit this answer.': Invalid row number: 'o find the topmost music instrument from the user's point of view, I'll identify the positions of all the music instruments in the view from my point of view.
#
# From the image:
# - There's a saxophone in cell A1.
# - There are two trumpets in cell D1 and D2.
#
# Since we need the topmost instrument from the user's point of view:
# - The topmost instrument from the user's view is in the bottom from my perspective.
#
# Therefore, the saxophone is the topmost from the user's perspective. It is in cell A1.
#
# I am going to submit this answer.'
# Error parsing coordinates for answer 'The image displays a shelving grid with various items stored in it. Specifically, there are two sharp shoes positioned in different grid cells. They are located at:
#
# 1. C1
# 2. C2
# 3. C4
#
# The task is to identify and select a sharp shoe from my point of view. I will submit one of these grid cell coordinates. Let me proceed with the submission.': Invalid row number: 'he image displays a shelving grid with various items stored in it. Specifically, there are two sharp shoes positioned in different grid cells. They are located at:
#
# 1. C1
# 2. C2
# 3. C4
#
# The task is to identify and select a sharp shoe from my point of view. I will submit one of these grid cell coordinates. Let me proceed with the submission.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To identify the bottommost stackable book from the user's point of view, I need to look for the lowest row containing a book. From the image:
#
# - There is a book in grid cell A1.
# - Another book is in grid cell C4.
# - Another book is in grid cell D4.
#
# The bottommost row containing books is row 4, and there are books in both column C and D. Therefore, from my point of view, both C4 and D4 contain books.
#
# I will now submit the location of one of these bottommost books from the user's perspective.
#
# Since the user is viewing from the opposite side of the grid, my column A is the user's column D. Hence, the bottommost book from their perspective will be in column A of row 4.
#
# I will submit the grid cell C4 as it represents the bottommost visible stackable book as viewed from the user's perspective.': Invalid row number: 'o identify the bottommost stackable book from the user's point of view, I need to look for the lowest row containing a book. From the image:
#
# - There is a book in grid cell A1.
# - Another book is in grid cell C4.
# - Another book is in grid cell D4.
#
# The bottommost row containing books is row 4, and there are books in both column C and D. Therefore, from my point of view, both C4 and D4 contain books.
#
# I will now submit the location of one of these bottommost books from the user's perspective.
#
# Since the user is viewing from the opposite side of the grid, my column A is the user's column D. Hence, the bottommost book from their perspective will be in column A of row 4.
#
# I will submit the grid cell C4 as it represents the bottommost visible stackable book as viewed from the user's perspective.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'The task is to identify the bottommost sharp shoe from the grid of images. The grid consists of several items, and I'm going to follow these steps to identify the correct grid cell:
#
# 1. Identify all sharp shoes in the grid.
# 2. Determine which one of them is the bottommost.
#
# By visually inspecting the grid from the top row down to the bottom row:
#
# - In row 3, column B (B3), there is a sharply pointed shoe (high heel).
# - In row 3, column C (C3), there is an ice skate.
# - In row 4, column C (C4), there is another ice skate, which is below C3.
#
# Analyzing the grid, the bottommost sharp shoe is located in cell C4, as it's below the high heel in B3 and the skate in C3. Therefore, the cell C4 contains the bottommost sharp shoe.
#
# Now, I'll submit the answer.': Invalid row number: 'he task is to identify the bottommost sharp shoe from the grid of images. The grid consists of several items, and I'm going to follow these steps to identify the correct grid cell:
#
# 1. Identify all sharp shoes in the grid.
# 2. Determine which one of them is the bottommost.
#
# By visually inspecting the grid from the top row down to the bottom row:
#
# - In row 3, column B (B3), there is a sharply pointed shoe (high heel).
# - In row 3, column C (C3), there is an ice skate.
# - In row 4, column C (C4), there is another ice skate, which is below C3.
#
# Analyzing the grid, the bottommost sharp shoe is located in cell C4, as it's below the high heel in B3 and the skate in C3. Therefore, the cell C4 contains the bottommost sharp shoe.
#
# Now, I'll submit the answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'Let's analyze the grid to determine the location of the leftmost shoe from the user's perspective, standing on the opposite side.
#
# From my point of view:
#
# - There are shoes in cells A2, D1, and D4.
#
# From the user's perspective, to locate the leftmost shoe:
# - My A is their D and vice versa.
# - My B is their C and vice versa.
#
# Given this understanding, the leftmost shoe from the user's perspective would be in cell D1.
#
# Now, I will submit this answer.': Invalid row number: 'et's analyze the grid to determine the location of the leftmost shoe from the user's perspective, standing on the opposite side.
#
# From my point of view:
#
# - There are shoes in cells A2, D1, and D4.
#
# From the user's perspective, to locate the leftmost shoe:
# - My A is their D and vice versa.
# - My B is their C and vice versa.
#
# Given this understanding, the leftmost shoe from the user's perspective would be in cell D1.
#
# Now, I will submit this answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the rightmost fruit from my point of view, I will analyze the grid for fruit images. Fruits typically include items that grow on plants or trees.
#
# Inspecting the grid:
#
# - A2 and A3 contain blueberries.
# - C3 contains grapes.
#
# Therefore, the rightmost fruit visible to me is the grapes located at C3.
#
# I will now submit my answer.': Invalid row number: 'o find the rightmost fruit from my point of view, I will analyze the grid for fruit images. Fruits typically include items that grow on plants or trees.
#
# Inspecting the grid:
#
# - A2 and A3 contain blueberries.
# - C3 contains grapes.
#
# Therefore, the rightmost fruit visible to me is the grapes located at C3.
#
# I will now submit my answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To identify the grid cell containing sharp clothes from the user's point of view, I need to consider the attributes and differences between the images in the grid.
#
# **Analysis:**
# - Sharp clothes typically refer to clothing items that have a refined or fashionable appearance.
# - From the visual inspection of the grid, both items in A1 and D4 are ice skates, which are likely used for skating sports and could be considered as related to "sharp clothes" due to their sleek and pointed aesthetic.
#
# Given the symmetry of ice skates being present in both A1 and D4, they serve as the sharp clothes the user might be referring to. In an everyday context, these are the items most closely associated with sharp attire due to their design and application.
#
# Since the user is standing on the opposite side of the shelving:
#
# - From the user's point of view: D1 will align with the top left cell (that is A1).
#
# Thus, I will submit A1 as the grid cell from my point of view that contains the item the user refers to as "sharp clothes".': Invalid row number: 'o identify the grid cell containing sharp clothes from the user's point of view, I need to consider the attributes and differences between the images in the grid.
#
# **Analysis:**
# - Sharp clothes typically refer to clothing items that have a refined or fashionable appearance.
# - From the visual inspection of the grid, both items in A1 and D4 are ice skates, which are likely used for skating sports and could be considered as related to "sharp clothes" due to their sleek and pointed aesthetic.
#
# Given the symmetry of ice skates being present in both A1 and D4, they serve as the sharp clothes the user might be referring to. In an everyday context, these are the items most closely associated with sharp attire due to their design and application.
#
# Since the user is standing on the opposite side of the shelving:
#
# - From the user's point of view: D1 will align with the top left cell (that is A1).
#
# Thus, I will submit A1 as the grid cell from my point of view that contains the item the user refers to as "sharp clothes".'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'Let's first analyze the image to identify the relevant items. We need to locate the bottommost car from my perspective.
#
# From left to right and top to bottom, here are the visible cars in the grid:
# - One car at cell C4
# - Another car at cell D4
#
# The bottommost car is located in the lowest row which is row 4, and in column D from my point of view.
#
# I'll submit the answer as cell D4.': Invalid row number: 'et's first analyze the image to identify the relevant items. We need to locate the bottommost car from my perspective.
#
# From left to right and top to bottom, here are the visible cars in the grid:
# - One car at cell C4
# - Another car at cell D4
#
# The bottommost car is located in the lowest row which is row 4, and in column D from my point of view.
#
# I'll submit the answer as cell D4.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the bottommost calculator from my point of view, I need to scan each column from top to bottom to locate the calculators and identify the one at the lowest row.
#
# - In column A: There are two calculators. One is located at row 3 (A3) and the bottommost one is at row 4 (A4).
# - In column B: No calculator is present.
# - In column C: No calculator is present.
# - In column D: One calculator is located at row 4 (D4).
#
# Both column A and column D have calculators on the bottommost row. However, since I need to pick one that is clearly at the bottommost row, we observe cell A4 and D4 only.
#
# Let's submit the answer based on our observation.': Invalid row number: 'o find the bottommost calculator from my point of view, I need to scan each column from top to bottom to locate the calculators and identify the one at the lowest row.
#
# - In column A: There are two calculators. One is located at row 3 (A3) and the bottommost one is at row 4 (A4).
# - In column B: No calculator is present.
# - In column C: No calculator is present.
# - In column D: One calculator is located at row 4 (D4).
#
# Both column A and column D have calculators on the bottommost row. However, since I need to pick one that is clearly at the bottommost row, we observe cell A4 and D4 only.
#
# Let's submit the answer based on our observation.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the topmost sharp shoe, we need to look at the grid cells that contain shoes and identify the uppermost one from my point of view.
#
# In this grid:
# 1. Shoe in B1
# 2. Shoe in B2
# 3. Shoe in B3
# 4. Shoe in A4
#
# The shoe in B1 is the topmost sharp shoe from my point of view. Thus, I'll submit "B1" as the answer.
#
# Let's proceed with the submission.': Invalid row number: 'o find the topmost sharp shoe, we need to look at the grid cells that contain shoes and identify the uppermost one from my point of view.
#
# In this grid:
# 1. Shoe in B1
# 2. Shoe in B2
# 3. Shoe in B3
# 4. Shoe in A4
#
# The shoe in B1 is the topmost sharp shoe from my point of view. Thus, I'll submit "B1" as the answer.
#
# Let's proceed with the submission.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'The stackable book in the grid is located at grid cell C3.
#
# I will submit this answer.': Invalid row number: 'he stackable book in the grid is located at grid cell C3.
#
# I will submit this answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the location of the blue stackable book from the perspective of the user standing on the opposite side, we can observe the grid:
#
# - The blue stackable books are located in:
#   - D1
#   - A4
#   - B4
#
# Since we're giving the coordinates from my point of view, and from the user's perspective:
#
# - The user will see item D1 as A1
# - The user will see item A4 as D4
# - The user will see item B4 as C4
#
# Considering this, the user is looking for a blue stackable book, let's assume they are requesting the first visible one, but since they didn't specify which, I'll provide the visible options from their perspective.
#
# Let's submit the first visible option from the user's perspective.': Invalid row number: 'o find the location of the blue stackable book from the perspective of the user standing on the opposite side, we can observe the grid:
#
# - The blue stackable books are located in:
#   - D1
#   - A4
#   - B4
#
# Since we're giving the coordinates from my point of view, and from the user's perspective:
#
# - The user will see item D1 as A1
# - The user will see item A4 as D4
# - The user will see item B4 as C4
#
# Considering this, the user is looking for a blue stackable book, let's assume they are requesting the first visible one, but since they didn't specify which, I'll provide the visible options from their perspective.
#
# Let's submit the first visible option from the user's perspective.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'I need to examine the grid to locate the smallest stackable book according to the user’s view. From a library or bookshelf perspective, stackable books generally refer to books that can be placed one on top of another. Here, I will identify all the books present in the grid and determine which one is the smallest by its size.
#
# Observing the image:
#
# - There are two visible books in the grid.
# - One is in cell A4, and another in cell D4.
# - After analyzing the size of depicted books:
#   - The one in D4 seems to be visually smaller, making it the smallest stackable book.
#
# Let's proceed by submitting the answer.': Invalid row number: ' need to examine the grid to locate the smallest stackable book according to the user’s view. From a library or bookshelf perspective, stackable books generally refer to books that can be placed one on top of another. Here, I will identify all the books present in the grid and determine which one is the smallest by its size.
#
# Observing the image:
#
# - There are two visible books in the grid.
# - One is in cell A4, and another in cell D4.
# - After analyzing the size of depicted books:
#   - The one in D4 seems to be visually smaller, making it the smallest stackable book.
#
# Let's proceed by submitting the answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the bottommost stackable book from the user's point of view, I need to identify the location of all books in the grid. In the image, the books are located in the following cells from my point of view:
#
# - B2
# - C4
#
# Among these, the bottommost stackable book from my point of view is in cell C4. I will now submit this as the user's view would make it the cell B4.
#
# Let's submit this answer.': Invalid row number: 'o find the bottommost stackable book from the user's point of view, I need to identify the location of all books in the grid. In the image, the books are located in the following cells from my point of view:
#
# - B2
# - C4
#
# Among these, the bottommost stackable book from my point of view is in cell C4. I will now submit this as the user's view would make it the cell B4.
#
# Let's submit this answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To determine the leftmost stackable book from my point of view, I need to identify the locations of all the stackable books in the grid and select the one furthest to the left.
#
# 1. In grid cell A1, there is a book.
# 2. In grid cell B2, there is another book.
#
# Based on these observations, the leftmost book is located in grid cell A1.
#
# I will now submit A1 as the answer.': Invalid row number: 'o determine the leftmost stackable book from my point of view, I need to identify the locations of all the stackable books in the grid and select the one furthest to the left.
#
# 1. In grid cell A1, there is a book.
# 2. In grid cell B2, there is another book.
#
# Based on these observations, the leftmost book is located in grid cell A1.
#
# I will now submit A1 as the answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To identify the bottommost clothes from my point of view, I need to look for clothing items located at the lowest row of the grid. From the grid provided:
#
# - Column A, Row 4 contains socks.
# - Column D, Row 4 contains another sock.
#
# Both grid cells at Row 4 contain socks, which are pieces of clothing. Therefore, the bottommost clothes in this grid are located at A4 and D4. Since the user only asked for one cell, I will choose A4 for submission.
#
# Let's submit the answer "A4" as the grid cell containing the bottommost clothes.': Invalid row number: 'o identify the bottommost clothes from my point of view, I need to look for clothing items located at the lowest row of the grid. From the grid provided:
#
# - Column A, Row 4 contains socks.
# - Column D, Row 4 contains another sock.
#
# Both grid cells at Row 4 contain socks, which are pieces of clothing. Therefore, the bottommost clothes in this grid are located at A4 and D4. Since the user only asked for one cell, I will choose A4 for submission.
#
# Let's submit the answer "A4" as the grid cell containing the bottommost clothes.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the correct grid cell that contains the stackable book, I need to identify its location from the user's point of view, who is standing on the opposite side of the shelving grid.
#
# From my view:
# - The stackable book is located at positions: C2, A3, and D4.
# - From the user's point of view, the grid would be flipped horizontally.
#
# Based on this reasoning, C2 would appear as C2 from my point of view when flipping the view horizontally.
#
# I'll submit this answer now.': Invalid row number: 'o find the correct grid cell that contains the stackable book, I need to identify its location from the user's point of view, who is standing on the opposite side of the shelving grid.
#
# From my view:
# - The stackable book is located at positions: C2, A3, and D4.
# - From the user's point of view, the grid would be flipped horizontally.
#
# Based on this reasoning, C2 would appear as C2 from my point of view when flipping the view horizontally.
#
# I'll submit this answer now.'
# Error parsing coordinates for answer 'The grid contains four blue shirts. I need to specify the location of one of them.
#
# The locations are as follows:
# - A2
# - B3
# - C2
# - C4
#
# For simplicity, I will select the first blue shirt I see, which is located at "A2". I will submit this answer.
#
# Let's proceed with submitting the selected grid cell.': Invalid row number: 'he grid contains four blue shirts. I need to specify the location of one of them.
#
# The locations are as follows:
# - A2
# - B3
# - C2
# - C4
#
# For simplicity, I will select the first blue shirt I see, which is located at "A2". I will submit this answer.
#
# Let's proceed with submitting the selected grid cell.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'The user is inquiring about the location of the small purple fruit, which in this context appears to be blueberries. Looking at the grid, we can identify the blueberries being stored in two cells: B2 and C2.
#
# From the user's perspective on the opposite side, what appears as B2 to us would appear as D2 to the user, and C2 would look like C2 is correct from the user's perspective as well. Since there are two identical small purple fruits in both B2 and C2 from the user's perspective, I'll select one of the two options.
#
# I am ready to submit the answer.': Invalid row number: 'he user is inquiring about the location of the small purple fruit, which in this context appears to be blueberries. Looking at the grid, we can identify the blueberries being stored in two cells: B2 and C2.
#
# From the user's perspective on the opposite side, what appears as B2 to us would appear as D2 to the user, and C2 would look like C2 is correct from the user's perspective as well. Since there are two identical small purple fruits in both B2 and C2 from the user's perspective, I'll select one of the two options.
#
# I am ready to submit the answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'The user wants to find the "sharp shoe" from their perspective. In the given shelving grid, I see a pair of ice skates that can be considered as having "sharp" blades.
#
# I'll select the grid cell that contains the ice skate. From my perspective:
#
# - The ice skate is located in grid cell C2 and A4.
#
# The selection that fits the description "sharp shoe" is the one in cell C2. I will submit this finding.': Invalid row number: 'he user wants to find the "sharp shoe" from their perspective. In the given shelving grid, I see a pair of ice skates that can be considered as having "sharp" blades.
#
# I'll select the grid cell that contains the ice skate. From my perspective:
#
# - The ice skate is located in grid cell C2 and A4.
#
# The selection that fits the description "sharp shoe" is the one in cell C2. I will submit this finding.'
# Error parsing coordinates for answer 'To find the topmost sharp shoe from my point of view, I'll analyze the grid to determine which ice skates are higher.
#
# - In row 1, column A, there is a sharp shoe (ice skate).
# - In row 1, column C, there is another sharp shoe (ice skate).
# - In row 4, column B, there is a third sharp shoe (ice skate).
#
# The sharp shoes in columns A and C of row 1 are at the same level, which is the topmost position in the grid. Thus, I can choose either A1 or C1.
#
# I will submit my answer as cell A1 since it meets the criteria for being the topmost sharp shoe.': Invalid row number: 'o find the topmost sharp shoe from my point of view, I'll analyze the grid to determine which ice skates are higher.
#
# - In row 1, column A, there is a sharp shoe (ice skate).
# - In row 1, column C, there is another sharp shoe (ice skate).
# - In row 4, column B, there is a third sharp shoe (ice skate).
#
# The sharp shoes in columns A and C of row 1 are at the same level, which is the topmost position in the grid. Thus, I can choose either A1 or C1.
#
# I will submit my answer as cell A1 since it meets the criteria for being the topmost sharp shoe.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the bottommost dress from the user's point of view, I need to identify all the dresses in the grid and select the one that would appear lowest when viewed from the opposite side.
#
# Starting from the top row and examining each one carefully:
# 1. Row 1: There is a dress in cell C1.
# 2. Row 3: Two dresses are in cells A3 and B3.
# 3. Row 4: There are no dresses in this row.
#
# From the opposite side (user's view), the order of rows would be reversed. Therefore, the bottommost dress would be the one in Row 3, as there are no dresses in Row 4.
#
# Since the cell containing the dress is either A3 or B3, for the bottommost dress, the correct answer would be the leftmost if considering the leftmost column from the user's point of view. From my view, the dress on the bottommost row (Row 3) and in the leftmost column would be A3.
#
# Thus, the bottommost dress is located at cell A3 from the user's point of view.
#
# I am going to submit this answer.': Invalid row number: 'o find the bottommost dress from the user's point of view, I need to identify all the dresses in the grid and select the one that would appear lowest when viewed from the opposite side.
#
# Starting from the top row and examining each one carefully:
# 1. Row 1: There is a dress in cell C1.
# 2. Row 3: Two dresses are in cells A3 and B3.
# 3. Row 4: There are no dresses in this row.
#
# From the opposite side (user's view), the order of rows would be reversed. Therefore, the bottommost dress would be the one in Row 3, as there are no dresses in Row 4.
#
# Since the cell containing the dress is either A3 or B3, for the bottommost dress, the correct answer would be the leftmost if considering the leftmost column from the user's point of view. From my view, the dress on the bottommost row (Row 3) and in the leftmost column would be A3.
#
# Thus, the bottommost dress is located at cell A3 from the user's point of view.
#
# I am going to submit this answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'The task is to locate the rightmost car from the user's point of view. Since the user is standing at the back of the shelving grid, I need to determine which column this corresponds to from their perspective.
#
# In the image, the columns are labeled from A (leftmost) to D (rightmost) from my perspective. From the user's perspective, this would be reversed, meaning the columns would go from D (leftmost from their view) to A (rightmost from their view).
#
# There are three car items visible:
# - A blue car in A1.
# - A red car in C1.
# - A red car in D2.
#
# From the user's perspective, the rightmost car would be the one located in A1 from my perspective.
#
# I will submit A1 as the correct answer.': Invalid row number: 'he task is to locate the rightmost car from the user's point of view. Since the user is standing at the back of the shelving grid, I need to determine which column this corresponds to from their perspective.
#
# In the image, the columns are labeled from A (leftmost) to D (rightmost) from my perspective. From the user's perspective, this would be reversed, meaning the columns would go from D (leftmost from their view) to A (rightmost from their view).
#
# There are three car items visible:
# - A blue car in A1.
# - A red car in C1.
# - A red car in D2.
#
# From the user's perspective, the rightmost car would be the one located in A1 from my perspective.
#
# I will submit A1 as the correct answer.'
# Error parsing coordinates for answer 'To find the stackable book from the user's point of view, we need to analyze the grid and identify which items are books.
#
# From my perspective, the books are located in the following grid cells:
#
# 1. B1
# 2. C1
# 3. D1
# 4. C3
#
# These positions translate to the following from the user's perspective:
#
# - A1
# - B1
# - C1
# - C3
#
# To select the correct book, we need to consider the most likely choice the user might have, which usually would be the one directly in their line of sight or easily accessible. The user is most likely to choose the stackable book in grid C1 from their perspective, as it is placed more centrally and at the top.
#
# Therefore, I'll submit C1 as the position of the stackable book from the user's point of view.': Invalid row number: 'o find the stackable book from the user's point of view, we need to analyze the grid and identify which items are books.
#
# From my perspective, the books are located in the following grid cells:
#
# 1. B1
# 2. C1
# 3. D1
# 4. C3
#
# These positions translate to the following from the user's perspective:
#
# - A1
# - B1
# - C1
# - C3
#
# To select the correct book, we need to consider the most likely choice the user might have, which usually would be the one directly in their line of sight or easily accessible. The user is most likely to choose the stackable book in grid C1 from their perspective, as it is placed more centrally and at the top.
#
# Therefore, I'll submit C1 as the position of the stackable book from the user's point of view.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'Let's analyze the image to find the leftmost yellow shoe from our point of view. From our perspective, we see:
#
# - A2: Yellow shoe (high heel)
# - B2: Yellow shoe (high heel)
# - D2: Yellow shoe (high heel)
#
# The leftmost yellow shoe from our perspective is located in grid cell A2.
#
# I will now submit this answer.': Invalid row number: 'et's analyze the image to find the leftmost yellow shoe from our point of view. From our perspective, we see:
#
# - A2: Yellow shoe (high heel)
# - B2: Yellow shoe (high heel)
# - D2: Yellow shoe (high heel)
#
# The leftmost yellow shoe from our perspective is located in grid cell A2.
#
# I will now submit this answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the bottommost bag from the user's perspective, I must first identify which cells contain bags from my current point of view.
#
# From the image provided:
# - There is a bag in cell **A1**.
# - There is another bag in cell **B2**.
# - There is a bag in cell **C2**.
#
# From the user's point of view, the grid is mirrored. The bottommost bag appears to be in row 2, column B. So, the correct cell from the user's perspective is **B2**.
#
# Let's confirm this understanding and submit the answer.': Invalid row number: 'o find the bottommost bag from the user's perspective, I must first identify which cells contain bags from my current point of view.
#
# From the image provided:
# - There is a bag in cell **A1**.
# - There is another bag in cell **B2**.
# - There is a bag in cell **C2**.
#
# From the user's point of view, the grid is mirrored. The bottommost bag appears to be in row 2, column B. So, the correct cell from the user's perspective is **B2**.
#
# Let's confirm this understanding and submit the answer.'
# Error parsing coordinates for answer 'In the shelving grid, the bottommost sharp clothes are ice skates, located at the bottom row. There are two pairs of ice skates visible — one in cell B4 and another in cell C4.
#
# To find the bottommost sharp clothes from the user's point of view, which is the opposite side, I should consider the rightmost pair in my view, which is C4.
#
# I will submit C4 as the correct answer.': Invalid row number: 'n the shelving grid, the bottommost sharp clothes are ice skates, located at the bottom row. There are two pairs of ice skates visible — one in cell B4 and another in cell C4.
#
# To find the bottommost sharp clothes from the user's point of view, which is the opposite side, I should consider the rightmost pair in my view, which is C4.
#
# I will submit C4 as the correct answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the leftmost red clothes from my point of view, I will analyze the grid to identify any red clothing items.
#
# - The grid shows a red shirt in cell A4.
#
# There is only one item that fits the description of red clothing, and it is in cell A4. I will submit this as the answer.': Invalid row number: 'o find the leftmost red clothes from my point of view, I will analyze the grid to identify any red clothing items.
#
# - The grid shows a red shirt in cell A4.
#
# There is only one item that fits the description of red clothing, and it is in cell A4. I will submit this as the answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To select the rightmost sharp shoe from the user's point of view, we need to determine which shoe is furthest to the user's right on the grid.
#
# There are three sharp shoes visible in the grid:
# 1. B1
# 2. B2
# 3. C3
#
# From the user's perspective, which is facing from D towards A, the shoe in C3 is the rightmost because it appears further to the user's right.
#
# Hence, the correct answer is C3.
#
# I will submit this answer using the submit function.': Invalid row number: 'o select the rightmost sharp shoe from the user's point of view, we need to determine which shoe is furthest to the user's right on the grid.
#
# There are three sharp shoes visible in the grid:
# 1. B1
# 2. B2
# 3. C3
#
# From the user's perspective, which is facing from D towards A, the shoe in C3 is the rightmost because it appears further to the user's right.
#
# Hence, the correct answer is C3.
#
# I will submit this answer using the submit function.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To locate the largest stackable book from my point of view, I need to examine each grid cell to determine which ones contain a book and then identify the largest one. From the image provided:
#
# - Grid C3 contains a small book.
# - Grid A3 contains a larger book.
# - Grid D4 also contains a book which appears about the same size as the one in A3.
#
# Visually comparing these options, the book in A3 and D4 are the same size, the largest within the grid. Hence, I will submit either A3 or D4 as both have the largest stackable book. Since either may be correct depending on slight differences in perspective, I will choose D4 for submission.': Invalid row number: 'o locate the largest stackable book from my point of view, I need to examine each grid cell to determine which ones contain a book and then identify the largest one. From the image provided:
#
# - Grid C3 contains a small book.
# - Grid A3 contains a larger book.
# - Grid D4 also contains a book which appears about the same size as the one in A3.
#
# Visually comparing these options, the book in A3 and D4 are the same size, the largest within the grid. Hence, I will submit either A3 or D4 as both have the largest stackable book. Since either may be correct depending on slight differences in perspective, I will choose D4 for submission.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To determine the rightmost sharp clothes from my point of view, I need to identify all clothing items in the grid and then select the one that is furthest to the right.
#
# Upon reviewing the grid, I can identify the following clothing items:
# 1. B1: A pair of socks.
# 2. C1: Ice skates.
# 3. D1: Ice skates.
# 4. B3: A black t-shirt.
# 5. C3: Ice skates.
# 6. D2: A red scarf.
#
# The rightmost grid column is 'D'. Among the items in column D, the ice skates in D1 are positioned to the extreme right on the grid. Thus, the rightmost sharp clothing item is the ice skates in cell D1.
#
# I will now submit this as the correct answer.': Invalid row number: 'o determine the rightmost sharp clothes from my point of view, I need to identify all clothing items in the grid and then select the one that is furthest to the right.
#
# Upon reviewing the grid, I can identify the following clothing items:
# 1. B1: A pair of socks.
# 2. C1: Ice skates.
# 3. D1: Ice skates.
# 4. B3: A black t-shirt.
# 5. C3: Ice skates.
# 6. D2: A red scarf.
#
# The rightmost grid column is 'D'. Among the items in column D, the ice skates in D1 are positioned to the extreme right on the grid. Thus, the rightmost sharp clothing item is the ice skates in cell D1.
#
# I will now submit this as the correct answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# ...
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To identify the only sharp shoe, I need to analyze the image of the shelving grid for any distinctive features.
#
# All the shelves mainly contain ice skates except for one shelf with a rose. Upon close examination:
#
# - The shoes (ice skates) on the shelves can be considered sharp due to their blades.
# - However, among the shelves A1, A2, A3, A4, B2, B4, C1, C3, D4 - all containing ice skates, none appear distinctively "sharper" than the others from a visual sharpness standpoint.
#
# This makes it tricky since all skates generally have sharp blades. I will assume the user means the specifically identified or “noteworthy” sharp shoe relative to orientation and visual clarity potentially aligned with user’s intent avoiding any non-shoes like a flower.
#
# Now, I’ll choose one based on evident physical orientation or clarity:
#
# - **B3** (flower) is not a shoe, so focus is around others and they look similar.
# - **A1** visually stands at a prominent position to mention as relatable sharp clarity or stand, even causing that as standout within skates since skates can be considered uniformly - for they possess defined sharp blades from our angle.
#
# Given above clarification:
#
# **A1** holds a defined perspective mostly aligning likely requests.
#
# Let’s proceed with confirming this selection.': Invalid row number: 'o identify the only sharp shoe, I need to analyze the image of the shelving grid for any distinctive features.
#
# All the shelves mainly contain ice skates except for one shelf with a rose. Upon close examination:
#
# - The shoes (ice skates) on the shelves can be considered sharp due to their blades.
# - However, among the shelves A1, A2, A3, A4, B2, B4, C1, C3, D4 - all containing ice skates, none appear distinctively "sharper" than the others from a visual sharpness standpoint.
#
# This makes it tricky since all skates generally have sharp blades. I will assume the user means the specifically identified or “noteworthy” sharp shoe relative to orientation and visual clarity potentially aligned with user’s intent avoiding any non-shoes like a flower.
#
# Now, I’ll choose one based on evident physical orientation or clarity:
#
# - **B3** (flower) is not a shoe, so focus is around others and they look similar.
# - **A1** visually stands at a prominent position to mention as relatable sharp clarity or stand, even causing that as standout within skates since skates can be considered uniformly - for they possess defined sharp blades from our angle.
#
# Given above clarification:
#
# **A1** holds a defined perspective mostly aligning likely requests.
#
# Let’s proceed with confirming this selection.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'The task requires identifying the bottommost cactus plant from my perspective (viewing the shelving grid from the front). The grid layout shows the following:
#
# - Column A: Cactus in row 1 and 2
# - Column B: Cactus in row 1, 2, and 3
# - Column C: Cactus in row 3
# - Column D: Cactus in row 2 and 4
#
# The bottommost cactus plant from my perspective is in Column D at Row 4. Therefore, the answer is D4.
#
# Let's submit the answer.': Invalid row number: 'he task requires identifying the bottommost cactus plant from my perspective (viewing the shelving grid from the front). The grid layout shows the following:
#
# - Column A: Cactus in row 1 and 2
# - Column B: Cactus in row 1, 2, and 3
# - Column C: Cactus in row 3
# - Column D: Cactus in row 2 and 4
#
# The bottommost cactus plant from my perspective is in Column D at Row 4. Therefore, the answer is D4.
#
# Let's submit the answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To tackle this problem, I'm tasked with identifying the topmost sharp shoe from the user's point of view (which corresponds to the back of the shelving grid).
#
# 1. Since the user is standing on the opposite side, I need to imagine the grid flipped.
# 2. I need to find the sharp shoe that is placed in a grid cell visible from the back and identify its topmost position.
#
# In the grid:
# - Column A has the shoes in cells A1, A2, A3, and A4; which have transparent plates.
# - Column B has the shoes in cells B1 and B2; which also have transparent plates.
# - Column C is empty.
# - Column D also has transparent plates, making D3 and D4 not visible from the user's perspective.
#
# Given these observations:
# - The visible topmost shoe, when viewed from the back, would be in column A, row 1.
#
# I will now submit "A1" as the answer since it corresponds to this observation.': Invalid row number: 'o tackle this problem, I'm tasked with identifying the topmost sharp shoe from the user's point of view (which corresponds to the back of the shelving grid).
#
# 1. Since the user is standing on the opposite side, I need to imagine the grid flipped.
# 2. I need to find the sharp shoe that is placed in a grid cell visible from the back and identify its topmost position.
#
# In the grid:
# - Column A has the shoes in cells A1, A2, A3, and A4; which have transparent plates.
# - Column B has the shoes in cells B1 and B2; which also have transparent plates.
# - Column C is empty.
# - Column D also has transparent plates, making D3 and D4 not visible from the user's perspective.
#
# Given these observations:
# - The visible topmost shoe, when viewed from the back, would be in column A, row 1.
#
# I will now submit "A1" as the answer since it corresponds to this observation.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the bottommost stackable book from my point of view, I need to identify the lowest row that contains a book. From my perspective, the bottommost row is row 4, and each cell in row 4 from A to D contains a stackable book.
#
# Therefore, the bottommost stackable book is located in either A4, B4, C4, or D4. Since the user is asking for the location from my point of view, any of these cell coordinates would be correct. I'll select the first option, A4.
#
# Let's submit the answer as 'A4'.': Invalid row number: 'o find the bottommost stackable book from my point of view, I need to identify the lowest row that contains a book. From my perspective, the bottommost row is row 4, and each cell in row 4 from A to D contains a stackable book.
#
# Therefore, the bottommost stackable book is located in either A4, B4, C4, or D4. Since the user is asking for the location from my point of view, any of these cell coordinates would be correct. I'll select the first option, A4.
#
# Let's submit the answer as 'A4'.'
# Error parsing coordinates for answer 'To find the smallest stackable book from the user's point of view (the opposite side of the grid), I need to look for the smallest depiction of a book in the grid from my point of view.
#
# From the image, I can see that:
# - There are three individual, smaller blue books located at:
#   - Column B, Row 1
#   - Column C, Row 1
#   - Column D, Row 3
#
# Out of these, the smallest one seems to be the one at Column C, Row 1.
#
# Thus, from my point of view, the correct grid position for the smallest stackable book is C1. I'll convert this to the user's perspective to ensure accuracy:
#
# So the corresponding grid position from the user's perspective would be C4 (since the user is on the opposite side).
#
# Now, I will submit the answer `C4`.': Invalid row number: 'o find the smallest stackable book from the user's point of view (the opposite side of the grid), I need to look for the smallest depiction of a book in the grid from my point of view.
#
# From the image, I can see that:
# - There are three individual, smaller blue books located at:
#   - Column B, Row 1
#   - Column C, Row 1
#   - Column D, Row 3
#
# Out of these, the smallest one seems to be the one at Column C, Row 1.
#
# Thus, from my point of view, the correct grid position for the smallest stackable book is C1. I'll convert this to the user's perspective to ensure accuracy:
#
# So the corresponding grid position from the user's perspective would be C4 (since the user is on the opposite side).
#
# Now, I will submit the answer `C4`.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the bottommost sharp shoe from my point of view, I need to identify the grid cell containing the ice skate which is located furthest down. Let's analyze each row starting from the bottom:
#
# - **Row 4**: There are two ice skates in this row, located in cells `A4` and `C4`.
# - **Row 3**: Ice skates are located in `A3` and `B3`, alongside a scarf.
# - **Row 2**: Ice skates are located in `A2`, `C2`, and `D2`.
# - **Row 1**: Ice skates are in `A1`, `B1`, `C1`, `D1`.
#
# From row 4, skates are located in cells `A4` and `C4`. These cells are the bottommost.
#
# Now, I will choose one of the grid cells to submit. I'll go with `A4`, arbitrarily, as both `A4` and `C4` are suitable answers.
#
# Let's submit this answer.': Invalid row number: 'o find the bottommost sharp shoe from my point of view, I need to identify the grid cell containing the ice skate which is located furthest down. Let's analyze each row starting from the bottom:
#
# - **Row 4**: There are two ice skates in this row, located in cells `A4` and `C4`.
# - **Row 3**: Ice skates are located in `A3` and `B3`, alongside a scarf.
# - **Row 2**: Ice skates are located in `A2`, `C2`, and `D2`.
# - **Row 1**: Ice skates are in `A1`, `B1`, `C1`, `D1`.
#
# From row 4, skates are located in cells `A4` and `C4`. These cells are the bottommost.
#
# Now, I will choose one of the grid cells to submit. I'll go with `A4`, arbitrarily, as both `A4` and `C4` are suitable answers.
#
# Let's submit this answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer 'To find the correct grid cell from the user's point of view, we need to consider how the view differs from the back versus the front. The user is looking at the shelf from the opposite side, so the positions are mirrored horizontally.
#
# From our point of view, the book is present in almost all grid cells except B1 and B2. Since the user is looking from the other side, we need to account for this mirroring effect.
#
# Let's determine the grid coordinates:
# - From the user's point of view, the leftmost column becomes the rightmost column (D becomes A, C becomes B, B becomes C, and A becomes D from the user's view).
#
# Since the books are present in almost all cells, the grid cells with gaps (B1, and B2) from the user's perspective will be flipped to "C1, and C2" in our perspective.
#
# Therefore, selecting any book from the user's point of view:
# - Column D from their view corresponds to Column A in our view
# - From their top to bottom, it stays the same, so let's select A1 from our perspective (which would be the topmost book in their most extreme right column)
#
# Let's submit the answer.': Invalid row number: 'o find the correct grid cell from the user's point of view, we need to consider how the view differs from the back versus the front. The user is looking at the shelf from the opposite side, so the positions are mirrored horizontally.
#
# From our point of view, the book is present in almost all grid cells except B1 and B2. Since the user is looking from the other side, we need to account for this mirroring effect.
#
# Let's determine the grid coordinates:
# - From the user's point of view, the leftmost column becomes the rightmost column (D becomes A, C becomes B, B becomes C, and A becomes D from the user's view).
#
# Since the books are present in almost all cells, the grid cells with gaps (B1, and B2) from the user's perspective will be flipped to "C1, and C2" in our perspective.
#
# Therefore, selecting any book from the user's point of view:
# - Column D from their view corresponds to Column A in our view
# - From their top to bottom, it stays the same, so let's select A1 from our perspective (which would be the topmost book in their most extreme right column)
#
# Let's submit the answer.'
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Error parsing coordinates for answer '': Invalid coordinate string: ''
# Test Top Reversed errors: 0
# Test Top Same errors: 0
# Test Bottom Reversed errors: 0
# Test Bottom Same errors: 0

# %% [markdown]
# ## Combined (Test + Control) Left/Right Error Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

combined_left_reversed_errors = control_left_reversed_errors + test_left_reversed_errors
combined_left_same_errors = control_left_same_errors + test_left_same_errors
combined_right_reversed_errors = control_right_reversed_errors + test_right_reversed_errors
combined_right_same_errors = control_right_same_errors + test_right_same_errors

print("=== COMBINED LEFT/RIGHT ERROR ANALYSIS ===")
print(f"Combined Left Reversed errors: {len(combined_left_reversed_errors)}")
print(f"Combined Left Same errors: {len(combined_left_same_errors)}")
print(f"Combined Right Reversed errors: {len(combined_right_reversed_errors)}")
print(f"Combined Right Same errors: {len(combined_right_same_errors)}")

all_left_right_errors = (combined_left_reversed_errors + combined_left_same_errors +
                        combined_right_reversed_errors + combined_right_same_errors)

if len(all_left_right_errors) > 0:
    all_x = [error[0] for error in all_left_right_errors]
    all_y = [error[1] for error in all_left_right_errors]

    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0

    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1

    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))

    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center',
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None

        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))

        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count

        return heatmap_data, error_counter

    categories = [
        (combined_left_reversed_errors, ax1, "Left Reversed 'rightmost x from my perspective'", "Reds"),
        (combined_left_same_errors, ax2, "Left Same 'leftmost x from your perspective'", "Blues"),
        (combined_right_reversed_errors, ax3, "Right Reversed 'leftmost x from my perspective'", "Greens"),
        (combined_right_same_errors, ax4, "Right Same 'rightmost x from your perspective'", "Purples")
    ]

    all_heatmaps = []
    all_counters = []

    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)

    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)

    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)

        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)

                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)

                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (dx)', fontsize=14)
                ax.set_ylabel('Row Error (dy)', fontsize=14)
                ax.tick_params(labelsize=10)

                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150,
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)

    plt.suptitle('GPT-4o Errors: Left/Right Questions by Perspective',
                 fontsize=18, y=0.98)
    plt.tight_layout()
    plt.show()

    print("\n=== DETAILED STATISTICS ===")

    category_names = ["Left Reversed 'rightmost x from my perspective'", "Left Same 'leftmost x from your perspective'", "Right Reversed 'leftmost x from my perspective'", "Right Same 'rightmost x from your perspective'"]
    error_lists = [combined_left_reversed_errors, combined_left_same_errors,
                   combined_right_reversed_errors, combined_right_same_errors]

    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])

            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")

            counter = Counter(tuple(error) for error in errors)
            print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")

else:
    print("No left/right errors found to visualize.")
# Out:
# === COMBINED LEFT/RIGHT ERROR ANALYSIS ===
# Combined Left Reversed errors: 427
# Combined Left Same errors: 359
# Combined Right Reversed errors: 444
# Combined Right Same errors: 347
# === DETAILED STATISTICS ===
#
# Left Reversed 'rightmost x from my perspective':
#   Count: 427
#   Mean error: (+1.06, +0.39)
#   Std error: (1.50, 1.68)
#   Most common: ((np.int64(1), np.int64(0)), 29)
#
# Left Same 'leftmost x from your perspective':
#   Count: 359
#   Mean error: (+0.03, -1.33)
#   Std error: (1.11, 1.25)
#   Most common: ((np.int64(0), np.int64(-1)), 45)
#
# Right Reversed 'leftmost x from my perspective':
#   Count: 444
#   Mean error: (-0.39, -0.74)
#   Std error: (1.39, 1.57)
#   Most common: ((np.int64(0), np.int64(-1)), 42)
#
# Right Same 'rightmost x from your perspective':
#   Count: 347
#   Mean error: (+0.07, +0.31)
#   Std error: (1.09, 1.60)
#   Most common: ((np.int64(-1), np.int64(0)), 39)

# %% [markdown]
# ## Combined (Test + Control) Top/Bottom Error Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.colors import LogNorm

combined_top_reversed_errors = control_top_reversed_errors + test_top_reversed_errors
combined_top_same_errors = control_top_same_errors + test_top_same_errors
combined_bottom_reversed_errors = control_bottom_reversed_errors + test_bottom_reversed_errors
combined_bottom_same_errors = control_bottom_same_errors + test_bottom_same_errors

print("=== COMBINED TOP/BOTTOM ERROR ANALYSIS ===")
print(f"Combined Top Reversed errors: {len(combined_top_reversed_errors)}")
print(f"Combined Top Same errors: {len(combined_top_same_errors)}")
print(f"Combined Bottom Reversed errors: {len(combined_bottom_reversed_errors)}")
print(f"Combined Bottom Same errors: {len(combined_bottom_same_errors)}")

all_top_bottom_errors = (combined_top_reversed_errors + combined_top_same_errors +
                        combined_bottom_reversed_errors + combined_bottom_same_errors)

if len(all_top_bottom_errors) > 0:
    all_x = [error[0] for error in all_top_bottom_errors]
    all_y = [error[1] for error in all_top_bottom_errors]

    combined_max_abs_x = max(abs(min(all_x)), abs(max(all_x))) if all_x else 0
    combined_max_abs_y = max(abs(min(all_y)), abs(max(all_y))) if all_y else 0

    grid_size_x = 2 * combined_max_abs_x + 1
    grid_size_y = 2 * combined_max_abs_y + 1

    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))

    def create_heatmap(errors, ax, title, cmap_color):
        if len(errors) == 0:
            ax.text(0.5, 0.5, 'No Data', horizontalalignment='center',
                   verticalalignment='center', transform=ax.transAxes, fontsize=16)
            ax.set_title(title, fontsize=16)
            return None, None

        error_counter = Counter(tuple(error) for error in errors)
        heatmap_data = np.zeros((grid_size_y, grid_size_x))

        for (dx, dy), count in error_counter.items():
            heatmap_x = dx + combined_max_abs_x
            heatmap_y = dy + combined_max_abs_y
            heatmap_data[heatmap_y, heatmap_x] = count

        return heatmap_data, error_counter

    categories = [
        (combined_top_reversed_errors, ax1, "Top Reversed 'topmost x from my perspective'", "Reds"),
        (combined_top_same_errors, ax2, "Top Same 'topmost x from your perspective'", "Blues"),
        (combined_bottom_reversed_errors, ax3, "Bottom Reversed 'bottommost x from my perspective'", "Greens"),
        (combined_bottom_same_errors, ax4, "Bottom Same 'bottommost x from your perspective'", "Purples")
    ]

    all_heatmaps = []
    all_counters = []

    for errors, ax, title, cmap in categories:
        heatmap_data, counter = create_heatmap(errors, ax, title, cmap)
        all_heatmaps.append(heatmap_data)
        all_counters.append(counter)

    nonzero_values = []
    for heatmap_data in all_heatmaps:
        if heatmap_data is not None:
            nonzero = heatmap_data[heatmap_data > 0]
            if len(nonzero) > 0:
                nonzero_values.extend(nonzero)

    if len(nonzero_values) > 0:
        global_vmin = min(nonzero_values)
        global_vmax = max(nonzero_values)

        for i, (errors, ax, title, cmap) in enumerate(categories):
            heatmap_data = all_heatmaps[i]
            if heatmap_data is not None:
                heatmap_data_log = np.where(heatmap_data > 0, heatmap_data, np.nan)

                sns.heatmap(heatmap_data_log,
                           annot=heatmap_data,
                           fmt='g',
                    annot_kws={'fontsize': 12},
                           cmap=cmap,
                           norm=LogNorm(vmin=global_vmin, vmax=global_vmax),
                           xticklabels=range(-combined_max_abs_x, combined_max_abs_x + 1),
                           yticklabels=range(-combined_max_abs_y, combined_max_abs_y + 1),
                           cbar_kws={'label': 'Errors (log scale)'},
                           ax=ax)

                ax.set_title(f'{title}\n({len(errors)} errors)', fontsize=16)
                ax.set_xlabel('Column Error (dx)', fontsize=14)
                ax.set_ylabel('Row Error (dy)', fontsize=14)
                ax.tick_params(labelsize=10)

                center_x = combined_max_abs_x
                center_y = combined_max_abs_y
                ax.scatter(center_x + 0.5, center_y + 0.5, marker='*', s=150,
                          color='white', edgecolor='black', linewidth=2,
                          label='Perfect Match (0,0)')
                ax.legend(fontsize=8)

    plt.suptitle('GPT-4o Errors: Top/Bottom Questions by Perspective',
                 fontsize=18, y=0.98)
    plt.tight_layout()
    plt.show()

    print("\n=== DETAILED STATISTICS ===")

    category_names = [
        "Top Reversed 'topmost x from my perspective'",
        "Top Same 'topmost x from your perspective'",
        "Bottom Reversed 'bottommost x from my perspective'",
        "Bottom Same 'bottommost x from your perspective'"
    ]
    error_lists = [combined_top_reversed_errors, combined_top_same_errors,
                   combined_bottom_reversed_errors, combined_bottom_same_errors]

    for name, errors in zip(category_names, error_lists):
        if len(errors) > 0:
            x_errors = np.array([error[0] for error in errors])
            y_errors = np.array([error[1] for error in errors])

            print(f"\n{name}:")
            print(f"  Count: {len(errors)}")
            print(f"  Mean error: ({np.mean(x_errors):+.2f}, {np.mean(y_errors):+.2f})")
            print(f"  Std error: ({np.std(x_errors):.2f}, {np.std(y_errors):.2f})")

            counter = Counter(tuple(error) for error in errors)
            print(f"  Most common: {counter.most_common(1)[0]}")
        else:
            print(f"\n{name}: No errors")

else:
    print("No top/bottom errors found to visualize.")
# Out:
# === COMBINED TOP/BOTTOM ERROR ANALYSIS ===
# Combined Top Reversed errors: 92
# Combined Top Same errors: 50
# Combined Bottom Reversed errors: 151
# Combined Bottom Same errors: 102
# === DETAILED STATISTICS ===
#
# Top Reversed 'topmost x from my perspective':
#   Count: 92
#   Mean error: (+0.14, +0.83)
#   Std error: (1.75, 1.23)
#   Most common: ((np.int64(1), np.int64(0)), 13)
#
# Top Same 'topmost x from your perspective':
#   Count: 50
#   Mean error: (-0.68, +0.60)
#   Std error: (1.53, 0.77)
#   Most common: ((np.int64(1), np.int64(0)), 9)
#
# Bottom Reversed 'bottommost x from my perspective':
#   Count: 151
#   Mean error: (+0.15, -0.47)
#   Std error: (1.61, 1.02)
#   Most common: ((np.int64(1), np.int64(0)), 36)
#
# Bottom Same 'bottommost x from your perspective':
#   Count: 102
#   Mean error: (+0.34, -0.36)
#   Std error: (1.38, 0.79)
#   Most common: ((np.int64(1), np.int64(0)), 33)
